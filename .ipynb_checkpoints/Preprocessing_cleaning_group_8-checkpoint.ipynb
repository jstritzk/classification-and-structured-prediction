# %% [markdown]
# ## Dependencies

# %%
# General.

from nltk.collocations import BigramCollocationFinder, BigramAssocMeasures
from collections import defaultdict
from nltk.corpus import stopwords
from collections import Counter
from string import punctuation
import pandas as pd
import numpy as np
import spacy
import re
import os

# %% [markdown]
# # 2.2 Preprocessing & cleaning

# %% [markdown]
# ## 2.2.1. Preprocessing
#
# It includes the following steps:
# * **Resumes**
#
#     * Preprocessing:
#         * Select job applications with unique job label
#         * Select job labels that have a high-enough count and that are also present in the job descriptions
#
#
# * **Job descriptions**
#
#     * Preprocessing:
#         * Select only IT job descriptions
#         * Within IT jobs, group similar job labels under one label (for example, *Senior systems administrator* and *Systems manager* are being grouped under *systems_administrator*)
#         * Only select job labels that have a high-enough count and that are also present in the job applications

# %% [markdown]
# ## Resumes

# %%
# Source data: https://github.com/florex/resume_corpus.

folder = sorted(os.listdir('resumes_corpus')) # Read in names of all files in this folder.

resume_positions = [] # Empty list to save labels.
resume_text = [] # Empty list to save documents (i.e. texts).

for file in folder:
    if file[-3:] == 'lab': # If extension ends with 'lab', add to labels list.
        with open('resumes_corpus/' + file) as f:
            lines = f.readlines()
            resume_positions.append(lines)
            
    if file[-3:] == 'txt': # If extension ends with 'txt', add to documents list.          
        with open('resumes_corpus/' + file, encoding = "utf8", errors ='ignore') as f:
            lines = f.readlines()
            resume_text.extend(lines)

# %%
# Inspect the different labels in the dataset.

resume_positions_unique = []

for p in resume_positions:
    for p_i in p:
        resume_positions_unique.append(p_i.strip('\n')) # Clean-up a bit.
    
set(resume_positions_unique)
# Out:
# {'Database_Administrator',
#  'Front_End_Developer',
#  'Java_Developer',
#  'Network_Administrator',
#  'Project_manager',
#  'Python_Developer',
#  'Security_Analyst',
#  'Software_Developer',
#  'Systems_Administrator',
#  'Web_Developer'}

# %%
# Some resumes have multiple labels.

resume_positions_clean = []

for p in resume_positions:
    current_position = ''
    
    for p_i in range(0, len(p)):
        if p_i == len(p)-1:
            current_position += p[p_i].strip('\n')
        else:
            current_position += p[p_i].strip('\n') + ' | '
            
    resume_positions_clean.append(current_position)

Counter(resume_positions_clean).most_common(10)
# Out:
# [('Systems_Administrator', 2349),
#  ('Project_manager', 2339),
#  ('Database_Administrator', 2225),
#  ('Software_Developer', 1991),
#  ('Web_Developer | Software_Developer', 1896),
#  ('Python_Developer | Software_Developer', 1738),
#  ('Security_Analyst', 1563),
#  ('Network_Administrator', 1466),
#  ('Software_Developer | Front_End_Developer', 1372),
#  ('Java_Developer | Software_Developer', 1324)]

# %%
# Continue with the 'uniquely' defined labels: 
# 1. Network_Administrator
# 2. Software_Developer
# 3. Database_Administrator
# 4. Project_manager
# 5. Systems_Administrator
# 6. Security_Analyst

# %%
KEEP = np.array(pd.Series(resume_positions_clean).isin(['Network_Administrator' , 'Security_Analyst',
                                                'Software_Developer', 'Database_Administrator',
                                                'Project_manager', 'Systems_Administrator']))

# %%
df_resume_final = pd.DataFrame(list(zip(np.array(resume_text)[KEEP], np.array(resume_positions_clean)[KEEP])),
                               columns = ['Resume', 'Label'])

df_resume_final
# Out:
#                                                   Resume  \
# 0      Database Administrator <span class="hl">Databa...
# 1      Database Administrator <span class="hl">Databa...
# 2      Oracle Database Administrator Oracle <span cla...
# 3      Amazon Redshift Administrator and ETL Develope...
# 4      Scrum Master Scrum Master Scrum Master Richmon...
# ...                                                  ...
# 11928  Full Stack Developer/Founder Full Stack <span ...
# 11929  Software Developer Software <span class="hl">D...
# 11930  Job Seeker Work Experience Angular February 20...
# 11931  Software Developer Software <span class="hl">D...
# 11932  Web Software Engineer <span class="hl">Web</sp...
#
#                         Label
# 0      Database_Administrator
# 1      Database_Administrator
# 2      Database_Administrator
# 3      Database_Administrator
# 4      Database_Administrator
# ...                       ...
# 11928      Software_Developer
# 11929      Software_Developer
# 11930      Software_Developer
# 11931      Software_Developer
# 11932      Software_Developer
#
# [11933 rows x 2 columns]

# %%
df_resume_final.Label.value_counts()
# Out:
# Systems_Administrator     2349
# Project_manager           2339
# Database_Administrator    2225
# Software_Developer        1991
# Security_Analyst          1563
# Network_Administrator     1466
# Name: Label, dtype: int64

# %% [markdown]
# ## Job descriptions

# %%
# Source data: https://www.kaggle.com/code/chadalee/text-analytics-explained-job-description-data/data?select=Train_rev1.csv.

df_descriptions = pd.read_csv('job_descriptions.csv') 
df_descriptions = df_descriptions[['Title', 'FullDescription', 'Category']]

df_descriptions.Category.value_counts()[:10]
# Out:
# IT Jobs                             38483
# Engineering Jobs                    25174
# Accounting & Finance Jobs           21846
# Healthcare & Nursing Jobs           21076
# Sales Jobs                          17272
# Other/General Jobs                  17055
# Teaching Jobs                       12637
# Hospitality & Catering Jobs         11351
# PR, Advertising & Marketing Jobs     8854
# Trade & Construction Jobs            8837
# Name: Category, dtype: int64

# %%
# Select IT jobs to match Resume dataset.

df_descriptions_IT = df_descriptions[df_descriptions['Category'] == 'IT Jobs']

# %%
# We observe that almost every job listing has a different/unique title.

set(df_descriptions_IT.Title)
# Out:
# {'Access & Identity Management',
#  'Server Support Engineer',
#  'Junior / Mid level Java/ J****EE Developer  Chessington Circa ****K',
#  'C Web Developer (Junior  Mid)',
#  'SENIOR NET DEVELOPER  LONDON',
#  'Senior Business Analyst  Change  Northampton',
#  'SENIOR AGILE ASPNET MVC DEVELOPER  FX / TRADING/ ****K',
#  'JUNIOR TELEMARKETER / JUNIOR TELESALES',
#  'Back End Java Developer',
#  'SENIOR PHP WEB DEVELOPER',
#  'Java Analyst Programmer – Surrey',
#  'Technical Operator/Junior Database Administrator/SQL Specialist',
#  'Junior Games Developer  Unity****D',
#  'WebMethods Developer',
#  'Software tester, Software test analyst  Performance, Integration, QTP',
#  'Web Developer (Javascript, Ajax, HTML, CSS, Net)',
#  'C NET Developer (Enterprise Web Solutions)',
#  'Mobile Developer  PhoneGap, iOS,  Games Developer  London',
#  'Multimedia Developer Graduate opportunity SW',
#  'Software / Web Developer ( ASPNET, C )',
#  'Arabic Speaking Teacher  SEN experience',
#  'UI Designer (ecommerce, mobile, HTML, CSS)  ****k',
#  'Software Project Manager Supply Chain Logistics',
#  'Cisco Engineer  Manchester City Centre  ****k****k plus benefits',
#  'Sr Application Support Consultant',
#  'Junior / Graduate NET Developer  Music Industry Nottingham',
#  'DBA',
#  'PreSales Consultant  Storage',
#  'MS CRM Developer, Bristol, ****  ****k  Latest Technologies',
#  'Presales Consultant  Security/Encryption; London,',
#  'UX / Web Front End CMS Developer',
#  'PHP Developer  Online Giant Fareham ****k',
#  'Implementation Consultant Payroll/HR Software N West ****k',
#  'Java Integration Engineer',
#  'IT Director',
#  'ORACLE IMPLEMENTATION FUNCTIONAL CONSULTANT, PERM, ****K',
#  'Senior Business Intelligence / Analytics Sales (ERP)',
#  'Virtualisation Consultant',
#  'EMC Storage Consultant  EMC, Storage, design, implementation',
#  'IT Help Desk Manager  West London',
#  'Microsoft Lync Consultant  Lync 2010/2013  Reading  ****k****k',
#  'Research Analyst',
#  'Network Analyst',
#  'Quality Engineer  Realistic progression to Team Leader',
#  'Information Security Specialist',
#  'ASPNET/ C Developer Birmingham',
#  'Technical Consultant  Citrix CCA CCIA VCP',
#  'Junior Technical Consultant  Software House',
#  'Application Support Analyst  Social Care',
#  'ASPNET MVC Developer  Oxford  **** , **** / **** , ****',
#  'Functional Tester',
#  'Cost Estimating Team Leader',
#  'C Developer / OOP Nottingham ****k',
#  'Applications Manager',
#  'Web Developer  Front End  CMS Development  12 Months',
#  'Virtualisation Customer Solutions Architect',
#  'VB6 SQL ASP developer',
#  'Support Workers',
#  'Snr Business Intelligence Developer  Retail  London  Perm',
#  'Technical SharePoint Administrator',
#  'Technical Sales Advisor',
#  'Cloud Hosted Services Sales Specialist',
#  'Junior Web Developer Role / HP',
#  'User Experience Designer  Mobile',
#  'Senior Risk Analyst  ****  London',
#  'Senior BI Architect/Datawarehouse Architect',
#  'MIS Lead',
#  'Web Developer with strong C Net and SQL skills',
#  'Head of Online Services',
#  'Web Developer (HTML, PHP, CSS, JQuery)',
#  'MS Dynamics NAV/Navision Developer, ****k****k, Yorkshire',
#  'Database Manager',
#  '3rd Line Support/Analyst Developer',
#  'SAP ABAB, BASIS Specialist',
#  'Business Analyst / Project Manager',
#  'SQL Database Administrator (DBA) SSRS Manchester',
#  'Team Lead (Java Web)  Entertainment  London',
#  'Datawarehouse Analyst  Oracle OBIA/OBIEE (Oracle BI, Business Intelli',
#  'Strategy Consultant (FTSE 100, Strategic Consulting background)',
#  'Senior Security Sales Information Security',
#  'Database Admin  High Wycombe  ****K  Great Benefits  IMAV',
#  'Saas Developer',
#  'Business Analyst Banking, UML, SQL Data analysis, (Credit Risk)',
#  'Unified Communications Solutions Architect MS Lync Cisco UC',
#  'Conversion Rate Optimisation Web Analyst',
#  'Software Engineer/Developer/Programmer, Net, Visual Studio, C++, VB,',
#  'Online Analyst',
#  'PHP Developer Web Applications',
#  'Field Sales Engineer  Sensors',
#  'Windows CE Developer',
#  'Group Sourcing Specialist (Procurement Manager)',
#  'Value Engineer ****  ****',
#  'SAP PS FICO Consultant',
#  'Customer Insight Data Analyst',
#  'SharePoint Lead Developer, London, ****k, Digital Design',
#  'C/C++ Software Engineer/Linux/Windows',
#  'Senior Web Designer',
#  'Project/Program Manager (Project Manager, PM, Project, Manager)',
#  'Senior Linux Systems Administrator  Leading Managed Hosting Provider',
#  'Technical Support Engineer  Mechanical Engineering',
#  'Automated Tester/ Technical Test Analyst',
#  'Lean Transformation Project Manager, Investment Bank, ****k',
#  'Web Designer  ECommerce  France',
#  'Multi Skilled Fitter',
#  'Data Warehouse Developer',
#  'Technical Design Authority, End User Computing',
#  'Cisco Network Analyst',
#  'Junior Front End Web Developer',
#  'Change and Release Analyst  South London/Kent/Surrey Borders',
#  'Net Developer  Permanant  Central London',
#  'Multiple Software Developer roles Leeds C,VBNet/VBnet',
#  'Network Security Shift Engineer',
#  'Supply Chain Manager  Procurement/Contracts',
#  'Java developer  Equities etrading FIX ****k',
#  'PHP/Magento developer (Magento, PHP, MySQL, HTML, CSS, Javascript)',
#  '1st/2nd Line Service Desk Analyst',
#  'Business Analyst  Supply Chain',
#  'Incident Manager',
#  'Infrastructure Engineer Bournemouth',
#  'Information Systems Manager',
#  'CNet Developer  C, ASPNet, SQL, WPF, WCF  URGENT',
#  'Senior Design Engineer',
#  'Excellent Graduate Opportunity  Junior PHP Developer',
#  'C Developer, Net, Huddersfield, Yorkshire, ****  benefits',
#  'Web Content (Digital Marketing) Executive',
#  'Senior IOS  Iphone Developer',
#  'Programmer/Software Developer',
#  'C ASPNET WEB DEVELOPER  LONDON',
#  'Technical Support Advisor',
#  'User Experience Developer',
#  'Embedded Engineer',
#  'Product Portfolio Manager',
#  'DataCentre Solution Architect Unified Communications, Networking',
#  'Quant Analyst  Modelling, Matlab, C',
#  'Electrical Engineer (PLC)',
#  'Payroll Manager',
#  'Non Functional Test Analyst/ Performance Tester (Loadrunner)',
#  'Dynamics AX Finance Consultant, London, c****k',
#  'Lead NET Developer, Senior NET Developer',
#  'Senior Web Developer  ASPNET, C, HTML',
#  'Senior Technical Engineer  NetApp  EMC  Cisco  VMware',
#  'Junior / Graduate Web Developer  C ASPNet, MVC  Urgent',
#  'Service Desk Analyst  Active Directory : 12 Weeks Contract  Lanarkshire',
#  'Senior Developer/Analyst  SQL Server SSAS, MDX, SSRS, SSIS',
#  'Technical Design Authority  Telecoms  Cisco  CCNP/ CCIP/ CCI',
#  'IT Apprentice with Club Systems International Ltd',
#  'Software / Systems Developer  C  ASPNET  MVC  SQL Server',
#  'Linux Systems Administrator (UNIX, MySQL, Apache)  London',
#  'Midlevel Java Developer',
#  'Graduate IT Sales Executive  ****k OTE  London',
#  'Java Developer x **** London (Digital Banking Project)',
#  'Service Delivery Manager / Service Manager',
#  'Graduate  Operations Support',
#  'Senior Electronic Design Engineer',
#  'C Developer Net **** WPF',
#  'Infrastructure Engineer / Network Support, to ****k, Newcastle',
#  'Java Developers x**** 6 month contracts, Central Manchester',
#  'MS Dynamics NAV Support Consultant, ****k, Shropshire, End user',
#  '2nd Line Desktop Support Analyst',
#  'Specialist Java Developer',
#  'SharePoint Consultant, West Midlands, Microsoft Gold Partner',
#  'Telephony Support Engineer  Banking',
#  'Junior and Senior Java Developer',
#  'Network Manager, Infrastructure, Server Support, Romford ****k',
#  'Embedded/Firmware Engineer  Embedded C/Device Drivers',
#  '**** x Principal Electronics Design Engineer South West ****',
#  'R****  Oracle Financial Consultant  London, ****K Fixed Term',
#  'Python Developer (Senior)  Django Frameworks',
#  'Java Software Engineer  ****K',
#  'PHP Developer, MVC, OOP, PHP, Web developer',
#  'Site Engineer  Teesside',
#  'Lead Tester / QA',
#  'Service Desk Advisor',
#  'Systems Analyst  Leeds',
#  'Ecommerce Systems Analyst',
#  'Business Objects Report Writer  Corporate Resources',
#  'Infrastructure Project Architect',
#  'Principal Technologist  Future Media',
#  'Tier **** / Tier **** Customer Support Engineer',
#  'Software Developer/Programmer  VBNet /VB6/SQL Server',
#  'Infrastructure Manager  Citrix, Wintel, App Packaging, SCCM, AppV',
#  'Web Designer  Birmingham, West Midlands  **** , ****',
#  'Microsoft Data Warehouse Developer  Slough',
#  'Systems Engineer  High Tech Finance Technology  London',
#  'Junior Software Tester  World Leader',
#  'Security Engineer Firewalls, DLP',
#  'Web Developer | Nottingham | ****K',
#  'Senior Developer (Force)',
#  'PMO Manager  Governance  Finance ****k',
#  "Trafficker/Ad Op's",
#  'Global FI / CO Delivery Manager',
#  'Development Manager,Java, Enterprise',
#  'Senior Service Desk Engineer',
#  'Product Manager  SaaS Software  London  ****k',
#  'Digital Media/ Internet online Business Analyst',
#  'SAP HR Consultant / American Legislation / Work from home ****K',
#  'Voice Recording Engineer  Nice, Cybertech',
#  'GIS Technician',
#  'QA Automation  Perl',
#  'Salesforce Business Analyst  Investment Banking  London  ********k',
#  'Support Assistant (Systems)',
#  'UNIX Analyst',
#  'Principal Database Programmer Home based, UK',
#  'WEB DEVELOPER',
#  'Lead Java Developer  Fixed Income Trade Processing',
#  'B****C Product Line Manager  Newbury  to GBP****K',
#  'SUPPORT DEVELOPER',
#  'IT Network Administrator',
#  'New Business Sales Executive',
#  'Storage NetApp and VMware Engineer  Herts  ****/****k',
#  'Software Support amp; Installations Engineer ndash; Leeds',
#  'Test Analyst  Agile  Java  XML  HTML  Cambridge',
#  'Graduate Application Support, Windsor',
#  'Technical PreSales Consultant VMware / IBM',
#  'Midlevel ASPNET Developer  Abingdon  ****/****',
#  'Senior Developer  PHP  Dynamic Digital Agency  Hampshire',
#  'Greenfield Java Web Application Programmer',
#  'Java Developer, Java, J****EE',
#  'Sales Manager  WMS / SCM / Logistics  UK wide  ****K OTE',
#  'Senior Software Engineer, Embedded, Linux, C, Manchester',
#  'Photocopier Engineer  Leicestershire',
#  'Electronics Engineer  VHDL  Cambridgeshire',
#  'Marketing Executive  Bradford',
#  'Data Centre Engineer / Infrastructure Support  Milton Keynes',
#  'BI Developer  Tech Track ****',
#  'NET Developer, ASPNET MVC, C, Umbraco, CMS  London',
#  'Business Analyst  Agile, Web, eCommerce, Scrum, TDD, BDD, UML',
#  'Component Technician  Aircraft manufacturing',
#  'Web Development Manager / Lead Java Developer',
#  'Linux Team Lead/ Systems Administrator',
#  'SaaS HRIS Consultants (Workday HCM)',
#  'Technical Consultant SCCM SCOM Active Direc',
#  'Java Developer  Agile  Milton Keynes',
#  'Information Security Analyst',
#  'Graduate analyst market research',
#  'SAP HR / SFSuccess Factors Managing/Principal Consultant',
#  'Senior C++ Front Office Developer  Financial Services  ****K',
#  'Project ManagerManufacturing/Engineering',
#  'Creative Designer / Creative UX Designer  (Online Gambling) – London',
#  'Software Consultant  Net Applications : Perm : Aberdeen  ****k',
#  'PHP/Zend developer (PHP/Zend/MySQL/MVC)',
#  'Sales & Marketing Assistant  Sussex',
#  'Head of Delivery',
#  'SQL DEVELOPER  BI',
#  'Field Support Engineer Microsoft Certified Poole ****k',
#  'Java EE Developer x **** Basingstoke Hampshire 6 months',
#  'London',
#  'Perl Developer Junior / Senior ****K  ****K',
#  'VBNET ASPNET',
#  'QlikView Consultant: Learn From The Best ',
#  'Business Analyst (Senior)  UK Leading Insurance Company',
#  'Automated QA Engineers  A World Leader in Creative Mobile Appl',
#  'Java Developer / Java Software Engineer',
#  'Implementation Analysts x****',
#  'Exchange/Migration/Messaging Expert',
#  'IT Technical Engineer',
#  'PHP SQL Developers',
#  'Windows 7 Support Analyst  London',
#  'NET  C/VBNET Graduate/Junior Developer',
#  'C ASPNET Developer  Altrincham',
#  'Mobile QA  London  Selenium, Cucumber, Eggplant, IOS,  Up to',
#  'Integration Developer',
#  'Head of Collections  North West  ****',
#  'Citrix 3rd Line Support Engineer Service Desk, CCitrix , Xenapp****xendesktop 5 Wokingham ****k****k',
#  'Hardware Engineer  VHDL/FPGA, signal processing, need security clearance, Guildford, to ****k  benefits',
#  'Senior Consultant SOFTWARE TESTING Industry Candidates Welcome',
#  'Project Engineer  IT',
#  'Junior PreSales Engineer  MPLS, VPLS, VoIP, WAN',
#  'WPF MVVM C Developer',
#  'IT Regulatory Compliance Analyst  Top Tech, ****k',
#  'Application support  asset management',
#  'Human Factors / Ergonomics Engineer',
#  'Cognos & ETL Consultant Bonus',
#  'Software QA / Test Engineer Agile, Automated, Digital Media',
#  'Contract DSV, NDSV and Drillers needed',
#  'C NET Web Developer (MVC, Nhibernate, SQL, Web Services)',
#  'Mobile Customer Support Engineer (1st/2nd line support)',
#  'Desktop Support Analyst, ****/HR',
#  'SENIOR NET DEVELOPER/ARCHITECT  C, ASPNET, MVC,WCF',
#  'Software Quality Engineer',
#  'Lead Web Developers',
#  'WinCE Tech Team Lead Level  WinCE / Device Drivers  Leeds',
#  'ASPnet Developer / Graduate',
#  'Application Developer (ASPNet/C)',
#  'Statistical Modelling Analyst  Manchester',
#  'Java / Scala Engineer  cutting edge social / comparison firm',
#  'Web Analyst  Web Analytics  Google Analytics  Permanent',
#  'SAP FI/CA Consultant ****K  Bonus',
#  'C / ASPNET Web Developer',
#  'MS SQL Developer  Hedge Fund',
#  'Senior business analyst  buy side, asset management',
#  'Oracle DBA  Leeds  ****K  ****K',
#  'JAVA Developer / Programmer',
#  'Ecommerce Web Developer',
#  'SEO Executive',
#  'MS Dynamics NAV Developer Gold Partner, ****K',
#  'NET Developer  Radio Station Group Camberley, Surrey',
#  'Software Developers (Junior and Senior)  Net, C, Agile & SQL',
#  'Business Analyst  Housing Mgt Sys',
#  'Senior Software Engineer  Java or C++',
#  'Developer (CNet, ASPNet) FX/MM',
#  'IT Trainer (Microsoft Products)',
#  'Java Developer (Spring, MVC, Hibernate) London',
#  'Data Warehouse Analyst',
#  'Senior Infrastructure Architect',
#  'Linux Administrator – Linux, Networks',
#  'Senior EDA Engineer',
#  'Street Lighting Electricians Urgently Required',
#  'Service Desk Administrator / 2nd Line Support',
#  'Senior Web Designer  Wakefield  ****k',
#  'UI Software Developer',
#  'Windows Support Engineer',
#  'Digital Account Manager  London',
#  'Microsoft SharePoint Developer',
#  'C ASPNET Web Application Developer  Shinfield, Reading',
#  'Head of Ecommerce/Technical Lead',
#  'Application Support  SQL / Echo**** / Education / Media Apps',
#  'Software Developer/Programmer & VBNet /VB6/SQL Server',
#  'Senior CRM Technical Analyst',
#  'Windows/SQL Engineer  High Tech Trading Software  London',
#  'Adams Analyst  Chassis',
#  'Java J****ee, Mobile Developers based in Glasgow **** , ****',
#  'Microsoft BI support consultant',
#  'Net Developer  C, ASPNET, SQL, MVC',
#  'Communications Officer  Digital and Social Media',
#  'ASPNET (C or VBNET) Web Developers X 2  Macclesfield',
#  'Project Manager / Lead Business Consultant',
#  'Contract Net Developer C / ASPNET **** / day',
#  'Oracle Database Architect',
#  'Norwegian Technical Support Agent in Dublin, Ireland',
#  'Chief Engineer  Electronic Warfare',
#  'Solutions Architect CCNP CCIP CCIE',
#  'Quedgeley  Optometrist',
#  'Antony / Software Engineer / ****K',
#  'Apprentice Marketing Executive',
#  'Business Analyst Lead Glasgow City Centre',
#  'Release Coordinator',
#  'Access Field Technician',
#  'SEO Executive  London',
#  'Demand Analyst / Financial Business Analyst / Infrastructure',
#  'Technical Project Manager Windows / Citrix',
#  'Salesforcecom Consultant',
#  'CRM Developer (Swansea)',
#  'Trading Systems Analyst / Application Support  Unix SQL  Finance',
#  'Service Desk Analyst  Banking, Windows, Microsoft, AD,VMWare',
#  'Mid Weight PHP Developer',
#  'Solution Architect  Leading Consultancy Firm  City of London  ****K',
#  'Industrial Data Communications Sales Specialist',
#  'Developer  C++, SQL, MFC, C  Online Gaming',
#  'Software Developer/Java/St Helens  Upto ****k  Bens',
#  'Principal Electrical Design Engineer',
#  'Management Consultant / Project Manager  Fluent German/French/English',
#  'Data Analyst  Insurance Company  TSQL, SQL Server, SSRS, Access, Ex',
#  'Senior Oracle Developer Team Lead  Reading',
#  'Unix Administrator',
#  'Project Manager  Infrastructure Solutions',
#  'Human Resources Advisor',
#  'Unix Linux Technical Specialist',
#  'Associate Quantity Surveyor',
#  'Network Implementation Engineer (Cisco or Juniper)',
#  'MI DEVELOPER/ BI DEVELOPER – SQL SERVER – SSIS  TWICKENHAM',
#  'Product Manager based Oxford technical role',
#  'Test and Validation Engineer',
#  'Inside Internal Sales  Enterprise Sales',
#  'Sage 200 Consultant  SOUTHEAST;LOCAL TRAVEL  ****K  Bonus',
#  'Software Developer Analyst Javascript Altrincham',
#  'PMO Manager  Business Change / Insurance',
#  'IT Sales Executive  Lanarkshire',
#  'Web Design and E Marketing',
#  'Data Analyst / Database Analyst SQL Server, ETL',
#  'Team Leader Instrumentation and Control',
#  'ASPNET Web Developer  (LightMid Weight)',
#  'C/C++ Developer, C, C++, Unix/Linux, Data, Greenfield, Software House,',
#  'ABERDEEN – PMO MANAGER in busy IT Department – STAFF ROLE',
#  'Senior Lead Server Engineer  London (VMware, Infrastructure)',
#  'Oracle BI OBIEE Consultant  OBIEE, ETL, Data Warehousing',
#  'Graduate / Junior NET Developer  Times Top 100 Employer',
#  'HEAD of USER EXPERIENCE  Digital',
#  'Storage Support Engineer (Security Cleared to SC)',
#  'Senior Electrical Design Engineer',
#  'C/C++ Software Engineer  Financial Software  London',
#  'Net Developer C, ASPNet, C++, WPF Developer',
#  'Graduate Application Support Analyst (Finance/Insurance)',
#  'Web Desinger / Web Developer ASPNET',
#  'Senior | Lead Server Engineer  London (VMware, Infrastructure)',
#  'Software Implementation Consultant (Maintenance Management, Local Auth)',
#  'Scorecard Developers  SAS  London  ****',
#  'Infrastructure Engineer / Solutions Designer',
#  'Digital Electronics Design Engineer (FPGA, DSP Firmware)',
#  'Sales Engineer  Hydraulics',
#  'QA Engineer  Site Auditor',
#  'User Interface Designer',
#  'PinPad / EPOS / ATM Tester',
#  'Technical Delivery Architect  ****k to ****k  UK Nationwide',
#  'Developer  ASPNet / VBNet / C / Web Services / CSS / HTML',
#  'French Tech Support from your Home in Ireland',
#  'Commodity Lead  Electronics',
#  'Oracle DBA / Database Administrator  RBI Global Media  SUTTON/SURREY',
#  'Junior Level PL/SQL Data Analyst, Database Admin',
#  'Solution Architect  Software/System Integration/TOGAF',
#  'Excel Developer',
#  'PHP Developer, London up to ****K, PHP/ API/ Cake/ Zend/ HTML5',
#  'B2B Sales Executive',
#  'C Web Developer/ASPNET/Sitecore',
#  'Cheltenham, Gloucestershire  Optometrist (Parttime 34 days)',
#  'Java/Grails Support',
#  'Android Developer / Mobile Developer',
#  'Cognos Consultant  Database Build, Reporting, Data Migration',
#  'PACS Support Engineer  Midlands  up to ****  car',
#  'Graduate Risk Analyst  Acquisition and Policy',
#  'NETWORK ANALYST  LAN/WAN/VLAN/VPN/WiFi/VOIP  RBI Media (FTSE100)',
#  'SaaS Project Manager  System Integrator  ****K****Kbonusbenefits',
#  'Test Analyst / Tester  Functional & Operational',
#  'Senior Software Engineer/Developer | Manchester | Up pound;****k',
#  'Service Desk Analyst / Application Support Analyst  imm start',
#  'Senior Net Developer / C / ASPNET',
#  'Principal Development Manager',
#  'C ASPNET software developers',
#  'Senior Tester / QA / Test Lead  Exeter  ****K',
#  'Java Developer, ****k  ****k, West London',
#  'QA Tester (Highly technical) Gain Finance experience in Camb',
#  'European Sales Account Manager',
#  'Implementation Mgr  Times **** Company  West London, ****K',
#  'Graduate/Junior NET Developer  Financial Services  Guildford',
#  'NET DEVELOPER  C, VBNET, ASPNET, INSURANCE',
#  'Junior / Graduate SQL Server Developer / DBA, Brighton',
#  'Resourcer / Delivery Consultant',
#  'Data Centre Pre Sales Consultant  EMC VNX  VNXe  VMware  CCDP',
#  'SQL Applications Support',
#  'SAP BPC Principle Consultant',
#  'Senior Software Engineer/ Developer (Displays, Real Time, Embed',
#  'Part Time Administrator',
#  'Senior Platform Engineer  End User Computing / Kent / ****k',
#  'SAP Financial Management Solution Director / Global Consultancy',
#  'NHS Reporting Consultant  ****k  ****k  15% Bonus',
#  'Java Developer (High Level  London)',
#  'Lead PHP Developer, PHP Development Manager',
#  'Aspnet DeveloperInterviews this week',
#  'Sharepoint Administration / Jnr Developer',
#  '2nd Line Support Analyst  ITIL',
#  'Data Administrator  knowledge/exp of Rims and Bloomberg  Leading Fin',
#  'Relations Manager (ICT Learning Programme)',
#  'Software Test Manager',
#  'Senior PR Consultant Associate Director to Director',
#  'Oracle/SQL DBA',
#  'Global Development Manager  SAP HR & Fi / Co',
#  'Training Officer  CAFM',
#  'Business Systems Manager  Social Housing Software, SQL',
#  'Junior  Senior VBNet/C Developers  Agile',
#  'Supplier Manager  SE London  3rd party',
#  'MI Analyst (Reporting Analyst)  Trainee',
#  'Android Developer  eMarkets and eCommerce  Berkshire  Up To',
#  'Tech Support Agent Job In Derry Learning Pool',
#  'Android App Developer, Cambridge, Salary ****k Neg DOE',
#  'Network Engineer  Permanent  Manchester  ****k',
#  'Network Technician West Sussex',
#  'SAP Security Authorisations Team Lead  London  up to ****k',
#  'SAP Technical Consultants (ABAP, Java, XML, Web Services)',
#  'Graduate Data Engineer / Linux Systems Engineer  BI Hadoop PHP',
#  'C Net Developers (WPF / WCF / LINQ)  Milton Keynes',
#  'Vendor Manager  ****K  London',
#  'Software Engineer / Embedded Software Engineer',
#  'Senior Software Developer C ASPNET APIs',
#  'Power Systems Technician  Communications Infrastructure',
#  'Software Engineer/Software Developer  C/GUI',
#  'Business Analysts, Bristol  Financial services  Fast growing company',
#  'Web designer/Web Developer',
#  'Staff Nurse Recovery  Main Theatres',
#  'C and C++ Senior Software Engineer',
#  'Java Developers  Financial Consulting Company London',
#  'UK Head of Sales',
#  'Junior Developer  Horsham',
#  'Support Operator',
#  'VP of Bioinformatics, IT Focus, Lead Role',
#  'SQL Data Analyst  Excel, SQL, top academics required, London, to ****k  bonus',
#  'Oracle DBA  Unix Administrator Solaris Banking',
#  'Junior Front End Web Developer (HTML, JQuery, Javascript)',
#  'We Developer',
#  'Software Developer | CNet, SQL Server',
#  'Linux Systems Administrator / Engineer',
#  'Global IT Manager  Prospect to Cash Solutions',
#  'Software Tester  Junior  Intermediate (C, C++)',
#  'Software Architect  Java',
#  'Microsoft Server Administrator',
#  'IT Engineer',
#  'Commercial Analyst (Metering/Utilities)',
#  'Wireless WLAN Ruckus Consultant, Lead and Build new division',
#  'C/WPF Developer',
#  'Global Senior Advertising Analyst  Entertainment Client',
#  '1st Line / 2nd Line Support',
#  'Video Streaming Network Engineer',
#  'NET Developer  Excellent conditions',
#  'Senior PHP / Magento Developer  Ambitious Ecommerce Company',
#  'Commercial Head of Data Products & Services',
#  'JavaScript Application Developer',
#  'Senior Global Business Analyst  London  ****k',
#  'IT Support Analyst  12 Month Fixed Term Contract',
#  'URGENT  IMPLEMENTATION CONSULTANT  WEALTH MGMT SOFTWARE VENDOR  LON',
#  'Senior Business Analyst  SC Clearable',
#  'Windows 7/SCCM Engineer',
#  'Application Support / Software Consultant  Urgent  IIS, SQL,',
#  'Software Engineer GNU/GCC Tools  Cambridgeshire',
#  'IT Systems Administrator  Linux',
#  'Dynamics AX Finance Consultant  North West  c****k',
#  'Project Manager  Contract/Durham',
#  'Web Systems Analyst',
#  'Dialogue Application Developer',
#  'Software Developer NET',
#  'Sage ERP X**** Consultant Home Based, NEW X**** Practice ****k',
#  'Informatics Manager',
#  'Unix/Linux Consultant',
#  'Solutions Analyst',
#  'ASPNET / C Developer  Birkenhead',
#  'Senior Systems Engineer',
#  'Senior Java Developer  Global Telco',
#  'Project Manager  Software Development',
#  'Cognos BI Consultant',
#  'Java Developer (Semantic Web)',
#  'Financial Application Support Consultant',
#  'Business Application Developer SQL / Crystal Reports / Microsoft',
#  'BI Solutions Architect  Bedfordshire',
#  'Data Analyst/Data Scientist',
#  'Continuous Improvement  Manufacturing/Industrial Engineer',
#  'Senior Business Analysts  Technical',
#  'Solution Developer  Manchester  ****k****K',
#  'Project Manager  Cardiff  ****k',
#  'Senior Project Manager – Senior PM – Solihull – up to ****k',
#  'Network Project Manager',
#  'Java Software Developer Finance J****EE JEE London ****K',
#  'Hardware Engineer  Digital',
#  'Senior Analyst Developer/s',
#  'IOS Developer ndash; Objective C / XCode/ PHP/ MySQL  pound;****K',
#  'Senior Infrastructure Engineer  Milton Keynes, Buckinghamshire',
#  'French Speaking Technical Support  Luton',
#  'Cognos & ETL Consultant Bonus ',
#  'Oracle Developer / Designer – Leyland, Lancashire  Circa ****K',
#  'Graduate/Trainee Software Developer  CNet  Leeds',
#  'Frontend Web Developer  Glasgow  ****mts',
#  'Cisco / Security Engineer',
#  'Release Manager (Documentum)',
#  'eCommerce Project Manager  London',
#  'Backoffice Supervisor',
#  'C Net Developer – TDD/ API / MVC / Net / C / Agile',
#  'Oracle Retail Consultant',
#  'Marketing Campaigns Analyst  SQL',
#  'Web Content Manager  Oxford',
#  'Applications Support Analyst  SQL Server',
#  'IT Engineer  2nd/3rd line',
#  'Senior SAP PP/MM and PP/APO Consultants',
#  'Systems Test Analyst',
#  'Business Analyst  Sharepoint  London  ****K',
#  'Solutions Architect  RealTime Applications',
#  'Consultant – Solution Design',
#  'Network Security Engineer',
#  'Technical Architect  TOGAF  ADM',
#  'C ASPNET Developer  Plymouth ****  ****',
#  'Open Source Software Development / Community Leader – R&D',
#  'UAT Test Analyst',
#  'Project Manager  South West London',
#  'FrontEnd Developer  Manchester',
#  'Test Manager; EPos; SAP',
#  'Release EngineerFinanceCheshire****kPackage',
#  'Senior Linux Kernel Developer',
#  'Senior Test Engineer  Royston, Herts',
#  'Application Support, (Electronic Trading, Windows) Essex',
#  'Application Support',
#  'Oracle Team Leader',
#  'ASPNET VBNET Web Application Developer',
#  'Technical Support Service Engineer',
#  'Business Analyst  Airline Operations',
#  'Automated Tester',
#  'Senior PHP Web Developer  Top SouthWest Digital Agency',
#  'Principle Server & Design Engineer',
#  'Application Support (Excel, Support Analyst, London)',
#  'Junior/ Graduate/ Support Developer (C, SQL) x****',
#  'Solutions Architect  Manchester',
#  'IT Infrastructure Project Manager  Eastleigh  ****k',
#  'Web Developer, C Developer,NET Developer, Software Developer',
#  'Senior Wordpress Web Designer',
#  'HTML Email Production ExecutiveMarketing and Technology Company',
#  'Lead Business Analyst',
#  'C ASPNET SQL **** Developer/Programmer PropTrading',
#  'Lead Solution Architect, Permanent, London, Investment Bank',
#  'Customer Service Advisor',
#  'Toolmaker  plastics injection moulding',
#  'Java Developer  AI Startup',
#  'Business Process / Business Analyst',
#  'IT Sales Consultant – Basingstoke  ****k****k  OTE',
#  'Net Software Developer',
#  'Junior Business Analyst (Financial, IT, Equities)',
#  'Senior Software Engineer  Graphics Expert',
#  'Apps Support Engineer',
#  'Mid / Senior Software Developer Shropshire ****k',
#  'iOS Developer  3 month contract  Central London',
#  'Service Desk & Operations Assistant',
#  'Solutions Architect  Surrey  ****  ****  Benefits',
#  'IT Security Analyst / ISO 2701 / ISO 27002',
#  'CRM sales specialist Higher/Further Education ****k  Car OTE',
#  'MS Dynamics CRM Presales Specialist, c****k, West Midlands',
#  'Field Engineer (EPOS/Server)',
#  'Analytics Manager  London ****',
#  'Customer Transformation Consultants (CRM, Contact Centre, UserCentric',
#  'Native iOS developer : iphone / ipad / objectivec / cocoa',
#  'ICT Teacher required ASAP',
#  'Lead UI Front End Developer  (CSS, HTML, JavaScript, Digital)',
#  'Software Developer C NET',
#  'Junior Embedded Linux Engineer  Near Guildford  ****',
#  'Collateral Business Analyst',
#  'Junior BI Developer / Data Analyst (Business Intelligence)',
#  'ASPNet MVC Developer  Lead/Architect',
#  'Front End Developer  Brighton',
#  '2nd Line Analyst',
#  'Software Developer Southampton, Hampshire  ****K****K',
#  'ETL Development Team Leader  Burton on Trent',
#  'Senior Digital Account Manager',
#  'Senior Java Developer  J****EE',
#  'Robotics C++ Software Engineer  South West',
#  'Senior Java Developer (J****EE/Web/Spring) Manchester City Centre',
#  'MS Dynamics NAV Technical BA, ****k****k, Greater Manchester',
#  'Business Analyst, Loyalty Marketing, City, to ****K',
#  'SharePoint Engineer',
#  'Project Manager  Polish Speaker',
#  '2nd line IT Support Technician  tempperm',
#  'Developer ****k',
#  'BI Application Developer',
#  'Apple Mac/PC help desk support',
#  'Graduate Developer Jan 2013',
#  'Senior Collections Strategy Analysts  Chester',
#  'Development Manager / VP Engineering  Startup',
#  'Developer/Product Consultant',
#  'Senior Application C++ and C Developers (Petrochemical sector)',
#  'Junior Net Developer **** , **** pa',
#  'NET Web Developer (C / ASPNET)',
#  'Senior Ruby on Rails Developer',
#  'C Job Opening C/AspNet Developer',
#  'Software Developer  C, NET, SQL Server, eCommerce, ntier, O',
#  'QA Engineer  Automation Engineer  Content Release',
#  'Oracle HR/Payroll Functional Consultant',
#  '2nd/3rd Line Systems Support Engineer',
#  'LINUX ADMINISTRATOR ( REDHAT ) / LINUX ENGINEER',
#  'Project Manager (Software development)',
#  'Senior Quality Assurance Engineer  MTM, Coded UI, Selenium, BD',
#  'Tester ndash; Web Testing / Test Analyst / Manual ndash; Altrincha',
#  'Devops Engineer  London  ****  ****',
#  'Technical QA Engineer',
#  'Network Engineer Hedge Fund',
#  'Senior Developers',
#  'Senior System Engineer / Senior System Administrator',
#  'IT Software Project Manager',
#  'Business Change Financial Services Project Manager',
#  'Software Support Lead',
#  'Mechanical Design Engineer  R&D Product Design  Oxfordshire',
#  'C WPF Software Development Manager Hands on',
#  'Email Migration Analyst Office ****/MS Exchange',
#  'Senior Planner/Planning Manager',
#  'Ruby on Rails Software Engineer London,',
#  'Implementation Consultant  SQL / Virtual Technologies / Softwa',
#  'ASPNET / C / SQL Developer',
#  'Equities/Futures Algorithmic Trading Support Analyst  Leading Tier ****',
#  'Project manager  Business Intelligence',
#  'SQL Application Support Analysts  Permanent',
#  'Junior Support Engineer',
#  'INSTALLATION ENGINEER',
#  'Configuration Manager / Config Manager  Embedded Systems & GIT',
#  'AX Systems Analyst, ****k, End User, Cardiff',
#  'Service Desk Analyst  Citrix, Xenapp',
#  'Java Developer/Engineer,JSP,Servlets,XML,Ajax,****k,Berkshire',
#  'Senior Project Manager  global projects  news technology',
#  'NET DeveloperDublin City Centre',
#  'Head of UX/UI',
#  'Web FrontEnd Developer / Designer',
#  '3rd Line Server Support Linux Consultant Cambridge ****',
#  'Systems Manager  Billing & CRM',
#  'Security Operations Centre Analyst',
#  'Instructional Designer',
#  'PHP / Zend Architect London, Python, MySQL',
#  'Apprentice Quality Liaison Officer',
#  'NET Webforms Developer',
#  'Java / Scala / Ruby Dynamic Developer',
#  'Production Operative',
#  'Senior Business Change Consultant  Oracle / Microsoft Change Programm',
#  'Web Developer Software House  Manchester  C AspNET, Episerver',
#  'Digital Marketing Specialist  6 month contract  Maidenhead',
#  'Automation Engineer',
#  'RF/Microwave Design Engineer  London',
#  'Network & Security Engineer CCIE/CCNP/CCNA/MCSE/MCSA/MCP/MCITP',
#  'Sales Executive Business Analytics Vendor ****k  OTE',
#  'Senior Systems Development Engineer',
#  'French speaking Network Support Engineer/',
#  'Compliance Solution Specialist',
#  'Web Developer, C, ASPNET, HTML, CSS, Windows Server, SQL Server',
#  'SQL Specialist, SSIS, SSRS, Bradford',
#  'PerformanceTest Analyst  Investment Banking',
#  'SQL DBA (Production & DBA)  Chester  Software House',
#  'UI Dev HTML, CSS, Javascript',
#  'SAP SCM (Supply Chain)  Lead Business Analyst',
#  'IT Reseller Account Manager ****k****K  OTE',
#  'VHDL Development Team Lead',
#  'IT Security Operations  PCIDSS',
#  'Sales Lead  Middleware / SOA',
#  'Senior Network Engineer Aberdeen **** ****  Benefits',
#  'Java Developer  Fife  ****K  ****K',
#  'Technical Consultant Unidata',
#  'Data Analyst, to ****k',
#  'Zend, MVC, PHP Developer (HTML5, JavaScript, RealTime)',
#  'Telecom Broadband Sales Consultant  Immediate Start',
#  'Saas Functional Consultant  Global IT Services  Manchester  ****K ',
#  'Design and Build Engineer',
#  'CRM Systems Administrator',
#  'Account Director, Digital Media, Cambs  ****k****k',
#  'Data Centre Engineer (Tivoli) | Notts ****K  Bonus',
#  'SQL Server Database Administrator/Duluth/****K',
#  'Senior Java Back End developer Java ,OOA , JSP , Gaming ****k London',
#  'Technical Field Sales Executive / Sales Engineer (OTE ****K)',
#  'Project Delivery Manager  ****k  EC',
#  'Embedded Systems Engineer  Electronics, Embedded, C/C++ Assembelr, top academic qualifications required, Cambridge, to ****k  benefits',
#  'BUSINESS DEVELOPMENT DIRECTOR',
#  'Creative Design Specialist / Web Designer',
#  'Technical Consultant, C, Cambridge, ****K****K',
#  'Chinese (Mandarin) speakingSales / Marketing Manager',
#  'Systems Engineer  Pre Sales  (Security / webfiltering / firewall)',
#  'Programme Manager  Asset Management, Strategy',
#  'SAP Supply Chain Management (SCM) Consultant',
#  'Project Cost Estimator',
#  '1st Line Support Technician',
#  'Developer  Surrey / MVC / C / SQL / AGILE',
#  'Technical Support Engineer  Systems Administrator  Backups  Windows',
#  'The Best Web Developer Job Ever  (Digital Agency)  Brighton',
#  'Business Analyst (UI) Macclesfield, Cheshire North West',
#  'Net C Developer',
#  'IT Support Engineer / Junior Developer',
#  'Front End UI Web Developer HTML5 CSS Javascript',
#  'Software Developer  Java  mobile / cloud startup  London',
#  'Frontend Website Develope  London',
#  'ICT Support Officer (AutoCAD Project)',
#  'ASPNet Support Developer, Croydon, ****K',
#  'Software Support Assistant  IT Support / Software Support',
#  'Mobile Web App Developer  php, Lamp, Backbone, MySQL',
#  'Service / Operations Manager (Healthcare)',
#  'Technical Business Analyst  BI & SAS  Bristol',
#  'Senior C NET Developer  (Programmer, Web, MVC)  Brighton, East Sus',
#  'Infrastructure Designer/Senior 3rd line  Infrastructure Solutions  A',
#  'ASPNET MVC Developer  Oxford  **** / ****',
#  'Customer Service Support Analyst  Leicester ****k',
#  'CCTV Security Engineer/Installer',
#  'Java eCommerce (ATG or Hybris) Consultant/s – UKwide',
#  'NET Developer  VBNET / ASPNET',
#  '1st Line IT Support/IT Helpdesk Support Technician Warrington',
#  'Oracle Senior Associate',
#  'Risk BA s  Tier One Investment Bank',
#  'Application Support Engineer – Sharepoint, Sharepoint 2010, Windows',
#  'Navision Developer ****k Yorkshire Well known Retail End',
#  'Helpdesk/Call Centre/Customer Service/Junior IT/1st Line',
#  'Multiple Software Developer roles Newcastle C,VBNet/VB',
#  'Technology / Business Consultant',
#  'ASPNET MVC Developer  Manchester  ****',
#  'Unix Solution Architect  Equities  Banking  London',
#  'Portfolio Manager  Rickmansworth, Hertfordshire',
#  'Database Administrator (DBA) / Data Manager  Oracle / SQL / E',
#  'Website Technical Support Agent  HTML/CSS, JavaScript SQL skills',
#  'Lead CCIE Consultant Gold Partner Finance',
#  'Desktop Engineer Mac OS DHCP Windows 7 SQL Admin Urgent',
#  'CNet Data Developer (Team Lead)',
#  'Senior Information Security Engineer',
#  'Tech Consultant  C++ / Net etc ****k Coventry',
#  'Senior Technical Java Consultant  Permanent  Essex  Up to ****k',
#  'Central Operations Group (COG) Controller',
#  'PHP Developer  PHP, MySQL, MVC, Jquery',
#  'Qt Developer',
#  'SQL Business Intelligence Team Lead  MS BI Lead  ****k',
#  'C++ Software Developer / C++ Software Engineer',
#  'Performance Test Consultant  London  HP  Performance ****/****k',
#  'Printer Engineer Reading  ****k to ****k  Benefits  HP',
#  'Head of Release Manager',
#  'Mobile applications Developer',
#  'Data Migration Consultant  SQL Server / C',
#  'Senior MI Developer',
#  'Developer (Linux / Python) | Coventry | Up to ****K',
#  'Project Manager (Change Communication)',
#  'Head Of SEO',
#  'Online Marketing Executive  Spanish Speaking',
#  'Senior Front End Web Designer, Liverpool',
#  'VB Developer  Senior / VB / SQL  Watford  ****k',
#  'Junior Javascript Developer/Graduate Javascript Developer',
#  'Deployment and Support Engineer, Cisco / MS Lync, SRT, SBA, SCCM',
#  'Unix Team LeaderGlobal BankCheshire****K',
#  'Security Architect',
#  'SalesForce Developer  Creative Agency  Central London',
#  'Sage 200, Sage 50 Implementation and Technical Consultant',
#  'Lead/Senior Data Manager',
#  'HR Service Delivery Analytics Manager  ****K',
#  'Head of MIS and ICT  Further Education (FE)  North West Perm',
#  'ICT Programme Manager',
#  'Client Support Analyst',
#  'Web Designer Manchester  ****KBens',
#  'Sharepoint Developer/Technical Lead/Senior Sharepoint Programmer',
#  'Associate Director/Director Designate (Structural)',
#  'JUNIOR WEB DEVELOPER  exp of C, SQL and Javascript/JQuery Library',
#  'Software Engineer C++, C or Java  Carlisle',
#  'NET Developer  Financial Services  Stockport  ****K',
#  'Network Engineer (Juniper)',
#  'Junior Application Support',
#  'Senior Net Web Developer  Nottingham (Up to **** , ****  Benefits)',
#  'Head of Client Services',
#  'C Developer X **** C NET SQL Macclesfield, Cheshire',
#  'Systems Administrator Jobs In Scotland',
#  'Front End Developer ( Web Java JavaScript HTML )',
#  'WEB DEVELOPER  RUBY ON RAILS  RUBY  DEVOPS  CLOUD',
#  'Tester / QA Test Lead  Startup',
#  'LAMP Developer  PHP, Linux',
#  'PMO  Banking  Edinburgh  ****/day',
#  'Test Consultant  Automation  QTP, QC, VBS/VBA  London ****',
#  'C and ASPNET Web Application Developer',
#  'Information Governance Manager',
#  'SEO Engineer / Search Engine Optimisation',
#  'Sponsorship Sales Manager',
#  'Internal Recruitment Manager',
#  'Build Engineer/DevOps  Microsoft  Tech Leader',
#  'PHP Developer  OO PHP / Zend / Agile / GIT / RESTful',
#  'Mobile Automation Developer',
#  '****  ASPNET / C Developers  West End  ****k',
#  'Electronics Test Engineer (Analogue/Digital & Test)',
#  'SPSS Data/Marketing Analyst London ****',
#  'BI Developer  SQL Server, SSRS  Milton Keynes  To ****k',
#  'Software Developer Graduates 2012  Read this now',
#  'QLIKVIEW DEVELOPER  PERMANENT  ****k',
#  'Senior Network Engineer CCNP CHECKPOINT, to ****K Middlesex',
#  'Commercial Management Principal  IT',
#  'Business Systems Manager (VBA and Access Support) Bristol',
#  'Front End Developer c****k Hertfordshire',
#  'Compliance Analyst',
#  'Senior Registration Authority Consultant',
#  'FEA Project Manager Swansea  ****k to ****k  Benefits',
#  'Oracle Payroll Support Consultant  Manchester',
#  'SAP PI Integration Support Consultant',
#  'UAC Analyst',
#  'Windows Systems Administrator  Server **** SMTP, Exchange ****',
#  'Excel/VBA quant developer  Rates Derivatives trading C,C++',
#  'Electronic test Engineer/ Diagnostic Technician',
#  'Solutions Architect  Innovation  Banking',
#  'Graduate NET Support Developer',
#  'Server Engineer / IT Support (Microsoft, Citrix)',
#  'Software tester / QA',
#  'SharePoint Developer (****SQL)',
#  'Java Developer  Oracle/PL/SQL/XML/JUnit/Agile',
#  'Team Lead/ Senior Developer(Java)x****',
#  'Lotus Notes Administrator',
#  'Sage 200 Support Consultant for a great team',
#  'Embedded Software Engineers',
#  'Presales Consultant  Dynamics NAV, Birmingham',
#  'CNet Developers X**** Perm',
#  'Senior UI Development Manager – Salary up to ****',
#  'Risk Manager, IT/IS Security  Midlands',
#  'Dynamics CRM System Tester',
#  'South Yorkshire – Java Developer – 3 Months Contract',
#  'Senior SQL Developer',
#  'QA Manager (Pharma/LifeSci)',
#  'UI Developer | C | ASPNet | Reading',
#  'Senior Technical Architect  mobile applications',
#  'Software Testers  QA (KN/****)  New positions',
#  'Project Manager  Technical  Infrastructure  Telephony',
#  'VBNetASPNet Developer / Contract / Phambra ****pd',
#  'Dynamics NAV / Navision Presales Consultant, ****k plus bonus',
#  'Interface Developer  NMA Top 100 Digital Agency',
#  'Solutions Architect  Software  ASPNET, CNET , SQL',
#  'Release/Configuration Manager  Net Software House',
#  'SQL Developer/Team Lead',
#  'Web Developer  C, Sharepoint  City, London',
#  'Database Campaign Executive (St Albans  Osterley/Perm  Cont)',
#  'Web Developer (PHP)',
#  'Business Applications and Information Analyst  Basingstoke, Hampshire',
#  'Predictive Modelling Analyst  SAS  Manchester',
#  'Pension Software Implementation Consultant/Software/SQL',
#  '2nd Line Helpdesk Technician Windows / Lotus Notes / Citrix',
#  'CRM Solutions Architect',
#  'AX Solutions Architect',
#  'Web Developer  PHP, MySQL, HTML, CSS',
#  'Junior Web Support',
#  'Controls Engineer  Automotive',
#  'Server Manager, IT Systems Operations Manager, Systems Manager',
#  'CNC Miller & CNC Turner',
#  'Graduate IT Consultant / Junior Project Manager, to ****k',
#  '1st Line IT SUPPORT ENGINEER',
#  '1st Line Technical Support Technician',
#  'Head of Technical Alliances',
#  'Network Technical Specialist',
#  'Service Transition Manager  Financial Services',
#  'Junior Evaluator',
#  'Field Service Engineer (Epos)  Poole / Dorset',
#  'Automated Tester Engineer, QTP, Agile, aspNET',
#  'Lead Developer  C/Net/SQL, Leeds Yorkshire',
#  'Future Leaders Development Programme  Technology',
#  'ASPNET Web Application Developers  Cambridge, Cambridgeshire',
#  'PHP Developer / Web Developer (PHP, MySQL, Javascript)  Bristol',
#  'Systems Architect, Systems Analyst, to ****K, Surrey',
#  'Lead Project Engineers & Project Engineers',
#  'Senior Project Manager ETRM/CTRM ****  London',
#  'UX/UI Designer',
#  'Junior/Graduate Application SupportLondon Banking',
#  'Senior Web Developer (Clientside)',
#  'Senior Systems Analyst (Database/SQL/Develop) London',
#  'PMO Lead  Project Office Lead',
#  'L**** Solaris Administrator in Finland',
#  'Lead Data Modeller  Data Modelling, Data Architecture',
#  'Sales Manager up to ****k  Bonus',
#  'Network Incident Manager',
#  'Verification Engineer (systemVerilog, Specman e, VHDL, Verilog',
#  'Online Marketing Exec, UK Nich , London, ****K',
#  'Account Manager (IT Sales)',
#  'Report Writer/Developer',
#  'Senior Developer Plymouth ****',
#  'Infrastructure Service Manager / Service Manager',
#  'Kalido MDM DIW Architect  BELGIUM',
#  'Project Manager / Lead Developer (Web Applications)',
#  'IT Systems Manager (Urgent)',
#  'MF Direct Mail  Apprentice Developer  Manchester',
#  'Avaya/Verint Service Delivery Manager central England, home based',
#  'Web Developer  PHP  ****k  Guildford',
#  'Senior Network Engineer  Cisco, Juniper, CCNP',
#  'Operations Information Analyst(Business Objects)',
#  'B2B Sales Executive  Basingstoke  ****k to ****k  OTE  Bens',
#  'Head of Business Analysis, ****k ****k  car  bonus  bens',
#  'Solution Architect  Delivery Validation',
#  'Senior PHP Developer  Back End',
#  'Greenfield, C, WPF, WCF Developer  Front Office trading App',
#  'Web officer',
#  'Release Engineer  London',
#  'Network Manager  NOC, LAN/WAN, TCPIP, DHCP, Switches',
#  'IT Account Manager – Software / Hardware',
#  'Senior/Lead QA Automation Engineer  eCommerce  London',
#  'Senior Project Manager  Barnwood',
#  'WordPress Web Developer',
#  'Head of IT Professional Services',
#  'Seeking IT GRADS  Junior Developers',
#  'Information Technology Security Officer  Finance Resources',
#  'UX Designer / Researcher  French / German speakers',
#  'IT TEST ENGINEER',
#  'Senior SAS Analyst  Telco  ****  ****K  SAS / SQL / CRM',
#  'Application Support  Excel / Access HR Applications',
#  'C Developer  Retail  (HTML, MVC, SQL, WPF)  ****k  ****k',
#  'Senior Web Developer (HTML, CSS, Javascript)',
#  'PHP Developer  Fife  ****K  ****K',
#  'Web Analyst Programmer',
#  'SQL Reports Developer',
#  'IT Helpdesk / Desktop Support Analyst  Fixed Late Shift, US Law Firm',
#  'C Winforms Developer C/RIA/WCF ****k',
#  "C Developer  Europe's Largest Radio Station Group  London",
#  'Senior Java Developer  Groovy / Grails  Oxfordshire  ****k',
#  'Telemarketing Assistant  Shirley',
#  'Software Developers (Cloud/Agile)',
#  'Virgin Media Head End Install Engineer',
#  'Data Centre Services Capacity and Availabilty Manager',
#  'Linux Technical Support  twentyfour/seven',
#  'Dynamics NAV Technical PreSales ****k Oxfordshire/Home Based',
#  'Product Manager  Collateral Management expert',
#  'Wintel System Administrator',
#  'IT Analyst',
#  'Graduate/Junior System on Chip Software Simulation Engineer',
#  'SAP Functional Consultants',
#  'VBNet SQl Server developer role, central Glasgow',
#  'IT Project Manager (Agile, Waterfall)',
#  'DATABASE ADMINISTRATOR',
#  'Desktop Support Engineer',
#  'UI DesignerUI DesignerUI DesignUI Design',
#  'Java Developer  Java, NEW STARTUP, Facebook, Twitter',
#  'Contract Business Analyst  West Mids  6 Months ',
#  'Production Support, Application Support, Front Office Support,',
#  'Major Incident Manager / Problem Manager Leader',
#  'Manufacturing Operations Manager (Heavy Engineering)',
#  'ASPNet / VBNet Developer',
#  'SQL Server Business Intelligence Developer',
#  'Cisco Network Engineer | Wireless & Network Security',
#  'EAI EDI GENTRAN CONSULTANT',
#  '2nd Line Support / Law Firm  Birmingham',
#  'Business Inteligence Architect',
#  'UI Product Designers x****  HTML, CSS',
#  'Senior Java Developer, Stirling',
#  'Application Support / IT Support',
#  'Senior EMC Data Storage Specialist',
#  'Software Engineer, Embedded , C, C',
#  'Senior Developer  Digital Asset Management specialist (DAM)  NET/SQ',
#  'Lead Telco BI Consultant : London : Salary ****k Exc bonus',
#  'Regional Coordinator/Service Delivery/IT Manager  Europe',
#  'TrakCare Support Analyst',
#  'Automation Test Analyst / Test Consultant /Newcastle/****pd',
#  'Web Developer (Clientside / Frontend)',
#  'Senior Application Packager',
#  'Senior IT Field Engineer  Basildon, Essex with extensive travel',
#  'Senior Systems Analyst',
#  'SQL Database Administrator (DBA)  London',
#  'Front End Web Developer x****',
#  'Technical Architect (VMware, Citrix, Microsoft), London, Essex',
#  'Embedded Software Engineer  UK Security Cleared',
#  'CASPNET SENIOR DEVELOPER  AGILE',
#  'Systems Engineer, Oil & Gas, Aberdeen, UK',
#  'Senior Software Developer VBNET, HTML, CSS, MSSQL  **** , ****',
#  'German Speaking Marketing Executive',
#  'Storage and Backup Engineer/Systems Engineer/SAN/Hitachi SAN',
#  'Document Analyst',
#  'Controls Design Engineer',
#  ...}

# %%
# Label annotation: Isolate job descriptions that match the chosen resume categories.

network_administrator = []
software_developer = []
database_administrator = []
project_manager = []
systems_administrator = []
security_analyst = []

for d in list(df_descriptions_IT.Title):
    job_position = d.lower()
    if 'network' in job_position and 'engineer' not in job_position and 'architect' not in job_position:
        network_administrator.append(d)
        continue
        
    if ('security' in job_position or 'cyber' in job_position) and ('engineer' not in job_position and 'developer' not in job_position):
        security_analyst.append(d)
        continue    
        
    if 'software' in job_position and 'developer' in job_position:
        software_developer.append(d)
        continue
        
    if ('database' in job_position or 'directory' in job_position or 'dba' in job_position) \
    and ('engineer' not in job_position and 'developer' not in job_position and 'analyst' not in job_position):
        database_administrator.append(d)
        continue
        
    if 'project' in job_position and 'manager' in job_position:
        project_manager.append(d)
        continue
        
    if 'systems' in job_position and \
        ('administrator' in job_position or 'manager' in job_position or 'director' in job_position or 'officer' in job_position):
        systems_administrator.append(d)
        continue


print(f'''Network Administrator: {len(network_administrator)}
Software Developer: {len(software_developer)},
Database Administrator: {len(database_administrator)},
Project Manager: {len(project_manager)},
Systems Administrator: {len(systems_administrator)},
Security Analyst: {len(security_analyst)}''')
# Out:
# Network Administrator: 494
# Software Developer: 1499,
# Database Administrator: 688,
# Project Manager: 1425,
# Systems Administrator: 530,
# Security Analyst: 453

# %%
# Create a dataframe with the isolated job descriptions above, including labels.

df_network = df_descriptions_IT[df_descriptions_IT.Title.isin(network_administrator)].reset_index(drop=True)[['FullDescription']]
df_network['Label'] = 'Network_Administrator' 

df_software = df_descriptions_IT[df_descriptions_IT.Title.isin(software_developer)].reset_index(drop=True)[['FullDescription']]
df_software['Label'] = 'Software_Developer' 

df_database = df_descriptions_IT[df_descriptions_IT.Title.isin(database_administrator)].reset_index(drop=True)[['FullDescription']]
df_database['Label'] = 'Database_Administrator' 

df_project = df_descriptions_IT[df_descriptions_IT.Title.isin(project_manager)].reset_index(drop=True)[['FullDescription']]
df_project['Label'] = 'Project_manager' 

df_systems = df_descriptions_IT[df_descriptions_IT.Title.isin(systems_administrator)].reset_index(drop=True)[['FullDescription']]
df_systems['Label'] = 'Systems_Administrator' 

df_security = df_descriptions_IT[df_descriptions_IT.Title.isin(security_analyst)].reset_index(drop=True)[['FullDescription']]
df_security['Label'] = 'Security_Analyst' 

df_descriptions_final = df_network.append([df_software, df_database, df_project, df_systems, df_security])
df_descriptions_final.reset_index(drop = True, inplace = True)
df_descriptions_final
# Out:
#                                         FullDescription                  Label
# 0     Job Title: Senior Support/Network Analyst Loca...  Network_Administrator
# 1     Our client is a Global organisation providing ...  Network_Administrator
# 2     Job Title: IT Administrator Customer Support, ...  Network_Administrator
# 3     Senior Account Manager (Oil and Gas sector sal...  Network_Administrator
# 4     Altran are currently recruiting for a Telecoms...  Network_Administrator
# ...                                                 ...                    ...
# 5084  IT Account Director  London / Hampshire, UK  A...       Security_Analyst
# 5085  Presales Consultant  Security/Encryption; Lond...       Security_Analyst
# 5086  IT Security Team Leader  Cambridge, UK  An exc...       Security_Analyst
# 5087  Product Security Consultant  London, UK  My cl...       Security_Analyst
# 5088  IT Security Analyst  CISM, CISA, CISSP, ISO270...       Security_Analyst
#
# [5089 rows x 2 columns]

# %%
df_descriptions_final.Label.value_counts()
# Out:
# Software_Developer        1499
# Project_manager           1425
# Database_Administrator     688
# Systems_Administrator      530
# Network_Administrator      494
# Security_Analyst           453
# Name: Label, dtype: int64

# %%
# Export preprocessed dataframes.

df_resume_final.to_csv('Resumes_final.csv', index = False)  
df_descriptions_final.to_csv('Descriptions_final.csv', index = False)

# %% [markdown]
# ## 2.2.2. Cleaning

# %%
# Load preformatted dataframes (after preprocessing).

df_resume = pd.read_csv('Resumes_final.csv') 
df_descriptions = pd.read_csv('Descriptions_final.csv')

# %% [markdown]
# ## Resumes - Cleaning

# %% [markdown]
# Several charactersitics are important for determining whether an applicant matches a job description.
# We do not want to remove information from the documents that could be essential.
#
# Important elements:
#
# * Nationality and work permit;
# * Specific technical abilities (e.g. proficiency in certain languages or applications/computer programs);
# * Experience gained through previous roles;
# * Soft skills (e.g. team-player, leader, organized, approachable, professional, self-motivated, excellent written communication ...);
# * Highest academic achievement (e.g. high-school, master degree, PhD, ..);
# * For junior positions: Grades and extracurricular activities.
#
#
# #### Steps
#
# 1. Remove job description at the beginning;
# 2. Remove punctuation;
# 3. Convert number words to numeric form (for homogeneity) and then remove all digits;
# 4. Remove stopwords;
#     - Remove words in extended nltk stopwords set
#     - Remove words with length $<= 2$
# 5. Remove months;
# 6. Remove common geolocations;
# 7. Lemmatize;
# 8. Join collocations.

# %% [markdown]
# ## 1. Remove job description at the beginning
#
# In the beginning of each resume, there is a short part that states the specific job that the candidate applied for. Inspecting the data, we observe, that oftentimes this *title* gets repeated three times. For example:
#
#    * ```'Database Administrator <span class="hl">Database</span> <span class="hl">Administrator</span> Database Administrator - ```<br>
# <br>
#    * ```'Oracle Database Administrator Oracle <span class="hl">Database</span> <span class="hl">Administrator</span> Oracle Database Administrator -```<br>
# <br>
#    * ```'Amazon Redshift Administrator and ETL Developer, Business Intelligence Amazon Redshift <span class="hl">Administrator</span> and ETL Developer, Business Intelligence ETL Developer and Database Administrator Plantation,```<br>
# <br>
#    * ```'Scrum Master Scrum Master Scrum Master ```<br>
# <br>
#    * ```'Lead Database Administrator/Developer Lead <span class="hl">Database</span> <span class="hl">Administrator</span>/Developer Lead Database Administrator/Developer -```
#
# There seems to be no straightforward way to solve this, as the format of the title changes with every resume. Nontheless, the following method seems to perform well:
# 1. Remove all html header-tags, such as ```<span class="hl">```  and ```</span>```;
# 2. Inspect if a resume starts with a recurrent pattern, and if so, remove all repetitions of it.

# %%
# Transform all applications into lower case (and store the output in a new column).

df_resume['Resume_cleaned'] = df_resume['Resume'].str.lower()

# Remove html tags.

df_resume['Resume_cleaned'] = df_resume['Resume_cleaned'].str.\
    replace("""(<span)|(class="hl">)|(</span>)""", '' , regex = True)

# Inspect output.

df_resume['Resume_cleaned'][0][:200]
# Out:
# 'database administrator  database  administrator database administrator - family private care llc lawrenceville, ga a self-motivated production sql server database administrator who possesses strong an'

# %%
# Remove titles corresponding to recurrent pattern.

def remove_pattern(x):
    l = x.split()
    
    for i in range(1,21): # Job titles can get as long as 20 words. 
        
        if (l[:i] == l[i:2*i]) & (l[i:2*i] == l[2*i:3*i]): l = " ".join(l[3*i:])
        if (l[:i] == l[i:2*i]) & (l[i:2*i] != l[2*i:3*i]): l = " ".join(l[2*i:])
    
    if type(l) == list: 
        l = " ".join(l)
    
    return l

df_resume['Resume_cleaned'] = df_resume['Resume_cleaned'].apply(remove_pattern)

# Inspect output.

df_resume['Resume_cleaned'][0][:200]
# Out:
# '- family private care llc lawrenceville, ga a self-motivated production sql server database administrator who possesses strong analytical and problem solving skills. my experience includes sql server '

# %% [markdown]
# ## 2. Remove punctuation and URLs

# %%
# Remove URLs using RegEx.

website_re = "(http|ftp|https):\/\/([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:\/~+#-]*[\w@?^=%&\/~+#-])"

def remove_website(x):
    return re.sub(website_re, '', x)

df_resume['Resume_cleaned'] = df_resume['Resume_cleaned'].apply(remove_website)

# %%
# Replace '&' signs by the word 'and'.

df_resume['Resume_cleaned'] = df_resume['Resume_cleaned'].str.\
    replace('[&]', ' and ', regex = True) #if we remove stopwords we don't need this

# Remove punctuation using RegEx.

my_punctuation = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

df_resume['Resume_cleaned'] = df_resume['Resume_cleaned'].str.\
    replace('[{}]'.format(my_punctuation), ' ' , regex = True)

# Inspect output.

df_resume['Resume_cleaned'][0][:200]
# Out:
# '  family private care llc lawrenceville  ga a self motivated production sql server database administrator who possesses strong analytical and problem solving skills  my experience includes sql server '

# %% [markdown]
# ## 3. Convert number words to digits (and remove them)

# %%
# Dictionary with common numbers that are written out in words instead of digits.

num_dic = {'zero':'0', 'one':'1', 'two':'2', 'three':'3', 'four':'4', 'five':'5', 'six':'6', 'seven':'7',
           'eight':'8', 'nine':'9', 'ten':'10', 'eleven':'11', 'twelve':'12', 'thirteen':'13', 'fourteen':'14',
           'fifteen':'15', 'sixteen':'16', 'seventeen':'17', 'eighteen':'18', 'nineteen':'19', 'twenty':'20',
           'twenty-one':'21', 'twenty-two':'22', 'twenty-three':'23', 'twenty-four':'24','twenty-five':'25',
           'twenty-six':'26', 'twenty-seven':'27', 'twenty-eight':'28', 'twenty-nine':'29', 'thirty':'30',
           'thirty-one':'31', 'thirty-two':'32', 'thirty-three':'33', 'thirty-four':'34','thirty-five':'35',
           'thirty-six':'36', 'thirty-seven':'37', 'thirty-eight':'38', 'thirty-nine':'39', 'fourty':'40',
           'fifty':'50', 'sixty':'60', 'seventy':'70', 'eighty':'80', 'ninety':'90', 'hundred':'100'}

# Replace the number words by digit counterparts.

def replace_num_words(x):
    l = x.split()
    return " ".join([num_dic[w] if w in set(num_dic) else w for w in l])

df_resume['Resume_cleaned'] = df_resume['Resume_cleaned'].apply(replace_num_words)

# Remove all digits.

df_resume['Resume_cleaned'] = df_resume['Resume_cleaned'].replace('\d+', ' ', regex = True)

# Inspect output.

df_resume['Resume_cleaned'][0][:200]
# Out:
# 'family private care llc lawrenceville ga a self motivated production sql server database administrator who possesses strong analytical and problem solving skills my experience includes sql server     '

# %% [markdown]
# ## 4. Remove stopwords and short words

# %%
# Load nltk stopwords in English.

nltk_stopwords = set(stopwords.words('english')) 

# To account for common typos, the stopwords set is expanded.

more_stopwords = ['us','aren t','arent','couldn t','couldnt', 'didn t','didnt','doesn t','doesnt','dont','don t',
           'hadnt','hadn t','hasnt','hasn t', 'havent','haven t','isnt','isn t','mightnt','mightn t',
           'mustnt','mustn t','neednt','needn t','shouldnt', 'shouldn t','wasnt','wasn t','werent','weren t',
           'wont','won t','wouldnt','wouldn t']
 
all_stopwords = nltk_stopwords.union(set(more_stopwords))

# Remove all stopwords from the resumes.

df_resume['Resume_cleaned'] = df_resume['Resume_cleaned'].\
            apply(lambda x: " ".join(x for x in x.split() if x not in all_stopwords))

# Remove words with length <= 2.

def remove_short_words(x):
    out = []
    l = x.split()
    
    for w in l:
        if len(w) <= 2:
            out.append('')
        else:
            out.append(w)
            
    return " ".join(out)

df_resume['Resume_cleaned'] = df_resume['Resume_cleaned'].apply(remove_short_words)

# Inspect output.

df_resume['Resume_cleaned'][0][:200]
# Out:
# 'family private care llc lawrenceville  self motivated production sql server database administrator possesses strong analytical problem solving skills experience includes sql server ssis well clusterin'

# %% [markdown]
# ## 5. Remove months

# %%
months = set(['january', 'february', 'march', 'april', 'may', 'june', 'july',
          'august', 'september', 'october', 'november', 'december'])

# Remove all months from the resumes.

df_resume['Resume_cleaned'] = df_resume['Resume_cleaned'].\
            apply(lambda x: " ".join(x for x in x.split() if x not in months))

# %%
# Remove leading/trailing/double white spaces.

def remove_empty(x):
    return " ".join(x.strip().split())

df_resume['Resume_cleaned'] = df_resume['Resume_cleaned'].apply(remove_empty)

# Inspect output.

df_resume['Resume_cleaned'][0][:200]
# Out:
# 'family private care llc lawrenceville self motivated production sql server database administrator possesses strong analytical problem solving skills experience includes sql server ssis well clustering'

# %% [markdown]
# ## 6. Remove common geolocations

# %%
nlp = spacy.load('en_core_web_sm', disable = ['tagger','parser'])

# Create a list with all geolocations that appear in the resumes.

locations = []

for res in df_resume['Resume_cleaned']:
    doc = nlp(res)
    locations.extend([ent.text for ent in doc.ents if ent.label_ in ['LOC', 'GPE']])
# Out:
# /Users/laurenshamm/opt/anaconda3/lib/python3.8/site-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %% [markdown]
# ### Note:
# Not all _locations_ identified by the Spacy package are actual geolocations. Some are coding languages or other technical terms. Since we do not want to remove these names, as they might be important for classification, we manually select the geolocations that we want to remove.

# %%
print(len(Counter(locations).most_common()))
Counter(locations).most_common()
# Out:
# 2186
# [('cisco', 4679),
#  ('united states', 1578),
#  ('new york', 1577),
#  ('washington', 1083),
#  ('houston', 979),
#  ('atlanta', 944),
#  ('chicago', 767),
#  ('india', 688),
#  ('palo alto', 683),
#  ('dallas', 626),
#  ('san diego', 617),
#  ('america', 579),
#  ('los angeles', 551),
#  ('california', 539),
#  ('texas', 435),
#  ('florida', 433),
#  ('maryland', 429),
#  ('san francisco', 422),
#  ('san jose', 405),
#  ('denver', 399),
#  ('miami', 369),
#  ('san antonio', 364),
#  ('richmond', 341),
#  ('colorado', 317),
#  ('baltimore', 302),
#  ('arlington', 267),
#  ('minneapolis', 249),
#  ('las vegas', 229),
#  ('fairfax', 226),
#  ('london', 226),
#  ('oltp', 223),
#  ('cincinnati', 222),
#  ('boston', 206),
#  ('canada', 194),
#  ('pittsburgh', 193),
#  ('columbus', 166),
#  ('china', 156),
#  ('georgia', 154),
#  ('north carolina', 152),
#  ('missouri', 146),
#  ('kansas city', 146),
#  ('philadelphia', 146),
#  ('arizona', 140),
#  ('orlando', 136),
#  ('sacramento', 132),
#  ('ohio', 128),
#  ('tampa', 123),
#  ('afghanistan', 121),
#  ('virginia', 118),
#  ('santa clara', 115),
#  ('iowa', 113),
#  ('europe', 113),
#  ('milwaukee', 108),
#  ('oakland', 97),
#  ('fort lauderdale', 92),
#  ('moscow', 91),
#  ('awr addm', 90),
#  ('puerto rico', 90),
#  ('minnesota', 89),
#  ('arkansas', 88),
#  ('japan', 86),
#  ('mexico', 85),
#  ('indianapolis', 84),
#  ('san storage', 83),
#  ('iraq', 83),
#  ('fort worth', 83),
#  ('san juan', 82),
#  ('new york city', 82),
#  ('tennessee', 78),
#  ('north america', 71),
#  ('brazil', 70),
#  ('oregon', 70),
#  ('dublin', 68),
#  ('michigan', 66),
#  ('australia', 66),
#  ('latin america', 65),
#  ('detroit', 63),
#  ('louisville', 61),
#  ('singapore', 61),
#  ('cleveland', 60),
#  ('harrisburg', 59),
#  ('manhattan', 59),
#  ('lagos', 56),
#  ('san network', 56),
#  ('virginia beach', 56),
#  ('massachusetts', 54),
#  ('new orleans', 54),
#  ('utah', 54),
#  ('illinois', 51),
#  ('lexington', 50),
#  ('germany', 50),
#  ('asia', 50),
#  ('indiana', 49),
#  ('kentucky', 49),
#  ('paris', 49),
#  ('france', 48),
#  ('aruba', 48),
#  ('pennsylvania', 47),
#  ('addis ababa', 47),
#  ('connecticut', 46),
#  ('panama city', 46),
#  ('boca raton', 46),
#  ('jacksonville', 45),
#  ('sunnyvale', 45),
#  ('palo alto firewall', 45),
#  ('south carolina', 44),
#  ('rhode island', 43),
#  ('russia', 43),
#  ('toronto', 42),
#  ('west virginia', 41),
#  ('orange county', 41),
#  ('philippines', 39),
#  ('cuba', 38),
#  ('new jersey', 38),
#  ('hollywood', 37),
#  ('birmingham', 37),
#  ('kansas', 37),
#  ('midwest', 37),
#  ('charleston', 37),
#  ('charlotte', 36),
#  ('san ramon', 36),
#  ('nebraska', 35),
#  ('havana', 34),
#  ('omaha', 34),
#  ('san nas', 33),
#  ('jersey city', 33),
#  ('baghdad', 33),
#  ('united kingdom', 32),
#  ('san mateo', 32),
#  ('lebanon', 31),
#  ('hsrp', 30),
#  ('stamford', 29),
#  ('kabul', 28),
#  ('malaysia', 28),
#  ('west palm beach', 28),
#  ('baltimore county', 27),
#  ('camtasia', 27),
#  ('oversaw', 26),
#  ('san francisco bay', 26),
#  ('gujarat', 26),
#  ('santa barbara', 25),
#  ('beijing', 25),
#  ('manassas', 25),
#  ('alaska', 25),
#  ('fort belvoir', 25),
#  ('costa mesa', 25),
#  ('hawaii', 25),
#  ('istanbul', 25),
#  ('palo alto cisco', 25),
#  ('ghana', 24),
#  ('israel', 24),
#  ('farmington hills', 24),
#  ('jakarta', 24),
#  ('bloomberg', 23),
#  ('south korea', 23),
#  ('san antonio san', 23),
#  ('pendleton', 23),
#  ('santa monica', 23),
#  ('italy', 22),
#  ('west chester', 22),
#  ('knoxville', 22),
#  ('saudi arabia', 22),
#  ('europe asia', 22),
#  ('africa', 22),
#  ('newport beach', 22),
#  ('tokyo', 22),
#  ('shanghai', 21),
#  ('spain', 21),
#  ('ashland', 21),
#  ('new york university', 21),
#  ('san salvador', 21),
#  ('cupertino', 21),
#  ('wisconsin', 21),
#  ('awr addm ash', 20),
#  ('austin', 20),
#  ('pittsburg', 20),
#  ('modesto', 20),
#  ('fort bragg', 20),
#  ('north carolina state', 19),
#  ('holland', 19),
#  ('poland', 19),
#  ('mexico city', 19),
#  ('cpm', 19),
#  ('hong kong', 19),
#  ('meditech', 18),
#  ('portland', 18),
#  ('west des moines', 18),
#  ('pakistan', 18),
#  ('taiwan', 18),
#  ('seattle', 18),
#  ('korea', 18),
#  ('santa cruz', 18),
#  ('leesburg', 17),
#  ('ethiopia', 17),
#  ('sia', 17),
#  ('west coast', 17),
#  ('sysadmin', 16),
#  ('nyc', 16),
#  ('northern virginia', 16),
#  ('beverly hills', 16),
#  ('canton', 16),
#  ('mississippi', 16),
#  ('vietnam', 16),
#  ('jpmorgan', 16),
#  ('san angelo', 16),
#  ('san switches', 16),
#  ('algeria', 15),
#  ('wellington', 15),
#  ('north america europe', 15),
#  ('rochelle', 15),
#  ('littleton', 15),
#  ('san bernardino', 15),
#  ('dublin ireland', 15),
#  ('ventura', 15),
#  ('fullerton', 14),
#  ('jefferson city', 14),
#  ('middle east', 14),
#  ('kandahar', 14),
#  ('silicon valley', 14),
#  ('fort meade', 14),
#  ('oklahoma', 14),
#  ('south africa', 14),
#  ('kenya', 14),
#  ('shenzhen', 14),
#  ('turkey', 14),
#  ('telangana', 13),
#  ('vienna', 13),
#  ('tableau', 13),
#  ('united states army', 13),
#  ('camden', 13),
#  ('south carolina columbia', 13),
#  ('milpitas', 13),
#  ('franklin county', 13),
#  ('warsaw', 13),
#  ('alabama', 13),
#  ('continental united states', 13),
#  ('naperville', 12),
#  ('bowie', 12),
#  ('indonesia', 12),
#  ('new delhi', 12),
#  ('asia pacific', 12),
#  ('ireland', 12),
#  ('louisiana', 12),
#  ('santa', 12),
#  ('south america', 12),
#  ('scada', 12),
#  ('hungary', 12),
#  ('iran', 12),
#  ('montana', 11),
#  ('nashville', 11),
#  ('new mexico', 11),
#  ('intermedia', 11),
#  ('san luis', 11),
#  ('argentina', 11),
#  ('collin county', 11),
#  ('togaf', 11),
#  ('san francisco state', 10),
#  ('golden valley', 10),
#  ('wyndham', 10),
#  ('crystal city', 10),
#  ('vancouver', 10),
#  ('san unix', 10),
#  ('colombia', 10),
#  ('morocco', 10),
#  ('nigeria', 10),
#  ('san diego county', 10),
#  ('los gatos', 10),
#  ('new zealand', 10),
#  ('kingston', 10),
#  ('san backup', 10),
#  ('missouri columbia', 9),
#  ('jupiter', 9),
#  ('nevada', 9),
#  ('canada mexico', 9),
#  ('fort wayne', 9),
#  ('dalton', 9),
#  ('bremerton', 9),
#  ('anesthesia', 9),
#  ('frankfurt', 9),
#  ('princeton', 9),
#  ('maryville', 9),
#  ('seoul korea', 9),
#  ('wpf xaml', 9),
#  ('camden county', 9),
#  ('west valley', 9),
#  ('denver denver', 9),
#  ('brussels', 9),
#  ('gulf coast state', 8),
#  ('zionsville', 8),
#  ('district columbia', 8),
#  ('bay area', 8),
#  ('jefferson county', 8),
#  ('east africa', 8),
#  ('prc', 8),
#  ('delhi', 8),
#  ('panama', 8),
#  ('hamburg', 8),
#  ('new york state', 8),
#  ('mcas', 8),
#  ('numara', 8),
#  ('thailand', 8),
#  ('carolina', 8),
#  ('san dell', 8),
#  ('costa rica', 7),
#  ('libya', 7),
#  ('san leandro', 7),
#  ('san marcos', 7),
#  ('southern california', 7),
#  ('san vmware', 7),
#  ('san based', 7),
#  ('winston', 7),
#  ('cairo', 7),
#  ('indian hills', 7),
#  ('miami beach', 7),
#  ('north west', 7),
#  ('san rafael', 7),
#  ('san clemente', 7),
#  ('kenosha', 7),
#  ('nicaragua', 7),
#  ('egypt', 7),
#  ('new york albany', 7),
#  ('hendersonville', 7),
#  ('qatar', 7),
#  ('san technologies', 7),
#  ('san fiber', 7),
#  ('beaverton', 7),
#  ('eaton', 7),
#  ('fort smith', 7),
#  ('sarasota', 7),
#  ('west ward', 7),
#  ('fort huachuca', 7),
#  ('rspec', 7),
#  ('san migration', 6),
#  ('midland', 6),
#  ('east tennessee', 6),
#  ('usa', 6),
#  ('san servers', 6),
#  ('damascus', 6),
#  ('east coast', 6),
#  ('asia europe', 6),
#  ('taipei', 6),
#  ('new delhi delhi', 6),
#  ('switzerland', 6),
#  ('midwest city', 6),
#  ('kingsville', 6),
#  ('baltimore city', 6),
#  ('san sql', 6),
#  ('chino hills', 6),
#  ('marriott', 6),
#  ('wallingford', 6),
#  ('west africa', 6),
#  ('veeva', 6),
#  ('west valley city', 6),
#  ('dominican republic', 6),
#  ('imac', 6),
#  ('berkeley', 6),
#  ('technician united states', 6),
#  ('spokane valley', 6),
#  ('delaware', 6),
#  ('san cisco', 6),
#  ('winston salem', 6),
#  ('united state', 6),
#  ('midland county', 6),
#  ('west kentucky', 6),
#  ('xpath', 6),
#  ('glbp', 6),
#  ('xslt', 6),
#  ('kentico', 6),
#  ('san ibm', 6),
#  ('east hartford', 5),
#  ('united arab emirates', 5),
#  ('north georgia', 5),
#  ('san dropping', 5),
#  ('valley', 5),
#  ('long beach', 5),
#  ('medina', 5),
#  ('lithonia', 5),
#  ('alberta', 5),
#  ('ellicott city', 5),
#  ('new york city department', 5),
#  ('tallahassee', 5),
#  ('karnataka', 5),
#  ('los angeles county', 5),
#  ('central valley', 5),
#  ('east carolina university', 5),
#  ('europe asia pacific', 5),
#  ('brookdale', 5),
#  ('mid atlantic', 5),
#  ('trowbridge', 5),
#  ('marc', 5),
#  ('san diego city', 5),
#  ('oman', 5),
#  ('san antonio san antonio', 5),
#  ('fairfax county', 5),
#  ('west des', 5),
#  ('asia pacific region', 5),
#  ('luxembourg', 5),
#  ('stockholm', 5),
#  ('black hills', 5),
#  ('atlantic city', 5),
#  ('kirkland', 5),
#  ('isas', 5),
#  ('first republic bank', 5),
#  ('south east', 5),
#  ('san shou', 5),
#  ('fort gordon', 5),
#  ('edwardsville', 5),
#  ('san disks', 5),
#  ('west marine', 5),
#  ('bengaluru', 4),
#  ('san replication', 4),
#  ('buffalo', 4),
#  ('bulgaria', 4),
#  ('yemen', 4),
#  ('milan', 4),
#  ('united states postal', 4),
#  ('east bay', 4),
#  ('harden', 4),
#  ('years crystal', 4),
#  ('san disk', 4),
#  ('los angeles valley', 4),
#  ('san bruno', 4),
#  ('new britain', 4),
#  ('new york state department', 4),
#  ('south carolina columbia columbia', 4),
#  ('belfast', 4),
#  ('san solution', 4),
#  ('university nagpur maharashtra', 4),
#  ('charlotte charlotte', 4),
#  ('twinsburg', 4),
#  ('new york suny', 4),
#  ('mid atlantic region', 4),
#  ('prussia', 4),
#  ('rwanda', 4),
#  ('tibco', 4),
#  ('hplc', 4),
#  ('geek squad', 4),
#  ('kuala lumpur', 4),
#  ('panama city beach', 4),
#  ('temple hills', 4),
#  ('ventura county', 4),
#  ('lorton', 4),
#  ('promedica', 4),
#  ('fort lewis', 4),
#  ('northern california', 4),
#  ('syngenta', 4),
#  ('britain', 4),
#  ('san juan capistrano', 4),
#  ('hilton', 4),
#  ('united arab', 4),
#  ('kosovo', 4),
#  ('bay city', 4),
#  ('baton rouge', 4),
#  ('scotland', 4),
#  ('jrotc', 4),
#  ('springfield', 4),
#  ('cambodia', 4),
#  ('jamaica', 4),
#  ('west hartford', 4),
#  ('roc', 4),
#  ('conn', 4),
#  ('romania', 4),
#  ('hudson county', 4),
#  ('fort sill', 4),
#  ('baytech', 4),
#  ('valley city', 4),
#  ('firewall', 4),
#  ('xining', 4),
#  ('palo altos', 4),
#  ('east greenwich', 4),
#  ('san volumes', 4),
#  ('mpls mpls vpns', 4),
#  ('gaza', 4),
#  ('franklin bach', 4),
#  ('san svn', 4),
#  ('las vegas skills', 3),
#  ('new york times', 3),
#  ('awr addm languages', 3),
#  ('san pedro', 3),
#  ('kentucky lexington', 3),
#  ('ssas', 3),
#  ('arabian gulf', 3),
#  ('calabasas', 3),
#  ('north hills', 3),
#  ('beaumont', 3),
#  ('asia africa', 3),
#  ('manhattanville', 3),
#  ('north texas', 3),
#  ('miamisburg', 3),
#  ('sirva', 3),
#  ('newton', 3),
#  ('guadalajara', 3),
#  ('artesia', 3),
#  ('kenan', 3),
#  ('medica', 3),
#  ('douala', 3),
#  ('san platforms', 3),
#  ('telephony united states', 3),
#  ('united states air force', 3),
#  ('vidalia', 3),
#  ('san rac', 3),
#  ('south west', 3),
#  ('east west', 3),
#  ('arcyber', 3),
#  ('peru', 3),
#  ('beginner', 3),
#  ('mississippi gulf coast', 3),
#  ('west deptford', 3),
#  ('gujarati', 3),
#  ('bartlesville', 3),
#  ('smyrna', 3),
#  ('keepas', 3),
#  ('san office', 3),
#  ('sqltune addm', 3),
#  ('mississippi gulf coast community', 3),
#  ('concord', 3),
#  ('sylmar', 3),
#  ('mvbo', 3),
#  ('eastern united states', 3),
#  ('west hollywood', 3),
#  ('bay state', 3),
#  ('syria', 3),
#  ('delmar', 3),
#  ('lowe', 3),
#  ('baja', 3),
#  ('west hills', 3),
#  ('nyc area', 3),
#  ('san allocation', 3),
#  ('sao paulo', 3),
#  ('san fernando', 3),
#  ('north africa', 3),
#  ('mid west', 3),
#  ('shelbyville', 3),
#  ('michaelis', 3),
#  ('fort leonard', 3),
#  ('san implementations', 3),
#  ('mpls vpls', 3),
#  ('bingham', 3),
#  ('southeastern united states', 3),
#  ('europe india', 3),
#  ('tel aviv', 3),
#  ('varina', 3),
#  ('new york city transit authority', 3),
#  ('halliburton', 3),
#  ('locations united states', 3),
#  ('san francisco san', 3),
#  ('tianjin', 3),
#  ('san francisco san francisco', 3),
#  ('galleria', 3),
#  ('huntingdon valley', 3),
#  ('kaseya', 3),
#  ('appleton', 3),
#  ('branchburg', 3),
#  ('rockland', 3),
#  ('dominguez hills', 3),
#  ('chaska', 3),
#  ('los palos', 3),
#  ('chacao', 3),
#  ('san lan', 3),
#  ('san joaquin valley', 3),
#  ('north carolina pembroke', 3),
#  ('miramar', 3),
#  ('dania beach', 3),
#  ('addon', 3),
#  ('mvc singleton', 3),
#  ('hunt valley', 3),
#  ('south coast', 3),
#  ('san jose city', 3),
#  ('san luns', 3),
#  ('san copy', 3),
#  ('larimer county', 3),
#  ('mid america', 3),
#  ('kirksville', 3),
#  ('belgium', 3),
#  ('crystal lake', 3),
#  ('belgrade', 3),
#  ('san iscsi', 3),
#  ('antelope valley', 3),
#  ('coshocton', 3),
#  ('xamarin', 3),
#  ('quebec city', 3),
#  ('bucheon korea', 3),
#  ('mumbai', 3),
#  ('blackpearl', 3),
#  ('aristocrat', 3),
#  ('inc mount', 3),
#  ('healthsparq', 3),
#  ('shreveport', 3),
#  ('unvetica', 3),
#  ('viroqua', 3),
#  ('guangzhou', 3),
#  ('san nutanix', 3),
#  ('belle', 3),
#  ('san san', 3),
#  ('san print', 3),
#  ('columbus united', 3),
#  ('san solutions', 3),
#  ('san monitoring', 3),
#  ('san ssa', 3),
#  ('ecuador', 2),
#  ('san performance', 2),
#  ('inc columbia columbia', 2),
#  ('centers united states', 2),
#  ('awr addm ash sql', 2),
#  ('awr addm ash sql shell', 2),
#  ('awr addm automatic', 2),
#  ('awr addm ash performance', 2),
#  ('jeddah', 2),
#  ('kansas city risk management', 2),
#  ('hudson valley', 2),
#  ('kenilworth', 2),
#  ('san technology', 2),
#  ('awr addm ash enterprise', 2),
#  ('los alamos', 2),
#  ('pretoria', 2),
#  ('brookeville', 2),
#  ('fort dodge', 2),
#  ('knoell', 2),
#  ('cockeysville', 2),
#  ('west bresnan', 2),
#  ('adsm', 2),
#  ('eodt', 2),
#  ('san srdf', 2),
#  ('san oracle', 2),
#  ('solumina', 2),
#  ('river valley', 2),
#  ('university delhi', 2),
#  ('san par', 2),
#  ('united way', 2),
#  ('arden hills', 2),
#  ('fort stewart', 2),
#  ('brownsburg', 2),
#  ('nomad', 2),
#  ('palestine', 2),
#  ('midwest league', 2),
#  ('ormond beach', 2),
#  ('clarksburg', 2),
#  ('onprem', 2),
#  ('west river', 2),
#  ('hemophilia', 2),
#  ('staruml', 2),
#  ('amravati', 2),
#  ('buckley', 2),
#  ('west san', 2),
#  ('awr addm assm', 2),
#  ('xhum', 2),
#  ('koch', 2),
#  ('west bengal', 2),
#  ('east petersburg', 2),
#  ('xchange', 2),
#  ('puerto rico mexico store', 2),
#  ('cigna', 2),
#  ('allston', 2),
#  ('awr addm ash alert', 2),
#  ('mid atlantic mount', 2),
#  ('walton beach', 2),
#  ('costa county', 2),
#  ('central asia', 2),
#  ('celestica', 2),
#  ('english united states', 2),
#  ('asia middle', 2),
#  ('orange beach', 2),
#  ('guangdong', 2),
#  ('ibm columbia', 2),
#  ('netherlands', 2),
#  ('rochester hills', 2),
#  ('hipsc', 2),
#  ('waukesha county', 2),
#  ('east north africa', 2),
#  ('tunisia', 2),
#  ('europe middle', 2),
#  ('nara', 2),
#  ('estonia', 2),
#  ('west central', 2),
#  ('mediterranean', 2),
#  ('south asia europe', 2),
#  ('fulton county', 2),
#  ('several united states', 2),
#  ('canada united states', 2),
#  ('mexico germany', 2),
#  ('greater asia europe', 2),
#  ('piscataway', 2),
#  ('napa valley', 2),
#  ('marmara', 2),
#  ('umbraco', 2),
#  ('first republic', 2),
#  ('mpls pri', 2),
#  ('janeiro', 2),
#  ('africa asia pacific', 2),
#  ('washington united states', 2),
#  ('llc columbia', 2),
#  ('nashville nashville', 2),
#  ('dubai', 2),
#  ('quezon city', 2),
#  ('prague', 2),
#  ('united states department', 2),
#  ('brasilia', 2),
#  ('north ridgeville', 2),
#  ('new mexico epa', 2),
#  ('osmotica', 2),
#  ('north america mexico', 2),
#  ('usa europe', 2),
#  ('caracas', 2),
#  ('puerto', 2),
#  ('castleton', 2),
#  ('south central', 2),
#  ('west houston', 2),
#  ('east west coast', 2),
#  ('latin america africa middle east asia pacific', 2),
#  ('mount laurel', 2),
#  ('nac huntsville', 2),
#  ('idaho', 2),
#  ('india philippines', 2),
#  ('san linux', 2),
#  ('east norriton', 2),
#  ('mexico united states', 2),
#  ('san dimas', 2),
#  ('kingsville kingsville', 2),
#  ('caribbean', 2),
#  ('aficionado', 2),
#  ('intelligence united states', 2),
#  ('valley village', 2),
#  ('university louisville louisville', 2),
#  ('marina', 2),
#  ('west georgia', 2),
#  ('bank united states', 2),
#  ('british columbia', 2),
#  ('mexico colombia', 2),
#  ('ncis', 2),
#  ('kazakhstan', 2),
#  ('europe asia south america', 2),
#  ('mckinley', 2),
#  ('northwest mexico', 2),
#  ('gras', 2),
#  ('west international airport', 2),
#  ('moreno valley', 2),
#  ('laguna hills', 2),
#  ('weston', 2),
#  ('north dallas', 2),
#  ('north island', 2),
#  ('mpls metro', 2),
#  ('hydra firewall', 2),
#  ('qsas', 2),
#  ('allina', 2),
#  ('bastille', 2),
#  ('serbia', 2),
#  ('palo alto configuration administration', 2),
#  ('asas', 2),
#  ('knightdale', 2),
#  ('ocia', 2),
#  ('quebec', 2),
#  ('uconn', 2),
#  ('middle east south asia', 2),
#  ('san server', 2),
#  ('west charlotte', 2),
#  ('supported united states', 2),
#  ('mecklenburg county', 2),
#  ('tirana', 2),
#  ('iselin', 2),
#  ('qinghai', 2),
#  ('north dakota', 2),
#  ('year', 2),
#  ('tuba city', 2),
#  ('ebensburg', 2),
#  ('venezuela', 2),
#  ('wireman united states', 2),
#  ('infantryman united states', 2),
#  ('san refresh', 2),
#  ('north miami beach', 2),
#  ('acas', 2),
#  ('san nic', 2),
#  ('north america asia europe', 2),
#  ('west pacific', 2),
#  ('army united states', 2),
#  ('transas', 2),
#  ('wis international joplin', 2),
#  ('naugatuck valley', 2),
#  ('fort oglethorpe', 2),
#  ('north dakota minnesota', 2),
#  ('piqua', 2),
#  ('west covina', 2),
#  ('moon valley', 2),
#  ('aon', 2),
#  ('onalaska', 2),
#  ('premises', 2),
#  ('palos hills', 2),
#  ('mid hudson valley', 2),
#  ('kingston cisco', 2),
#  ('bergen county', 2),
#  ('around united states', 2),
#  ('san joaquin valley clinical systems', 2),
#  ('san administer', 2),
#  ('west orange', 2),
#  ('united states miliary', 2),
#  ('san working', 2),
#  ('mount san', 2),
#  ('richmond county', 2),
#  ('waynesburg', 2),
#  ('netvanta', 2),
#  ('tyngsboro', 2),
#  ('xitech', 2),
#  ('gulf region', 2),
#  ('san netapp', 2),
#  ('asia pacific europe', 2),
#  ('asia pacific mexico brazil', 2),
#  ('midwest wildcard', 2),
#  ('west palm', 2),
#  ('eastern coast', 2),
#  ('ottumwa', 2),
#  ('checkpoint', 2),
#  ('palo alto wan', 2),
#  ('san volume', 2),
#  ('changeover', 2),
#  ('pendleton united states', 2),
#  ('allmerica', 2),
#  ('gaza palestine', 2),
#  ('india korea', 2),
#  ('mobile', 2),
#  ('california city', 2),
#  ('wpf crystal', 2),
#  ('redux', 2),
#  ('nyc city', 2),
#  ('ooma', 2),
#  ('arris', 2),
#  ('west region', 2),
#  ('river city republic', 2),
#  ('los angeles orange counties', 2),
#  ('jersey united states', 2),
#  ('kuwait', 2),
#  ('green hills', 2),
#  ('knoxville united states', 2),
#  ('roorkee', 2),
#  ('south bay', 2),
#  ('atlantic beach', 2),
#  ('east carolina', 2),
#  ('kalona', 2),
#  ('harcourt', 2),
#  ('walton', 2),
#  ('oneonta', 2),
#  ('north lauderdale', 2),
#  ('kpds', 2),
#  ('school york', 2),
#  ('berlin', 2),
#  ('san francisco city', 2),
#  ('san desktop', 2),
#  ('san joaquin delta', 2),
#  ('san systems', 2),
#  ('inc york', 2),
#  ('karavay', 2),
#  ('villa rica', 2),
#  ('san arrays', 2),
#  ('san luis obispo health', 2),
#  ('south county', 2),
#  ('michigan city', 2),
#  ('san connectivity vmware', 2),
#  ('liberia', 2),
#  ('north west region', 2),
#  ('jacl', 2),
#  ('japan korea', 2),
#  ('school united states', 2),
#  ('san data', 2),
#  ('gantech columbia', 2),
#  ('san units', 2),
#  ('peregrine', 2),
#  ('san cifs', 2),
#  ('san wan', 2),
#  ('winston tower', 2),
#  ('texas city', 2),
#  ('tualatin hills', 2),
#  ('north county', 2),
#  ('north carolina marine', 2),
#  ('las vegas system', 2),
#  ('san diego usa', 1),
#  ('southern hills', 1),
#  ('hadr', 1),
#  ('canonsburg', 1),
#  ('wallingford wallingford', 1),
#  ('edo state', 1),
#  ('johnston county', 1),
#  ('chipton', 1),
#  ('texas dallas', 1),
#  ('taipei city', 1),
#  ('inc edina', 1),
#  ('north jersey', 1),
#  ('sta addm sql', 1),
#  ('east windsor years', 1),
#  ('washington database', 1),
#  ('united states international university', 1),
#  ('awr addm fine tune', 1),
#  ('approx', 1),
#  ('san vmware various', 1),
#  ('northeast indiana', 1),
#  ('san juan network security administration', 1),
#  ('awr addm ash backup utilities', 1),
#  ('english rhode island', 1),
#  ('addis ababa midroc technology', 1),
#  ('stoutsville', 1),
#  ('agencies united states', 1),
#  ('university york', 1),
#  ('corp mountain', 1),
#  ('yogyakarta', 1),
#  ('bmc addm bmc', 1),
#  ('san fernando valley', 1),
#  ('addmrpt awrpt', 1),
#  ('asia pacific analysis', 1),
#  ('hamilton county city', 1),
#  ('eagle island', 1),
#  ('north carolina present plc', 1),
#  ('west coast east', 1),
#  ('san francisco california', 1),
#  ('hurley', 1),
#  ('san scsi', 1),
#  ('canyon county', 1),
#  ('ussocom united states', 1),
#  ('chung hwa', 1),
#  ('africa central asia eastern', 1),
#  ('north america asia africa europe', 1),
#  ('africa middle east', 1),
#  ('laurel hills', 1),
#  ('west mciwest', 1),
#  ('corp york', 1),
#  ('mandarin fluent', 1),
#  ('fygm', 1),
#  ('kenton', 1),
#  ('multnomah county', 1),
#  ('san changes', 1),
#  ('xtivia', 1),
#  ('navi mumbai', 1),
#  ('chitwan', 1),
#  ('chicagos west southwest', 1),
#  ('new york gather', 1),
#  ('landlord', 1),
#  ('saratha', 1),
#  ('green bay', 1),
#  ('isam', 1),
#  ('concord github', 1),
#  ('abbott', 1),
#  ('san views profiler', 1),
#  ('central africa', 1),
#  ('goshen', 1),
#  ('texas united states', 1),
#  ('migos', 1),
#  ('new york institute', 1),
#  ('nuvox', 1),
#  ('insurance columbia', 1),
#  ('itanium', 1),
#  ('san microsoft', 1),
#  ('sedona', 1),
#  ('miami lauderdale', 1),
#  ('san external', 1),
#  ('pennsylvania philadelphia', 1),
#  ('mexico power', 1),
#  ('awr addm ash diagnostics', 1),
#  ('eagan minnesota', 1),
#  ('francis', 1),
#  ('caracas venezuela', 1),
#  ('chefdk', 1),
#  ('datas', 1),
#  ('mexico mexico government pmc', 1),
#  ('msr united', 1),
#  ('oceana beach', 1),
#  ('neohe bay', 1),
#  ('north potomac', 1),
#  ('china beijing', 1),
#  ('topton', 1),
#  ('tripp', 1),
#  ('gnvq', 1),
#  ('holoprosencephaly', 1),
#  ('oooo', 1),
#  ('ooooa', 1),
#  ('mahanagar', 1),
#  ('poc golden', 1),
#  ('leesburg database', 1),
#  ('trainer', 1),
#  ('andalusia andalusia faulkner', 1),
#  ('newsweek dallas', 1),
#  ('clarendon hills', 1),
#  ('club united states', 1),
#  ('new york complete administration', 1),
#  ('san hyperion', 1),
#  ('kenan arbor herndon', 1),
#  ('washington county', 1),
#  ('somalia', 1),
#  ('asian peninsula', 1),
#  ('contrak', 1),
#  ('maryvale', 1),
#  ('nyc hra', 1),
#  ('rio janeiro', 1),
#  ('llc united states department', 1),
#  ('world mount', 1),
#  ('usa mexico france', 1),
#  ('nyc venture', 1),
#  ('new york united', 1),
#  ('united states government agency', 1),
#  ('burnett', 1),
#  ('bay minette', 1),
#  ('san bcv', 1),
#  ('san san replication', 1),
#  ('new york investment accounting', 1),
#  ('louisville city louisville', 1),
#  ...]

# %%
# List of locations with count > 7.

all_locations_abv7 = []

for i in Counter(locations).most_common():
    if i[1] > 7:
        all_locations_abv7.append(i[0])

# All words in locations with count > 7 that don't correspond to geolocations.

remove = ['cisco', 'lan wan', 'roadmap', 'linq','nmap','qualys','veritas','peoplesoft','vmware','ssas','oversaw',
'srvctl','mssql','mongo','imap','san network','password','synonyms','san nas','offsite','sun solaris','grid',
'nexus','new hire','analyzer','rac','spss','avamar','toledo','erwin','metadata','node rac','decatur','new cisco',
'san storage','new sql','veracode','scrum','php','keras','firewalls','usmt','repo','bgp wan','iaas','usmc','webex',
'troubleshooting cisco','oracle sql sql','roc','concord','hadoop','asa cisco','appendix','xbox','vlans','webapi',
'etls', 'lan wan network','kofax','vpn cisco','new wan','new pos','sas','arcmap','comm','retina','vpn','php zend',
'bgp cisco','oncommand','webinar','rfqs','bcbs','intern','itar','heroku','itgc','mailbox','maas','isapi','cpu psu',
'san migration','bitmap','macon','liaison client','pbx','maintain cisco','bitcoin', 'vlsm','inheritance',
'javascript client','san storage']

# Final set of geolocations to remove from text.

geolocations = set(all_locations_abv7).difference(set(remove))

# %%
# Remove isolated geolocations from the documents.

def remove_geoloc(x):
    regex = re.compile(r'\b({}r)\b'.format('|'.join(geolocations)), flags = re.IGNORECASE)
    return regex.sub('', x)

df_resume['Resume_cleaned'] = df_resume['Resume_cleaned'].apply(remove_geoloc)

# %%
# Remove leading/trailing/double white spaces.

df_resume['Resume_cleaned'] = df_resume['Resume_cleaned'].apply(remove_empty)

# Inspect output.

df_resume['Resume_cleaned'][0][:200]
# Out:
# 'family private care llc lawrenceville self motivated production sql server database administrator possesses strong analytical problem solving skills experience includes sql server ssis well clustering'

# %% [markdown]
# ## 7. Lemmatization

# %%
# Load Spacy's lemmatizer.

nlp = spacy.load('en_core_web_sm', disable = ['parser', 'ner'])

# Construct empty, new column.

df_resume['Resume_lemma'] = ''

# %% [markdown]
# ### Note:
# Spacy transforms ordinal numbers into _unexpected_ lemmas (e.g. 'first' becomes '\ufeff1'). For this reason, we ignore tokens that correspond to ordinal numbers.

# %%
ordinal = set(['first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'seventh', 'eighth', 'ninth', 'tenth',
'eleventh', 'twelfth', 'thirteenth', 'fourteenth', 'fifteenth', 'sixteenth', 'seventeenth', 'eighteenth', 'nineteenth', 
'twentieth', 'thirtieth', 'fortieth', 'fiftieth', 'sixtieth', 'seventieth', 'eightieth', 'ninetieth', 'hundredth'])

# %%
# Lemmatize the entire set of resumes. Please note, this takes some time. 

df_resume['Resume_lemma'] = df_resume['Resume_cleaned'].\
        apply(lambda x: " ".join([token.lemma_ if token.text not in ordinal else token.text for token in nlp(x)]))

# %%
df_resume.head(5)
# Out:
#                                               Resume                   Label  \
# 0  Database Administrator <span class="hl">Databa...  Database_Administrator
# 1  Database Administrator <span class="hl">Databa...  Database_Administrator
# 2  Oracle Database Administrator Oracle <span cla...  Database_Administrator
# 3  Amazon Redshift Administrator and ETL Develope...  Database_Administrator
# 4  Scrum Master Scrum Master Scrum Master Richmon...  Database_Administrator
#
#                                       Resume_cleaned  \
# 0  family private care llc lawrenceville self mot...
# 1  sql server database administrator database adm...
# 2  cognizant hyderabad carrier objective obtain o...
# 3  etl developer database administrator plantatio...
# 4  work experience scrum master quest technologie...
#
#                                         Resume_lemma
# 0  family private care llc lawrenceville self mot...
# 1  sql server database administrator database adm...
# 2  cognizant hyderabad carrier objective obtain o...
# 3  etl developer database administrator plantatio...
# 4  work experience scrum master quest technologie...

# %% [markdown]
# ## 8. Join collocations (such that they act as single words)

# %%
# Create a long list of all words in all documents, in the original order. 

documents = df_resume['Resume_lemma'].tolist()

def words_list(documents):
    words = []
    
    for doc in documents: 
        for word in str(doc).split(): 
            
            words.append(word)
            
    return words

words = words_list(documents)

# %%
# Find the most common collocations.

common_collocations = BigramCollocationFinder.from_words(words)
bgm = BigramAssocMeasures()
scores = bgm.mi_like 

# Print the collocations, joined by an underscore '_'.

collocations = {'_'.join(bigram): mi_like 
                for bigram, mi_like in common_collocations.score_ngrams(scores)} 
collocations
# Out:
# {'active_directory': 5708.465573573564,
#  'sql_server': 2210.307982819014,
#  'red_hat': 1578.019579110844,
#  'disaster_recovery': 1328.096539957311,
#  'third_party': 1192.1361350777506,
#  'golden_gate': 1140.97717638285,
#  'additional_information': 1137.094695192593,
#  'life_cycle': 1043.4297943423412,
#  'work_experience': 926.691604445509,
#  'certification_license': 839.899436174855,
#  'asp_net': 715.653839733021,
#  'education_bachelor': 701.0638042327763,
#  'visual_studio': 687.3105974270175,
#  'help_desk': 683.1600993920624,
#  'measure_candidate': 644.8438534126888,
#  'root_cause': 629.2361086242912,
#  'less_year': 541.6459640755407,
#  'subject_matter': 499.330043786819,
#  'good_practice': 421.34963612713534,
#  'export_import': 417.9775205160769,
#  'marine_corps': 403.67959706880424,
#  'project_manager': 396.5260800673108,
#  'work_employer': 364.95407286828856,
#  'employer_work': 362.0168308988735,
#  'store_procedure': 359.3551739209829,
#  'html_css': 334.21295710775854,
#  'authorize_work': 330.11653263759933,
#  'lan_wan': 325.7681706684385,
#  'end_user': 315.8392280369819,
#  'expdp_impdp': 308.5624824863851,
#  'wells_fargo': 278.59837124575205,
#  'high_availability': 276.9183349548145,
#  'day_day': 276.4518512562531,
#  'trouble_shoot': 276.10203521586016,
#  'hewlett_packard': 264.2597734888433,
#  'computer_science': 263.80144412318225,
#  'microsoft_office': 262.77897636275156,
#  'pvt_ltd': 235.25944845598403,
#  'bachelor_science': 234.75085258040576,
#  'problem_solve': 223.09787839720016,
#  'lotus_note': 210.36356710919054,
#  'fast_pace': 210.11125047098477,
#  'tamil_nadu': 209.073732718894,
#  'exp_imp': 202.36522336769758,
#  'operating_system': 197.81447453531501,
#  'instal_configure': 195.82963811589204,
#  'full_result': 195.3500559360403,
#  'backup_recovery': 188.04846120906194,
#  'anti_virus': 186.99861359712764,
#  'air_force': 185.47287746961084,
#  'hardware_software': 183.83626580604985,
#  'cross_functional': 181.1408607571838,
#  'high_school': 178.592834702354,
#  'candidate_ability': 170.42624159648668,
#  'community_college': 168.41323111255585,
#  'shell_scripting': 166.4504949082922,
#  'system_administrator': 166.09717505087355,
#  'make_sure': 163.93614900270092,
#  'team_member': 151.26256741564066,
#  'front_end': 137.33939191234379,
#  'internal_external': 137.29046553686342,
#  'quality_assurance': 135.57675412846982,
#  'social_medium': 132.6573904687499,
#  'information_technology': 132.459235194827,
#  'installation_configuration': 131.20865492181983,
#  'sarbane_oxley': 127.56628938072237,
#  'timely_manner': 126.9676984675174,
#  'solar_wind': 123.77089128247619,
#  'database_administrator': 120.106362310298,
#  'software_developer': 118.6455257721024,
#  'state_university': 117.28547620360881,
#  'supply_chain': 116.83023488263942,
#  'baton_rouge': 115.46899224806202,
#  'hot_cold': 114.79647217377517,
#  'sun_solaris': 114.74596052745979,
#  'performance_tune': 112.3932371165037,
#  'load_balancer': 111.67039434961742,
#  'northrop_grumman': 110.17158111879627,
#  'risk_assessment': 109.09949536202814,
#  'customer_service': 108.29245378069616,
#  'oracle_database': 106.90733467379133,
#  'indicative_license': 106.09532120390014,
#  'pci_dss': 101.87633662803191,
#  'chennai_tamil': 101.50857711281188,
#  'vice_president': 93.9538929969552,
#  'matter_expert': 93.30154125801668,
#  'project_management': 93.07689557335965,
#  'lockheed_martin': 92.85714285714286,
#  'education_master': 89.6668145542141,
#  'router_switch': 88.74908814451035,
#  'dns_dhcp': 86.87840500327012,
#  'virtual_machine': 86.836596522267,
#  'shell_script': 86.6709720945789,
#  'tata_consultancy': 86.62614860014358,
#  'ruby_rail': 86.25295384615384,
#  'intrusion_detection': 85.94332375599899,
#  'explain_plan': 85.80395595846619,
#  'frame_relay': 85.4932868126898,
#  'import_export': 84.75393458448276,
#  'jawaharlal_nehru': 84.7534693877551,
#  'mumbai_maharashtra': 83.82404337361234,
#  'result_indeed': 82.98129307684289,
#  'proficient_measure': 81.2040426099528,
#  'kaiser_permanente': 79.88021648408973,
#  'incident_response': 79.85117443744937,
#  'scrum_master': 79.37055858449669,
#  'fiber_optic': 78.90002269908312,
#  'large_scale': 75.06768550365037,
#  'stake_holder': 72.13096656839993,
#  'long_term': 72.12224021661513,
#  'fannie_mae': 69.50800915331808,
#  'million_dollar': 69.43295361178771,
#  'attention_detail': 69.23073369431239,
#  'bengaluru_karnataka': 68.16362637362637,
#  'datum_guard': 67.60755389356234,
#  'andhra_pradesh': 67.59958462590042,
#  'salt_lake': 66.55898553596195,
#  'capacity_planning': 65.59010684600652,
#  'corrective_action': 65.1574390869023,
#  'soql_sosl': 64.64506522972206,
#  'policy_procedure': 63.874085567861535,
#  'window_server': 63.483151326968965,
#  'technical_support': 63.191184072445054,
#  'ann_arbor': 62.35382933661269,
#  'milestone_poa': 60.598775661479344,
#  'performance_tuning': 59.83407367692027,
#  'criminal_justice': 59.57238859528936,
#  'action_milestone': 58.79573543197665,
#  'log_shipping': 57.33383274599346,
#  'indeed_assessment': 55.73396667728638,
#  'highly_proficient': 54.522183493091,
#  'coca_cola': 54.390625,
#  'agile_scrum': 53.29866481649242,
#  'cyber_security': 53.16055912950018,
#  'work_closely': 52.4546617930955,
#  'grid_control': 51.60565687000824,
#  'justifiable_conclusion': 50.00500050005,
#  'unix_shell': 49.88890429849555,
#  'can_not': 49.31506849315068,
#  'nist_rev': 48.862624560011895,
#  'steering_committee': 48.37437416367217,
#  'stand_alone': 46.897484339266185,
#  'datum_center': 46.86270098655552,
#  'trace_tkprof': 46.83475419153169,
#  'point_contact': 46.51800071073205,
#  'ssis_package': 46.20773817178232,
#  'visual_basic': 45.837231057062674,
#  'real_time': 45.24237802723252,
#  'certification_continue': 44.457493258751825,
#  'physical_standby': 43.56258858357132,
#  'real_estate': 43.12256117179489,
#  'george_mason': 43.043965624610784,
#  'school_equivalent': 42.42379677255256,
#  'web_service': 41.85209432883669,
#  'tkprof_explain': 41.746228212181705,
#  'ether_channel': 40.25679654967281,
#  'rollback_segment': 40.06764461635353,
#  'mission_critical': 39.99674746823657,
#  'programming_language': 39.74993689051711,
#  'booz_allen': 38.1137136672851,
#  'information_security': 37.745323059144994,
#  'pune_maharashtra': 37.67044311015698,
#  'ethical_hacker': 37.31345177664975,
#  'draw_justifiable': 37.0823599213854,
#  'merrill_lynch': 36.570130189142716,
#  'thomson_reuters': 36.03140350877193,
#  'transportable_tablespace': 35.996401310554226,
#  'winston_salem': 35.642475171886936,
#  'ado_net': 35.56957344579116,
#  'agile_methodology': 35.51992158826659,
#  'credit_card': 34.998857670476404,
#  'country_rank': 34.591198339774074,
#  'ospf_bgp': 34.545474045474045,
#  'oem_grid': 34.51032717903088,
#  'western_governor': 34.135592527156135,
#  'hand_experience': 34.07265938980153,
#  'traceability_matrix': 34.02011218581764,
#  'test_indicative': 33.87037076823272,
#  'morgan_chase': 33.57901053659898,
#  'ids_ips': 33.43380511022044,
#  'goldman_sachs': 33.18349928876245,
#  'corpus_christi': 33.02857142857143,
#  'proof_concept': 32.90507970503301,
#  'saint_paul': 32.78246096594127,
#  'object_orient': 32.48214301236719,
#  'blue_shield': 31.855048877146633,
#  'stony_brook': 31.852941176470587,
#  'backup_restore': 31.82261199485657,
#  'entity_framework': 31.686532966617325,
#  'robert_half': 31.640071556350627,
#  'word_excel': 31.179907567787613,
#  'vulnerability_scan': 30.689160929761886,
#  'mobile_device': 30.62494207883533,
#  'human_resource': 30.163947340779384,
#  'bnp_paribas': 30.03125,
#  'flat_file': 29.46564838316911,
#  'information_system': 29.24086880707697,
#  'inbound_outbound': 28.959471074380165,
#  'security_analyst': 28.855735199351514,
#  'self_motivated': 28.29115755460862,
#  'user_account': 28.2114010989011,
#  'abu_dhabi': 28.0,
#  'process_improvement': 27.919642565779835,
#  'test_case': 27.8414406684558,
#  'cisco_asa': 27.815101595313696,
#  'desktop_laptop': 27.647872518947604,
#  'des_moines': 27.523809523809526,
#  'geek_squad': 27.47165458141068,
#  'use_rman': 27.46965251920217,
#  'load_balance': 27.37546298128668,
#  'sarbanes_oxley': 27.076923076923077,
#  'self_starter': 27.04701138487448,
#  'unidirectional_bidirectional': 27.04303724097957,
#  'bny_mellon': 26.814432989690722,
#  'raiser_edge': 26.546905916106056,
#  'cisco_router': 26.49449490888537,
#  'web_application': 26.37853903923945,
#  'quick_learner': 26.016015700717194,
#  'srvctl_crsctl': 25.56679909380438,
#  'datum_pump': 25.36263816765662,
#  'credit_union': 25.024631664075358,
#  'office_suite': 24.978694847819018,
#  'allen_hamilton': 24.704166666666666,
#  'apache_tomcat': 24.58717761242487,
#  'eigrp_ospf': 24.546504363696965,
#  'adobe_photoshop': 24.368269524300768,
#  'stp_rstp': 24.17966476091476,
#  'oil_gas': 23.958582589285715,
#  'cycle_sdlc': 23.71489130385626,
#  'loss_prevention': 23.663032512315272,
#  'password_reset': 23.515765817348985,
#  'materialize_view': 23.469827586206897,
#  'group_policy': 23.459397199920087,
#  'uttar_pradesh': 23.08091908091908,
#  'bare_metal': 23.07605633802817,
#  'gmail_com': 22.600944677441177,
#  'logical_physical': 22.4587903593262,
#  'table_index': 22.361047676927015,
#  'cum_laude': 22.153846153846153,
#  'nipr_sipr': 22.053504296455426,
#  'bug_fix': 22.04658831203679,
#  'salesforce_com': 22.019781737649513,
#  'crystal_report': 21.861767470380798,
#  'science_computer': 21.85956013418667,
#  'university_skill': 21.675002721176728,
#  'lean_sigma': 21.589579532436677,
#  'epolicy_orchestrator': 21.53156609696547,
#  'business_requirement': 21.52070348420782,
#  'spring_boot': 21.331558103778942,
#  'back_end': 21.291529301358388,
#  'full_stack': 21.168273171862783,
#  'mercedes_benz': 20.667989417989418,
#  'sql_loader': 20.60300223659981,
#  'bluecross_blueshield': 20.503125,
#  'span_tree': 20.113072651245005,
#  'gramm_leach': 20.045454545454547,
#  'embry_riddle': 20.0,
#  'kwame_nkrumah': 20.0,
#  'konica_minolta': 19.955654101995567,
#  'software_engineer': 19.94554927905459,
#  'false_positive': 19.89900839054157,
#  'I_ve': 19.616071428571427,
#  'santo_domingo': 19.53125,
#  'javascript_jquery': 19.258034300791557,
#  'jsp_servlet': 19.215942633678093,
#  'wolter_kluwer': 19.047619047619047,
#  'secret_clearance': 18.994622494245473,
#  'team_player': 18.98775969054145,
#  'detail_orient': 18.959173726661554,
#  'bmc_remedy': 18.85561464713954,
#  'recycle_bin': 18.762517680339464,
#  'domain_controller': 18.68747048228159,
#  'ddl_dml': 18.55391955835962,
#  'harley_davidson': 18.49906015037594,
#  'certification_accreditation': 18.336459637224333,
#  'nehru_technological': 18.23938775510204,
#  'noida_uttar': 18.206793206793208,
#  'leach_bliley': 18.181818181818183,
#  'trouble_ticket': 18.12969273412439,
#  'eli_lilly': 18.025185185185187,
#  'hat_linux': 17.993692352262812,
#  'design_implement': 17.74535282538719,
#  'endpoint_protection': 17.531246563454367,
#  'green_belt': 17.528296237149416,
#  'contingency_plan': 17.34298383174436,
#  'vrrp_glbp': 17.04093799682035,
#  'critical_thinking': 16.97957331077879,
#  'routing_protocol': 16.905417229409554,
#  'standby_database': 16.89081704334848,
#  'production_environment': 16.819685788803024,
#  'weekly_monthly': 16.72881086451329,
#  'hard_drive': 16.649620924986028,
#  'bachelor_art': 16.607801607729396,
#  'eau_claire': 16.563146997929607,
#  'professional_field': 16.468305360500565,
#  'hacker_ceh': 16.412722263961932,
#  'disk_space': 16.38578007189816,
#  'software_development': 16.365116225370176,
#  'anheuser_busch': 16.0,
#  'vmware_vsphere': 15.93315073488608,
#  'network_administrator': 15.88280523829684,
#  'expert_measure': 15.844055533875693,
#  'net_mvc': 15.78856377273398,
#  'change_management': 15.757057203018483,
#  'tool_like': 15.637813388939803,
#  'high_level': 15.474464434807246,
#  'excel_powerpoint': 15.422271761651237,
#  'nerc_cip': 15.35820895522388,
#  'zimmer_biomet': 15.347368421052632,
#  'scrummaster_csm': 15.173321144438406,
#  'eclipse_ide': 15.169536452803417,
#  'break_fix': 15.082803764179495,
#  'little_rock': 15.006069844408739,
#  'nat_pat': 14.772189941895412,
#  'single_sign': 14.767480891558005,
#  'business_intelligence': 14.75292279408857,
#  'status_report': 14.592471018038706,
#  'next_generation': 14.493329367423518,
#  'link_additional': 14.438199375177506,
#  'mule_esb': 14.359477124183007,
#  'desktop_support': 14.223448601686785,
#  'customer_satisfaction': 14.21088144548053,
#  'year_experience': 14.150639365102853,
#  'adobe_acrobat': 14.094395143728223,
#  'carbon_black': 14.05963827838828,
#  'security_control': 13.919314015180028,
#  'extensive_experience': 13.838652013179319,
#  'ltm_gtm': 13.822231567143257,
#  'install_configure': 13.815517277552818,
#  'communication_skill': 13.759257752270472,
#  'dhcp_dns': 13.521701275343363,
#  'notre_dame': 13.518543956043956,
#  'technical_skill': 13.352737457436632,
#  'datapump_conventional': 13.279855394883203,
#  'license_certification': 13.268461928760741,
#  'risk_management': 13.090044047641097,
#  'pitney_bowe': 13.066666666666666,
#  'sql_query': 13.027991682690852,
#  'unix_linux': 12.895816178726912,
#  'walt_disney': 12.820560747663551,
#  'iphone_ipad': 12.756316712569024,
#  'oracle_rac': 12.756164155876103,
#  'datum_warehouse': 12.756156013877657,
#  'design_develop': 12.75043648392529,
#  'rebuild_index': 12.742431717046761,
#  'css_javascript': 12.682487419945105,
#  'tiaa_cref': 12.552238805970148,
#  'tune_advisor': 12.503781723915841,
#  'enterprise_manager': 12.48895740054929,
#  'rest_api': 12.328770748644986,
#  'physical_logical': 12.294149589053838,
#  'cause_analysis': 12.218245564579044,
#  'windows_server': 12.131404770621002,
#  'resolve_issue': 12.125634641773798,
#  'cust_omer': 12.071428571428571,
#  'master_science': 11.920359554905069,
#  'include_limited': 11.826673225146779,
#  'oceanic_atmospheric': 11.805668016194332,
#  'dun_bradstreet': 11.71875,
#  'dbca_dbua': 11.618492018321273,
#  'ospf_eigrp': 11.565713007497555,
#  'john_deere': 11.561419025157234,
#  'security_policy': 11.516760471042419,
#  'continue_development': 11.480082336219326,
#  'due_diligence': 11.455181347150258,
#  'decision_make': 11.45454534207791,
#  'business_analyst': 11.421846551816833,
#  'sencha_touch': 11.32017725122836,
#  'assessment_authorization': 11.299319204319723,
#  'daily_basis': 11.203961039750888,
#  'account_payable': 11.158958092843008,
#  'overland_park': 11.153234960272417,
#  'symantec_endpoint': 11.151366484374725,
#  'education_associate': 11.124115874873697,
#  'privacy_threshold': 11.047718820386569,
#  'eden_prairie': 11.021348169232759,
#  'societe_generale': 11.0,
#  'development_life': 10.997258772299064,
#  'requirement_gather': 10.87735113687622,
#  'strategic_planning': 10.834591049151632,
#  'cain_abel': 10.760784313725491,
#  'regular_basis': 10.52295235276709,
#  'health_care': 10.500453245258544,
#  'wilke_barre': 10.393939393939394,
#  'license_comptia': 10.376671228550373,
#  'csu_dsu': 10.359473684210526,
#  'school_diploma': 10.306762497471352,
#  'business_continuity': 10.303765162029062,
#  'software_hardware': 10.239916386160742,
#  'ernst_young': 10.189473684210526,
#  'extract_transform': 10.160277854331405,
#  'jira_confluence': 10.156075315504573,
#  'cost_saving': 10.150252513880222,
#  'security_assessment': 10.137998488194043,
#  'becton_dickinson': 10.1010101010101,
#  'driver_license': 10.074960071948023,
#  'onshore_offshore': 10.031943689408354,
#  'nest_formulas': 9.97120949074074,
#  'gurgaon_haryana': 9.940359477124183,
#  'rio_janeiro': 9.924050632911392,
#  'barne_noble': 9.846498599439776,
#  'thermo_fisher': 9.827044025157234,
#  'fault_tolerant': 9.813721035892776,
#  'wide_range': 9.774637255473493,
#  'internally_externally': 9.766684753119913,
#  'rajiv_gandhi': 9.756756756756756,
#  'call_center': 9.755834692570883,
#  'rsa_archer': 9.74570448722768,
#  'caracas_distrito': 9.644927536231885,
#  'vmware_esxi': 9.634466029978027,
#  'cumulative_differential': 9.60334623264284,
#  'privacy_impact': 9.602203398722637,
#  'schofield_barrack': 9.6,
#  'html_javascript': 9.554102758456692,
#  'juniper_srx': 9.486022404071653,
#  'unit_test': 9.408593277785807,
#  'anne_arundel': 9.291521486643438,
#  'backup_exec': 9.21785425042435,
#  'auto_scaling': 9.16825583101071,
#  'selenium_webdriver': 9.138449983309224,
#  'dependency_injection': 9.125040316205533,
#  'service_desk': 9.100060393194543,
#  'belo_horizonte': 9.090909090909092,
#  'cradle_grave': 9.036890645586297,
#  'ponte_vedra': 9.0,
#  'pap_chap': 8.972307692307693,
#  'monte_carlo': 8.827586206896552,
#  'law_enforcement': 8.812932690422988,
#  'low_voltage': 8.763433667781493,
#  'command_line': 8.708343875528842,
#  'theta_kappa': 8.699346405228757,
#  'coso_cobit': 8.69270890323522,
#  'verita_netbackup': 8.689122668768059,
#  'information_skill': 8.671634973052699,
#  'lexis_nexis': 8.642857142857142,
#  'io_android': 8.641515091246594,
#  'honorable_discharge': 8.628331332533014,
#  'owing_mill': 8.620842572062084,
#  'fine_grain': 8.618383296836065,
#  'bottle_neck': 8.587096774193549,
#  'silver_spring': 8.545616283839212,
#  'vtp_stp': 8.506050129645635,
#  'make_recommendation': 8.460780315811435,
#  'dmvs_dmfs': 8.427439886845827,
#  'force_com': 8.352728339371646,
#  'riddle_aeronautical': 8.331428571428571,
#  'information_assurance': 8.271067258362146,
#  'flower_mound': 8.271043771043772,
#  'framework_rmf': 8.263807824867074,
#  'pivottable_conditional': 8.238226153478365,
#  'conventional_export': 8.179756491595965,
#  'workload_repository': 8.127768601596655,
#  'snow_flake': 8.116883116883116,
#  'citrix_xenapp': 8.073854366885078,
#  'pivot_table': 8.02932064784091,
#  'continuous_monitoring': 8.025129982668977,
#  'vmware_esx': 8.024562957810657,
#  'ladoke_akintola': 8.0,
#  'olabisi_onabanjo': 8.0,
#  'node_rac': 7.993418823949691,
#  'plan_action': 7.910231404327974,
#  'abercrombie_fitch': 7.875739644970414,
#  'procedure_trigger': 7.8253684705361835,
#  'ticket_system': 7.823584288908711,
#  'mcafee_epo': 7.802208054734878,
#  'level_agreement': 7.793566512940599,
#  'top_secret': 7.778629866738874,
#  'staten_island': 7.746543778801843,
#  'amm_asmm': 7.74453781512605,
#  'general_ledger': 7.7244328718160595,
#  'des_moine': 7.714285714285714,
#  'morgan_stanley': 7.689477124183006,
#  'provide_technical': 7.61695515977224,
#  'johnson_johnson': 7.563091557669441,
#  'aliso_viejo': 7.5,
#  'react_redux': 7.473011155876447,
#  'tortoise_svn': 7.459337008230763,
#  'across_multiple': 7.443977431134966,
#  'sailpoint_iiq': 7.43855421686747,
#  'problem_solver': 7.436707483476057,
#  'cold_backup': 7.39270147501025,
#  'lesson_learn': 7.3585741893111445,
#  'switchover_switchback': 7.347222222222222,
#  'end_end': 7.296949563667206,
#  'interpersonal_skill': 7.265289363998266,
#  'fort_collins': 7.198534798534799,
#  'business_unit': 7.179413464156089,
#  'development_team': 7.164278990949993,
#  'dodd_frank': 7.133116883116883,
#  'vmstat_iostat': 7.130864197530864,
#  'sikkim_manipal': 7.117647058823529,
#  'abn_amro': 7.111111111111111,
#  'terre_haute': 7.111111111111111,
#  'bachelor_degree': 7.0812097322708825,
#  'acceptance_testing': 7.048515899614032,
#  'short_term': 7.048336860943334,
#  'backlog_grooming': 7.046128659476117,
#  'vulnerability_assessment': 7.026476614401407,
#  'novell_netware': 6.984516745106064,
#  'ford_motor': 6.967913075711241,
#  'version_control': 6.933144402426254,
#  'new_hire': 6.921673471264421,
#  'tcp_udp': 6.898561455468585,
#  'open_source': 6.890301882339293,
#  'lacp_pagp': 6.86,
#  'ipv_ipv': 6.838020647917408,
#  'ipx_spx': 6.808510638297872,
#  'dress_rehearsal': 6.789620535714286,
#  'act_liaison': 6.77284042055307,
#  'fabric_extender': 6.763897696047347,
#  'greenwood_village': 6.744346116027532,
#  'inter_vlan': 6.725674456083803,
#  'fall_church': 6.715029761904762,
#  'vice_versa': 6.713107287449393,
#  'special_publication': 6.705527084237314,
#  'table_space': 6.670797931403596,
#  'microsoft_exchange': 6.666324226348328,
#  'user_interface': 6.642967396853678,
#  'bulk_insert': 6.637638062871708,
#  'penetration_testing': 6.635271672247195,
#  'plan_ssp': 6.61196624110543,
#  'link_certification': 6.584746782284513,
#  'procedure_function': 6.578853297500778,
#  'amazon_web': 6.572573186637033,
#  'lake_city': 6.56967860289517,
#  'conditional_split': 6.563681625513019,
#  'party_vendor': 6.531825741176033,
#  'business_process': 6.496143999182161,
#  'alert_log': 6.486458098823439,
#  'business_administration': 6.463127342395927,
#  'ssis_ssrs': 6.456348681532009,
#  'information_technical': 6.412632461583909,
#  'wire_shark': 6.409134402203085,
#  'larsen_toubro': 6.4,
#  'prove_ability': 6.369066202228489,
#  'dell_poweredge': 6.364278053054565,
#  'continuous_improvement': 6.311738871320847,
#  'product_owner': 6.30101535094974,
#  'wal_mart': 6.288236292649805,
#  'switch_router': 6.25390395725319,
#  'berkshire_hathaway': 6.230769230769231,
#  'military_service': 6.198878747998088,
#  'ensure_proper': 6.198751552790576,
#  'hyderabad_andhra': 6.197846271375683,
#  'camp_lejeune': 6.176943699731903,
#  'remote_desktop': 6.172100438011042,
#  'cocoa_touch': 6.149440798217097,
#  'walnut_creek': 6.145536384096024,
#  'kwazulu_natal': 6.125,
#  'nine_four': 6.125,
#  'sql_trace': 6.0895591745638145,
#  'oracle_enterprise': 6.0894541899043455,
#  'bask_ridge': 6.080459770114943,
#  'annapolis_junction': 6.080445544554456,
#  'breakdown_structure': 6.07121493891876,
#  'hit_ratio': 6.067971946230275,
#  'access_control': 6.066994339468872,
#  'ralph_lauren': 6.02262443438914,
#  'single_instance': 6.016514080104472,
#  'ocr_voting': 6.016042780748663,
#  'adekunle_ajasin': 6.0,
#  'banca_comercio': 6.0,
#  'm_a': 6.0,
#  'obafemi_awolowo': 6.0,
#  'sudler_hennessey': 6.0,
#  'tory_burch': 6.0,
#  'design_development': 5.982726925090573,
#  'medicare_medicaid': 5.9696013289036545,
#  'omb_circular': 5.917199222006113,
#  'role_responsibility': 5.897731182174003,
#  'estee_lauder': 5.882352941176471,
#  'neiman_marcus': 5.882352941176471,
#  'database_administration': 5.877289626620562,
#  'aldridge_pite': 5.818181818181818,
#  'bon_secour': 5.818181818181818,
#  'look_feel': 5.813288477712363,
#  'alcatel_lucent': 5.798533724340176,
#  'minimal_supervision': 5.791856180917291,
#  'provide_support': 5.777246290881366,
#  'cpu_psu': 5.727590673575129,
#  'well_verse': 5.725039619651347,
#  'wide_variety': 5.690265100503765,
#  'incremental_cumulative': 5.665587077071446,
#  'answer_question': 5.600358422939068,
#  'application_use': 5.599436873299624,
#  'core_competency': 5.5977523641035365,
#  'eagle_scout': 5.592436974789916,
#  'conference_room': 5.590597823011187,
#  'database_object': 5.501695456306254,
#  'operate_ato': 5.498244998244998,
#  'grand_rapid': 5.477369365964282,
#  'walter_reed': 5.458888888888889,
#  'regular_interval': 5.454666052253082,
#  'oracle_sql': 5.451568505000949,
#  'creve_coeur': 5.444444444444445,
#  'geographically_disperse': 5.43236074270557,
#  'indore_madhya': 5.359375,
#  'redo_log': 5.358128139581375,
#  'tyson_corner': 5.353443941679235,
#  'web_base': 5.338858666853648,
#  'hong_jung': 5.333333333333333,
#  'database_use': 5.332846681892059,
#  'chapel_hill': 5.332170050761421,
#  'glen_burnie': 5.3088235294117645,
#  'newport_news': 5.2852201257861635,
#  'sga_pga': 5.241758966244726,
#  'hrs_min': 5.23862973760933,
#  'load_balancing': 5.230639872193727,
#  'awr_ash': 5.21442430808628,
#  'self_employ': 5.209363479829609,
#  'search_engine': 5.209343682270345,
#  'sns_sqs': 5.202921562400762,
#  'charles_schwab': 5.194594594594594,
#  'service_branch': 5.191655730004634,
#  'veer_narmad': 5.142857142857143,
#  'sonic_wall': 5.142719149963777,
#  'pta_pia': 5.133160179001102,
#  'packet_tracer': 5.1219262806125,
#  'design_pattern': 5.120040292781926,
#  'psu_patch': 5.032529718178176,
#  'startup_shutdown': 5.028597285067874,
#  'uni_directional': 5.019607843137255,
#  'dml_ddl': 5.016214511041009,
#  'costa_rica': 5.008695652173913,
#  'upper_marlboro': 5.006694203104971,
#  'write_verbal': 5.004062557454051,
#  'extensive_knowledge': 5.003801972759762,
#  'blueconnection_blueenroll': 5.0,
#  'cerebral_palsy': 5.0,
#  'dbu_rlu': 5.0,
#  'fastcopy_fastunload': 5.0,
#  'kuala_lumpur': 5.0,
#  'meng_martial': 5.0,
#  'nederland_loodswezen': 5.0,
#  'associate_degree': 4.985957096332063,
#  'purchase_order': 4.943991123224235,
#  'window_vista': 4.924587494912176,
#  'jesus_christ': 4.875457875457876,
#  'call_rotation': 4.869991613435858,
#  'tso_ispf': 4.824019759184933,
#  'dbms_stat': 4.820307609764821,
#  'rev_fip': 4.815141550596052,
#  'asa_firewall': 4.808579633478468,
#  'plug_in': 4.804247010007322,
#  'project_plan': 4.798887915623813,
#  'burp_suite': 4.797418451562193,
#  'downer_grove': 4.794326241134752,
#  'change_request': 4.7930226277325785,
#  'continuous_integration': 4.784596582466568,
#  'coral_gable': 4.780327868852459,
#  'use_sql': 4.779525339933735,
#  'johns_hopkin': 4.776119402985074,
#  'health_check': 4.764014954768738,
#  'bausch_lomb': 4.763888888888889,
#  'vgs_lvs': 4.7407407407407405,
#  'babcock_wilcox': 4.733766233766234,
#  'mozilla_firefox': 4.726890756302521,
#  'user_story': 4.71531987749093,
#  'access_point': 4.711272626132122,
#  'video_conferencing': 4.6742364171691655,
#  'shopping_cart': 4.634085213032582,
#  'dead_lock': 4.613395276809911,
#  'exxon_mobil': 4.608,
#  'school_district': 4.595123418084325,
#  'agile_waterfall': 4.58733295074867,
#  'waterfall_agile': 4.58733295074867,
#  'non_profit': 4.583096265863196,
#  'ethical_hack': 4.582785257117634,
#  'automatic_workload': 4.579939234794732,
#  'mongoowl_mongovue': 4.571428571428571,
#  'verbal_write': 4.567072786499262,
#  'personally_identifiable': 4.560703812316715,
#  'active_passive': 4.541648804472402,
#  'saint_petersburg': 4.5380379021063435,
#  'ftk_imager': 4.524886877828054,
#  'init_ora': 4.5193422578265,
#  'tablespace_tts': 4.513266015044799,
#  'vcp_dcv': 4.5131578947368425,
#  'tacac_radius': 4.511647783740807,
#  'dbpromo_hpsd': 4.5,
#  'nonverbal_cue': 4.5,
#  'king_prussia': 4.49438202247191,
#  'apply_patch': 4.477553773318445,
#  'excellent_communication': 4.473881919621255,
#  'problem_resolution': 4.467763989781905,
#  'rancho_cucamonga': 4.461873638344227,
#  'oracle_dba': 4.452574175806197,
#  'adr_asmcmd': 4.451566951566951,
#  'cpu_memory': 4.418783118015221,
#  'pstack_pmap': 4.408163265306122,
#  'sacred_heart': 4.402439024390244,
#  'materialized_view': 4.39180537772087,
#  'rpm_yum': 4.389044943820225,
#  'windows_mac': 4.383868018146007,
#  'highly_motivated': 4.381856561429327,
#  'system_security': 4.373882516831894,
#  'cat_cat': 4.344724979695774,
#  'blue_cross': 4.3397721537613,
#  'create_maintain': 4.3355837924568545,
#  'sherwin_williams': 4.329004329004329,
#  'configure_maintain': 4.313953994083531,
#  'catalyst_switch': 4.308684553269081,
#  'settling_dispute': 4.306902654867256,
#  'advice_adequacy': 4.302297329150877,
#  'apex_class': 4.300401740527793,
#  'rsa_envision': 4.288488816148391,
#  'veteran_affair': 4.284127088685418,
#  'blue_coat': 4.283468578977166,
#  'physical_virtual': 4.282357090391917,
#  'window_window': 4.264956153557254,
#  'encryption_tde': 4.262838406216292,
#  'gorilla_mux': 4.234567901234568,
#  'mongostat_mongotop': 4.234567901234568,
#  'norton_ghost': 4.233313586097946,
#  'procter_gamble': 4.231404958677686,
#  'microsoft_word': 4.2112776033907435,
#  'factor_authentication': 4.1910450951339895,
#  'bala_cynwyd': 4.166666666666667,
#  'barranquilla_atlntico': 4.166666666666667,
#  'bharati_vidyapeeth': 4.166666666666667,
#  'greenberg_traurig': 4.166666666666667,
#  'iboutlet_ibactionsin': 4.166666666666667,
#  'oilwell_varco': 4.166666666666667,
#  'schering_plough': 4.166666666666667,
#  'triger_rowversion': 4.166666666666667,
#  'madhya_pradesh': 4.145748987854251,
#  'duty_include': 4.144828765572206,
#  'naive_baye': 4.142045454545454,
#  'relate_issue': 4.138233826708798,
#  'functional_team': 4.120540943481057,
#  'local_area': 4.116982654296087,
#  'codedeploy_codepipeline': 4.114285714285714,
#  'apttus_cpq': 4.106247661803217,
#  'clear_concise': 4.105376593279258,
#  'table_view': 4.102985704661249,
#  'sigma_green': 4.091092753883451,
#  'fine_tune': 4.089973557063927,
#  'recovery_strategy': 4.087657518563836,
#  'cron_job': 4.084635717301477,
#  'solve_problem': 4.07879587477833,
#  'sql_profiler': 4.061500932159226,
#  'urbana_champaign': 4.061022120518688,
#  'mac_osx': 4.058359714007752,
#  'institute_technology': 4.052300472634568,
#  'network_infrastructure': 4.045028957538013,
#  'administrative_assistant': 4.033580266075388,
#  'conditional_nest': 4.033298220973783,
#  'daily_weekly': 4.026532261541859,
#  'bonaire_eustatius': 4.0,
#  'emark_enterprize': 4.0,
#  'emcon_noncon': 4.0,
#  'giesecke_devrient': 4.0,
#  'jtac_physion': 4.0,
#  'koneru_lakshmaiah': 4.0,
#  'ngetla_mbonuh': 4.0,
#  'ocrdump_ocrcheck': 4.0,
#  'pepper_snapple': 4.0,
#  'phnom_penh': 4.0,
#  'sqlperf_logspace': 4.0,
#  'sscpac_sdren': 4.0,
#  'techon_dater': 4.0,
#  'internet_explorer': 3.971186847327499,
#  'electrical_engineering': 3.947840990234359,
#  'spam_filter': 3.941135217320564,
#  'management_system': 3.9362795561368116,
#  'big_ltm': 3.9347719688542826,
#  'awr_automatic': 3.9284878324387584,
#  'user_acceptance': 3.9236008132492506,
#  'lang_lasalle': 3.9183673469387754,
#  'cisco_catalyst': 3.9177162863212405,
#  'square_foot': 3.917671783625731,
#  'net_framework': 3.917442460932087,
#  'solaris_aix': 3.8965528501610818,
#  'interim_opatch': 3.894900736266455,
#  'import_utility': 3.893861737178853,
#  'fault_tolerance': 3.8923415492957747,
#  'jaipur_rajasthan': 3.8921985815602835,
#  'solutions_inc': 3.8863391693580374,
#  'emotional_appeal': 3.881544657664061,
#  'page_layout': 3.871507267288933,
#  'cisco_switch': 3.860357197604987,
#  'data_entry': 3.859470188240947,
#  'synchronous_asynchronous': 3.8593481989708405,
#  'accellion_watchdox': 3.857142857142857,
#  'ibm_aix': 3.8468290217428094,
#  'english_spanish': 3.8456583254006547,
#  'hint_wherever': 3.840917874396135,
#  'service_pack': 3.827343000510291,
#  'arcsight_esm': 3.816410697274565,
#  'wappalyzer_flagfox': 3.811111111111111,
#  'sense_urgency': 3.809826589595376,
#  'web_api': 3.789151181988173,
#  'home_depot': 3.7872726002874546,
#  'reset_password': 3.7640156503483158,
#  'domestically_internationally': 3.7616326530612243,
#  'sql_plus': 3.757041987315072,
#  'http_https': 3.749470275271802,
#  'positive_attitude': 3.7158267457180503,
#  'bangalore_karnataka': 3.7066200466200465,
#  'tech_mahindra': 3.703827126563144,
#  'web_page': 3.692184488040119,
#  'yellow_belt': 3.6797210300429186,
#  'powershell_script': 3.65299623661102,
#  'ansible_playbook': 3.6504895700298,
#  'improve_performance': 3.6500079183789365,
#  'contra_costa': 3.6231884057971016,
#  'rman_backup': 3.6065394192516815,
#  'server_database': 3.6057674992573943,
#  'jquery_ajax': 3.6039005744605035,
#  'beckman_coulter': 3.6,
#  'multiplexing_combiner': 3.6,
#  'rpo_rto': 3.592982456140351,
#  'jasmine_karma': 3.588516746411483,
#  'vlan_vtp': 3.5802428043712484,
#  'responsibility_include': 3.5754953549425705,
#  'sardar_patel': 3.5729166666666665,
#  'madurai_kamaraj': 3.5714285714285716,
#  'design_implementation': 3.570204845242761,
#  'forescout_counteract': 3.5676532769556024,
#  'remedy_ticket': 3.5609462422438938,
#  'program_manager': 3.5135312193585952,
#  'iaas_paas': 3.5081130055184913,
#  'endure_freedom': 3.5079545454545453,
#  'chick_fil': 3.5,
#  'liberal_art': 3.498670160239108,
#  'sri_lanka': 3.492845786963434,
#  'role_privilege': 3.4860774145977858,
#  'key_achievement': 3.480246355127179,
#  'good_knowledge': 3.479395077476414,
#  'tkprof_statspack': 3.463966029990785,
#  'visualforce_page': 3.4628402337489184,
#  'spring_mvc': 3.4555018961926334,
#  'data_warehouse': 3.4438793492833017,
#  'statspack_awr': 3.43689527113772,
#  'boehringer_ingelheim': 3.4285714285714284,
#  'mongodump_mongorestore': 3.4285714285714284,
#  'liberty_mutual': 3.421044487427466,
#  'production_support': 3.4156849640011653,
#  'classify_unclassified': 3.414281744929147,
#  'fast_learner': 3.413944110546052,
#  'gap_analysis': 3.3912702211834937,
#  'vpn_tunnel': 3.3908310615641115,
#  'account_receivable': 3.3897986778846154,
#  'dobbs_ferry': 3.375,
#  'pvst_rpvst': 3.370686926242482,
#  'logical_backup': 3.3675270124638352,
#  'lance_corporal': 3.3581681476418317,
#  'multitenant_container': 3.343347754816865,
#  'area_network': 3.338122807394431,
#  'identity_access': 3.336853396954842,
#  'rman_duplicate': 3.336353068505231,
#  'sql_sql': 3.3276850946147682,
#  'network_security': 3.3240599315052237,
#  'orient_programming': 3.3216424710870562,
#  'log_file': 3.3188003336554197,
#  'repository_awr': 3.3140277044304223,
#  'system_admin': 3.3069589585682007,
#  'query_optimization': 3.302084614308877,
#  'aw_cloud': 3.302061469405997,
#  'grant_revoke': 3.2976092333058533,
#  'cluster_rac': 3.2934156077755636,
#  'united_airlines': 3.279662099581617,
#  'expeience_semantec': 3.272727272727273,
#  'seguridad_informtica': 3.272727272727273,
#  'add_remove': 3.2678753783279006,
#  'college_skill': 3.263221624028507,
#  'project_coordinator': 3.2383898183713553,
#  'mobile_app': 3.2315464758951387,
#  'enterprise_wide': 3.2174892439097684,
#  'iron_mountain': 3.2108551105613112,
#  'printer_scanner': 3.200186574948886,
#  'cote_voire': 3.2,
#  'gainwell_commosales': 3.2,
#  'harte_hanks': 3.2,
#  'jiao_tong': 3.2,
#  'kelsey_seybold': 3.2,
#  'marta_abreu': 3.2,
#  'newell_rubbermaid': 3.2,
#  'plusnet_rpn': 3.2,
#  'proudyogiki_vishwavidyalaya': 3.2,
#  'vxdmp_vcfs': 3.2,
#  'resource_allocation': 3.1885897615531915,
#  'myers_squibb': 3.1779661016949152,
#  'mocha_chai': 3.1666666666666665,
#  'kick_meeting': 3.164365444169892,
#  'real_application': 3.164355879562112,
#  'white_glove': 3.1586658955080007,
#  'monday_friday': 3.154022988505747,
#  'taco_bell': 3.1514723678902783,
#  'linux_unix': 3.1424372779009806,
#  'san_nas': 3.136470682795483,
#  'bowling_green': 3.13291687283523,
#  'code_review': 3.1312524054761997,
#  'professional_pmp': 3.1309321681634072,
#  'los_alamos': 3.1296296296296298,
#  'harland_clarke': 3.125,
#  'occidental_descuento': 3.125,
#  'van_nuy': 3.125,
#  'face_face': 3.120377218934911,
#  'asa_firewalls': 3.1196179502728927,
#  'cellcli_dcli': 3.118181818181818,
#  'aon_hewitt': 3.1177272727272727,
#  'server_sql': 3.1063257136990226,
#  'lite_speed': 3.0866843865214784,
#  'subnette_vlsm': 3.080197019449356,
#  'captiva_inputaccel': 3.0625,
#  'apply_protocol': 3.061957760073779,
#  'scatter_plot': 3.061529614721104,
#  'guard_broker': 3.055259481554302,
#  'university_bachelor': 3.053348530750808,
#  'gfi_languard': 3.051388888888889,
#  'it_d': 3.0476190476190474,
#  'conflict_resolution': 3.0423558085271374,
#  'derive_column': 3.0237701934652965,
#  'new_feature': 3.015726170223466,
#  'datum_analysis': 3.0036652135948656,
#  'aesthetically_pleasing': 3.0,
#  'aisherwood_fastmail': 3.0,
#  'autoscriptor_inferno': 3.0,
#  'bluekey_seidor': 3.0,
#  'boart_longyear': 3.0,
#  'centum_adetel': 3.0,
#  'clar_ifying': 3.0,
#  'computacenter_fusionstorm': 3.0,
#  'cvg_ferrominera': 3.0,
#  'diffie_hellman': 3.0,
#  'dnsenum_knockpy': 3.0,
#  'elmsoft_framescript': 3.0,
#  'fang_kuai': 3.0,
#  'federico_villarreal': 3.0,
#  'foglightnms_foglightfms': 3.0,
#  'fuquay_varina': 3.0,
#  'gfirst_ncrcg': 3.0,
#  'godiva_chocolatier': 3.0,
#  'goldey_beacom': 3.0,
#  'gustavus_adolphus': 3.0,
#  'hdam_hidam': 3.0,
#  'jomo_kenyatta': 3.0,
#  'kor_jpn': 3.0,
#  'llq_wre': 3.0,
#  'luigi_bocconi': 3.0,
#  'mongoexport_mongoimport': 3.0,
#  'nepool_nyiso': 3.0,
#  'pdoris_pmode': 3.0,
#  'pritchard_jerden': 3.0,
#  'quintana_roo': 3.0,
#  'rickmers_linie': 3.0,
#  'sanchar_nigam': 3.0,
#  'sturm_ruger': 3.0,
#  'toppan_photomasks': 3.0,
#  'txm_rxm': 3.0,
#  'varchetti_olivi': 3.0,
#  'wapple_feng': 3.0,
#  'cpr_aed': 2.993212669683258,
#  'rational_rose': 2.992282082324455,
#  'carnegie_mellon': 2.983569587628866,
#  'certify_professional': 2.9794292527863933,
#  'eventkit_cfnetwork': 2.9761904761904763,
#  'fort_gordon': 2.9701760104302477,
#  'laptop_desktop': 2.966740500115401,
#  'multimillion_dollar': 2.962074137561603,
#  'whatsup_gold': 2.9598496240601504,
#  'hld_lld': 2.956896551724138,
#  'standard_operating': 2.9564428656236235,
#  'ash_addm': 2.9462313612313613,
#  'increase_productivity': 2.9445475411200848,
#  'reporting_service': 2.9424165786474337,
#  'inheritance_polymorphism': 2.939516129032258,
#  'production_database': 2.9370021948700447,
#  'deep_dive': 2.9360386779741616,
#  'mutually_beneficial': 2.933134328358209,
#  'windows_linux': 2.922807009815754,
#  'unit_testing': 2.916633820925835,
#  'cut_edge': 2.916296439628483,
#  'merger_acquisition': 2.9135536398467434,
#  'acceptance_criterion': 2.8841716658975542,
#  'glen_ellyn': 2.8823529411764706,
#  'nucleic_acid': 2.8823529411764706,
#  'train_new': 2.871489278897258,
#  'failover_cluster': 2.863611941319441,
#  'voip_phone': 2.8601509885225687,
#  'intrusion_prevention': 2.860123552123552,
#  'wily_introscope': 2.857142857142857,
#  'comms_ocm': 2.8421052631578947,
#  'ciudad_mxico': 2.834710743801653,
#  'remote_access': 2.828966374638283,
#  'black_box': 2.820794900002821,
#  'informatica_powercenter': 2.810889105479749,
#  'operating_procedure': 2.8084498105589573,
#  'panera_bread': 2.8051948051948052,
#  'accordance_nist': 2.7996660146844397,
#  'asset_management': 2.798802626025341,
#  'tight_deadline': 2.795144658753709,
#  'mountlake_terrace': 2.782608695652174,
#  'ppp_hdlc': 2.7816059757236227,
#  'brotherhood_laurence': 2.7777777777777777,
#  'redhat_linux': 2.775002775002775,
#  'cron_tab': 2.769166182264419,
#  'chandigarh_chandigarh': 2.7648,
#  'nunit_moq': 2.7528188865398167,
#  ...}

# %%
# We observe many different collocations.

len(collocations)
# Out:
# 1419840

# %%
# Join the X most common collocations in all documents by an underscore, corresponding to a score > 50.

l_begin = []
l_end = []

for coll in collocations:
    if collocations[coll] > 50:
        begin, end = coll.split('_')   
        l_begin.append(begin)
        l_end.append(end)

def join_collocations(x):
    l = x.split()
    
    for i in range(len(l)-1):
        
        if l[i] in l_begin:            
            if l[i+1] == l_end[l_begin.index(l[i])]:
                join = '_'.join([l[i], l[i+1]])
                l[i] = join
                l[i+1] = ' '
                
    return " ".join(l)

df_resume['Resume_lemma'] = df_resume['Resume_lemma'].apply(join_collocations)

# %%
# Remove leading/trailing/double white spaces.

df_resume['Resume_lemma'] = df_resume['Resume_lemma'].apply(remove_empty)

# Inspect the output.

df_resume['Resume_lemma'][0]
# Out:
# 'family private care llc lawrenceville self motivated production sql_server database_administrator possess strong analytical problem_solve skill experience include sql_server ssis well cluster mirroring high_availability solution environment proficient database backup_recovery performance_tune maintenance task security consolidation confident would make beneficial addition company course career thus far design database fit variety need successfully ensure security database problem_solve order meet back end front_end need instal test new version database management system customize installed application meticulously monitor performance smooth front_end experience possible year work database work_experience database_administrator family private care llc roswell present confirm backup make successfully save secure location planning backup_recovery database information maintain archive datum back restore database contact database vendor technical_support generate various report query database per need manage monitor datum replication act liaison user high_availability disaster_recovery log check high_availability disaster_recovery process log depend solution log_shipping cluster replication database mirroring cdp etc use dictate need check correcting error make necessary modification modify exist database database management system direct programmer analyst make change work part project team coordinate database development see termite project scope limitation train user answer question approve schedule plan supervise installation test new product improvement computer system installation new database review procedure database management system manual make change database select enter code monitor database performance create production database check backup failure alert correct error rerun backup review average duration backup significant change occur investigate time happen due network low bandwidth validate backup file use restore verify create job take care task send notification fail verify backup monitoring backup log history cleaning design find newly add database define backup plan verify free space drive server significant variance free space day research cause free space fluctuation resolve necessary often time log file grow monthly job automate job job run every hour report drive less free space design ssrs report showcase review delta value confirm server database run fine usually enterprise database environment third_party tool use monitor server database monitor design native sql_server solution use sql code maintenance plan run min min send email dba team able connect database instance design native script use sql monitor replication mirroring log_shipping database_administrator incomm alpharetta alpharetta responsible administer maintain database server production test environment analyze current database environment determine recommend database maintenance security microsoft sql_server good_practice monitor troubleshoot production environment use idera sqldm create maintain documentation dba standard operating procedure ensure code change make production environment sox compliance deploy analysis migrate datum use etl sql_server database support customer implementation work closely infrastructure team patch hardware upgrade ensure production test server date apply windows sql_server patch upgrade server require sql_server sql_server completes database administration maintenance project require provide call support need coordinate configure new node production server cluster high_availability periodically restore backup file test environment check corruption review security performance disk space recommend corrective_action need assist application team creation database construction query modification database table troubleshoot datum issue monitor server resource utilization disk space memory cpu etc create execute migration decommission plan database within month project window education_bachelor science lead city  ...

# %% [markdown]
# ## 9. Store output

# %%
# Output final dataframe.

df_resume.to_csv('Resumes_cleaned.csv', index = False)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ## Job descriptions - Cleaning

# %% [markdown]
# To find suitable matches between applications and job descriptions, several aspects need to be taken into account, including:
#
# * Place of work;
# * Salary;
# * Required hard and soft skills;
# * Experience level.
#
# ### Steps (similar to Ch. 1)
#
# 1. Remove punctuation and URLs;
# 2. Convert number words to numeric form (for homogeneity) and then remove all digits;
# 3. Remove stopwords;
#     - Remove words in extended nltk stopwords set
#     - Remove words with length $<= 2$
# 4. Remove months
# 5. Remove geolocations
# 6. Lemmatize;
# 7. Join collocations.

# %% [markdown]
# ## 1. Remove punctuation and URLs

# %%
# Transform all descriptions into lower case (and store the output in a new column).

df_descriptions['Description_cleaned'] = df_descriptions['FullDescription'].str.lower()

# Remove URLs using RegEx.

website_re = "((http|ftp|https):\/\/)?([\b\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:\/~+#-]*[\w@?^=%&\/~+#-])"

def remove_website_descriptions(x):
    return re.sub(website_re, '', x)

df_descriptions['Description_cleaned'] = df_descriptions['Description_cleaned'].apply(remove_website_descriptions)

# %%
# Replace '&' signs by the word 'and'.

df_descriptions['Description_cleaned'] = df_descriptions['Description_cleaned'].str.\
    replace('[&]', ' and ' ,regex = True)

# Remove punctuation using RegEx.

df_descriptions['Description_cleaned'] = df_descriptions['Description_cleaned'].str.\
    replace('[{}]'.format(my_punctuation), ' ' , regex = True)

# Inspect output.

df_descriptions['Description_cleaned'][0][:200]
# Out:
# 'job title  senior support network analyst location  london  westend salary       this is an excellent opportunity to join a dynamic and intelligent team who will really test your skills and experience'

# %% [markdown]
# ## 2. Convert number words to digits (and remove them)

# %%
# Replace the number words by digit counterparts.

df_descriptions['Description_cleaned'] = df_descriptions['Description_cleaned'].apply(replace_num_words)

# Remove all digits.

df_descriptions['Description_cleaned'] = df_descriptions['Description_cleaned'].replace('\d+', ' ', regex = True)

# Inspect output.

df_descriptions['Description_cleaned'][0][:200]
# Out:
# 'job title senior support network analyst location london westend salary this is an excellent opportunity to join a dynamic and intelligent team who will really test your skills and experience it will '

# %% [markdown]
# ## 3. Remove stopwords and short words

# %%
# Remove all stopwords from the job descriptions.

df_descriptions['Description_cleaned'] = df_descriptions['Description_cleaned'].\
            apply(lambda x: " ".join(x for x in x.split() if x not in all_stopwords))

# Remove words with length <= 2.

df_descriptions['Description_cleaned'] = df_descriptions['Description_cleaned'].apply(remove_short_words)

# Remove leading/trailing/double white spaces.

df_descriptions['Description_cleaned'] = df_descriptions['Description_cleaned'].apply(remove_empty)

# Inspect output.

df_descriptions['Description_cleaned'][0][:200]
# Out:
# 'job title senior support network analyst location london westend salary excellent opportunity join dynamic intelligent team really test skills experience autonomous role give great platform progress c'

# %% [markdown]
# ## 4. Remove months

# %%
# Remove all months from the resumes.

df_descriptions['Description_cleaned'] = df_descriptions['Description_cleaned'].\
            apply(lambda x: " ".join(x for x in x.split() if x not in months))

# %% [markdown]
# ## 5. Remove common geolocations

# %%
nlp = spacy.load('en_core_web_sm', disable = ['tagger','parser'])

# Create a list with all geolocations that appear in the resumes.

locations = []
for desc in df_descriptions['Description_cleaned']:
    doc = nlp(desc)
    locations.extend([ent.text for ent in doc.ents if ent.label_ in ['LOC', 'GPE']])

# %%
print(len(Counter(locations).most_common()))
Counter(locations).most_common()
# Out:
# 495
# [('london', 1071),
#  ('cisco', 469),
#  ('europe', 249),
#  ('roadmap', 67),
#  ('belfast', 49),
#  ('west london', 46),
#  ('birmingham', 38),
#  ('west', 34),
#  ('north west', 33),
#  ('west yorkshire', 30),
#  ('linq', 29),
#  ('scotland', 28),
#  ('cambridge', 28),
#  ('north east', 26),
#  ('lan wan', 24),
#  ('south east', 23),
#  ('germany', 22),
#  ('newcastle', 22),
#  ('garden city', 21),
#  ('san vlan', 20),
#  ('south west', 19),
#  ('south wales', 18),
#  ('php', 17),
#  ('south west london', 17),
#  ('north england', 16),
#  ('north yorkshire', 16),
#  ('firewalls', 15),
#  ('north london', 13),
#  ('west sussex', 12),
#  ('ssas', 12),
#  ('button', 11),
#  ('roc', 11),
#  ('paris', 11),
#  ('southampton hampshire', 11),
#  ('ssrs ssas', 11),
#  ('itil', 10),
#  ('united kingdom', 10),
#  ('frankfurt', 10),
#  ('juniper cisco', 9),
#  ('troubleshooting cisco', 9),
#  ('ireland', 9),
#  ('san nas', 9),
#  ('uk', 9),
#  ('richmond', 9),
#  ('qualys', 9),
#  ('warrington', 9),
#  ('northern ireland', 9),
#  ('india', 9),
#  ('north west london', 8),
#  ('macclesfield', 8),
#  ('luton', 8),
#  ('biggleswade', 8),
#  ('canada', 8),
#  ('north america europe', 8),
#  ('oforefront', 8),
#  ('san windows', 7),
#  ('san storage', 7),
#  ('keynsham', 7),
#  ('north west england', 7),
#  ('knutsford', 7),
#  ('japan', 7),
#  ('middle east', 7),
#  ('tivoli', 7),
#  ('aruba', 6),
#  ('mvc razor', 6),
#  ('south east london', 6),
#  ('lan wan security', 6),
#  ('php software', 6),
#  ('south yorkshire', 6),
#  ('westminster hyde park', 6),
#  ('netherlands', 6),
#  ('north wales', 6),
#  ('mix city', 6),
#  ('imap', 6),
#  ('giacgcia', 6),
#  ('south west south east', 6),
#  ('lefthand', 5),
#  ('thames valley', 5),
#  ('newcastle york', 5),
#  ('east london', 5),
#  ('new zealand', 5),
#  ('new york', 5),
#  ('england', 5),
#  ('edinburgh', 5),
#  ('south yorkshire client reputable organisation', 5),
#  ('nottingham city', 5),
#  ('dewsbury', 5),
#  ('newcastleupontyne', 5),
#  ('belgium', 5),
#  ('php zend', 5),
#  ('watford', 5),
#  ('surrey hampshire', 5),
#  ('chicago', 5),
#  ('mssql', 5),
#  ('south west england', 5),
#  ('london city', 5),
#  ('portugal', 5),
#  ('east', 5),
#  ('central london', 5),
#  ('iaas', 5),
#  ('sql php', 5),
#  ('location city', 4),
#  ('manchester area', 4),
#  ('malton', 4),
#  ('gatwick', 4),
#  ('hamburg', 4),
#  ('luton bedford', 4),
#  ('france', 4),
#  ('wakefield', 4),
#  ('republic ireland', 4),
#  ('kasia', 4),
#  ('oxfordshire', 4),
#  ('phpmyadmin', 4),
#  ('doha', 4),
#  ('qatar', 4),
#  ('west sussex hampshire', 4),
#  ('northern district', 4),
#  ('supplier base', 4),
#  ('south coast', 4),
#  ('san server', 4),
#  ('south west london plus', 4),
#  ('san technologies', 4),
#  ('gcih', 4),
#  ('lan cisco', 3),
#  ('san linux', 3),
#  ('sun solaris', 3),
#  ('nexus cisco', 3),
#  ('south manchester', 3),
#  ('twickenham', 3),
#  ('burgess hill', 3),
#  ('australia', 3),
#  ('italy', 3),
#  ('berlin', 3),
#  ('south england', 3),
#  ('south west client', 3),
#  ('maclurg', 3),
#  ('mansfield', 3),
#  ('denver', 3),
#  ('keynes buckinghamshire', 3),
#  ('south birmingham', 3),
#  ('norfolk', 3),
#  ('dublin', 3),
#  ('php python', 3),
#  ('china', 3),
#  ('cheltenham', 3),
#  ('central glasgow', 3),
#  ('skipton', 3),
#  ('win sql sql sql', 3),
#  ('west london easy', 3),
#  ('helsinki', 3),
#  ('variant sql', 3),
#  ('manchester city', 3),
#  ('vmware', 3),
#  ('south east international computer consultants ltd hmg', 3),
#  ('yorkshire south yorkshire', 3),
#  ('anand', 3),
#  ('johannesburg', 3),
#  ('peoplesoft', 3),
#  ('watlington', 3),
#  ('san hitachi', 3),
#  ('nmap', 3),
#  ('picturesque', 3),
#  ('san left', 3),
#  ('southern california', 3),
#  ('kamailio', 2),
#  ('mobileand', 2),
#  ('wlan', 2),
#  ('etherchannel', 2),
#  ('worcestershire', 2),
#  ('lan wan san', 2),
#  ('rexer', 2),
#  ('north client', 2),
#  ('ccna', 2),
#  ('splat', 2),
#  ('multivendor', 2),
#  ('multi city', 2),
#  ('north birmingham', 2),
#  ('san backup', 2),
#  ('vpn', 2),
#  ('rsa bluecoat', 2),
#  ('africa', 2),
#  ('phoenix', 2),
#  ('south east england', 2),
#  ('washington', 2),
#  ('honk kong', 2),
#  ('atlanta', 2),
#  ('america', 2),
#  ('protocols rtsp', 2),
#  ('northumbria', 2),
#  ('higherprofile client', 2),
#  ('sql gloucestershire', 2),
#  ('applicati', 2),
#  ('sean devlin', 2),
#  ('holland', 2),
#  ('luxembourg slovenia cyprus', 2),
#  ('north west northumberland', 2),
#  ('brighton', 2),
#  ('americas asia', 2),
#  ('middle east africa europe', 2),
#  ('winchester', 2),
#  ('paddington', 2),
#  ('vienna', 2),
#  ('grange hill', 2),
#  ('north bristol', 2),
#  ('belfast client', 2),
#  ('fleet hampshire', 2),
#  ('bonuscompany', 2),
#  ('edinburgh city centre', 2),
#  ('malaysia', 2),
#  ('brazil', 2),
#  ('salford', 2),
#  ('europe asia', 2),
#  ('wpf', 2),
#  ('metadata', 2),
#  ('frameworks zend', 2),
#  ('netdevelopersoftwarehousewarrington', 2),
#  ('livingston', 2),
#  ('java scala functional programming', 2),
#  ('new heights', 2),
#  ('ssis ssas', 2),
#  ('new sql', 2),
#  ('kbasicsqlserver', 2),
#  ('central cambridge', 2),
#  ('sunderland york', 2),
#  ('ecommerce york', 2),
#  ('holton', 2),
#  ('glasgow', 2),
#  ('spain', 2),
#  ('ecrm', 2),
#  ('euston north west london', 2),
#  ('forefront', 2),
#  ('mars', 2),
#  ('savvy background', 2),
#  ('asia', 2),
#  ('britain', 2),
#  ('nottingham client', 2),
#  ('southern england', 2),
#  ('togaf', 2),
#  ('kofax', 2),
#  ('quinn strictest', 2),
#  ('manchester', 2),
#  ('south east south west', 2),
#  ('vast county', 2),
#  ('san global apps network', 2),
#  ('epos', 2),
#  ('scrum', 2),
#  ('handson area', 2),
#  ('portsmouth south client', 2),
#  ('lan wan refresh', 2),
#  ('axapta', 2),
#  ('centrifugal', 2),
#  ('central birmingham', 2),
#  ('gym britain', 2),
#  ('rocs', 2),
#  ('hris', 2),
#  ('newport cardiff', 2),
#  ('warwick client', 2),
#  ('bfsi', 2),
#  ('north east forefront technology', 2),
#  ('bash php', 2),
#  ('freebsd', 2),
#  ('network cisco', 2),
#  ('asia europe', 2),
#  ('qsa isa hsm', 2),
#  ('palo alto', 2),
#  ('gcsx', 2),
#  ('afds', 2),
#  ('hyphen', 2),
#  ('wan lan cisco', 1),
#  ('kingdomcompany', 1),
#  ('intrateam', 1),
#  ('mediums', 1),
#  ('lampthe companya', 1),
#  ('srx ssgcisco', 1),
#  ('nexus', 1),
#  ('cisco commands', 1),
#  ('san part', 1),
#  ('cork city', 1),
#  ('town ireland city', 1),
#  ('san vmware', 1),
#  ('mitel sql', 1),
#  ('north africa', 1),
#  ('mitel', 1),
#  ('san experience', 1),
#  ('hong kong', 1),
#  ('cayman', 1),
#  ('waas mars', 1),
#  ('lan wan cisco', 1),
#  ('uccx', 1),
#  ('san netapp', 1),
#  ('san emc', 1),
#  ('west south yorkshire', 1),
#  ('asa firewalls cisco', 1),
#  ('asia pacific', 1),
#  ('milan', 1),
#  ('houston south africa', 1),
#  ('guildford', 1),
#  ('europe america', 1),
#  ('lan security', 1),
#  ('lan wan wlan pbx ipt mobile satellite', 1),
#  ('vlans', 1),
#  ('lan wan ipt', 1),
#  ('procurve', 1),
#  ('neustar', 1),
#  ('lan wan network', 1),
#  ('south east united', 1),
#  ('south cambridge', 1),
#  ('new mediai', 1),
#  ('drupallamp', 1),
#  ('lsquocando rsquo', 1),
#  ('north east forefront', 1),
#  ('north wales location', 1),
#  ('greenfieldan area', 1),
#  ('south west united kingdom', 1),
#  ('nottinghamshire east', 1),
#  ('views city', 1),
#  ('hannah', 1),
#  ('west bromwich', 1),
#  ('nottingham city centre', 1),
#  ('north hampshire', 1),
#  ('infiniband', 1),
#  ('lake district', 1),
#  ('aspnetstockportcheshire', 1),
#  ('north west client', 1),
#  ('katharine’s way london', 1),
#  ('staffordshire west', 1),
#  ('san francisco', 1),
#  ('middle silicon', 1),
#  ('nosqldb', 1),
#  ('barnet', 1),
#  ('south birmingham city centre', 1),
#  ('hadoop', 1),
#  ('net york', 1),
#  ('united states', 1),
#  ('environmentin', 1),
#  ('west client', 1),
#  ('nathan callaghan futureheads', 1),
#  ('austria', 1),
#  ('knit', 1),
#  ('northampton', 1),
#  ('applicationswpf', 1),
#  ('north cambridge', 1),
#  ('prpc', 1),
#  ('keynes', 1),
#  ('wareham', 1),
#  ('gui component', 1),
#  ('repo', 1),
#  ('gloucestershire', 1),
#  ('minibus', 1),
#  ('struts', 1),
#  ('ocjp scjp', 1),
#  ('scala', 1),
#  ('keynes hertfordshire', 1),
#  ('desirable', 1),
#  ('•deep', 1),
#  ('softwaredevelopersouthampton', 1),
#  ('zina', 1),
#  ('america europe', 1),
#  ('hudson amazon', 1),
#  ('nottingham city centre east', 1),
#  ('surrey cobol', 1),
#  ('sql html', 1),
#  ('zurich', 1),
#  ('php sql', 1),
#  ('newcastleupontyne city centre', 1),
#  ('compan', 1),
#  ('birmingham city', 1),
#  ('frankfurt germany', 1),
#  ('surrey west london', 1),
#  ('veritas', 1),
#  ('central cardiff', 1),
#  ('welwyn garden city', 1),
#  ('belfast city', 1),
#  ('plc client', 1),
#  ('azizi', 1),
#  ('applicationand', 1),
#  ('san dba ssis ssrs', 1),
#  ('profiler', 1),
#  ('brentwood', 1),
#  ('north west commutable', 1),
#  ('tsql ssis', 1),
#  ('europe north america', 1),
#  ('quinn vanrath', 1),
#  ('dublin ireland', 1),
#  ('•firsthand', 1),
#  ('versionsany', 1),
#  ('san storage sql', 1),
#  ('luxembourg', 1),
#  ('sitescope database', 1),
#  ('namp servicedesk', 1),
#  ('ichgcp phase', 1),
#  ('south africa', 1),
#  ('est rec', 1),
#  ('centre bristol', 1),
#  ('south east energetic consultancy', 1),
#  ('savvy', 1),
#  ('cima', 1),
#  ('manchester base', 1),
#  ('san nas sql', 1),
#  ('projectsa', 1),
#  ('georgia', 1),
#  ('poland', 1),
#  ('sweden', 1),
#  ('denmark', 1),
#  ('ireland europe', 1),
#  ('portsmouth', 1),
#  ('orgtel', 1),
#  ('solutionsoversee', 1),
#  ('dubai', 1),
#  ('taiwan', 1),
#  ('prince surestep', 1),
#  ('baan', 1),
#  ('eden scotts client', 1),
#  ('prince itl', 1),
#  ('london frimley', 1),
#  ('elan', 1),
#  ('meica', 1),
#  ('archie', 1),
#  ('thames valley global', 1),
#  ('norway', 1),
#  ('theit', 1),
#  ('northwest client', 1),
#  ('georgina', 1),
#  ('xml client', 1),
#  ('pretoria', 1),
#  ('prince certified client client construction', 1),
#  ('east hampshire', 1),
#  ('marlborough', 1),
#  ('west coast', 1),
#  ('uxbridge buckinghamshire', 1),
#  ('west chair', 1),
#  ('north sea', 1),
#  ('location jersey', 1),
#  ('midland', 1),
#  ('benefitsmy client', 1),
#  ('keynes client', 1),
#  ('additon', 1),
#  ('eden brown', 1),
#  ('quantify manage', 1),
#  ('pioneers', 1),
#  ('strand', 1),
#  ('south west london zone', 1),
#  ('edinburgh city', 1),
#  ('south london', 1),
#  ('san storage area', 1),
#  ('windows', 1),
#  ('counties', 1),
#  ('eastbourne', 1),
#  ('loughborough', 1),
#  ('eaton', 1),
#  ('belfast county', 1),
#  ('west hertfordshire', 1),
#  ('acorss', 1),
#  ('wakefield client', 1),
#  ('west yorkshire wakefield', 1),
#  ('san blue', 1),
#  ('san accordance', 1),
#  ('san based', 1),
#  ('phpi', 1),
#  ('kerry', 1),
#  ('focus europe', 1),
#  ('congleton', 1),
#  ('php html', 1),
#  ('skillset', 1),
#  ('klondon', 1),
#  ('south east england europe', 1),
#  ('san implementations', 1),
#  ('west suffolk', 1),
#  ('ups west london', 1),
#  ('redis hadoop', 1),
#  ('tech city', 1),
#  ('europe usa', 1),
#  ('san mcitp', 1),
#  ('pki identity', 1),
#  ('divspan', 1),
#  ('veracode', 1),
#  ('vision britain', 1),
#  ('ilkeston', 1),
#  ('mirp', 1),
#  ('bluecoat websense', 1),
#  ('north america europe asia pacific', 1),
#  ('afield', 1),
#  ('best city', 1),
#  ('new approaches', 1),
#  ('north east england', 1),
#  ('managementpmp', 1),
#  ('keynes birmingham', 1),
#  ('iqtsb ware', 1),
#  ('mubadala', 1),
#  ('south area', 1),
#  ('ids base', 1),
#  ('north west area', 1),
#  ('beirut', 1),
#  ('singapore', 1),
#  ('suffolk', 1)]

# %%
# List of locations with count > 2.

all_locations_abv2 = []

for i in Counter(locations).most_common():
    if i[1] > 2: all_locations_abv2.append(i[0])

# All words in locations with count > 2 that don't correspond to geolocations.

remove_loc = set(['cisco','lan wan','roadmap', 'linq','san vlan','php','firewalls','ssas','itil','roc','juniper cisco',
'troubleshooting cisco','san nas','qualys','ssrs ssas','san windows','san storage','php software','aruba',
'lan wan security', 'net asp net','tivoli' ,'mix city' , 'imap','giacgcia','lefthand','higherprofile client',
'sql asp','php zend', 'farringdon asp','mssql','iaas','sql php','san technologies','javaj','phpmyadmin',
'supplier base','san server','gcih','lan cisco', 'san linux', 'sun solaris','nexus cisco','agile net sql',
'php python','win sql sql sql','vmware','nmap','san left','wlan'])

add_loc = set(['farringdon']) # Different from 'farringdon asp', so we add this back.

# Final set of geolocations to remove from text.

geolocations = set(all_locations_abv2).difference(remove_loc).union(add_loc)

print(len(all_locations_abv2))
print(len(geolocations))
# Out:
# 164
# 122

# %%
# Remove geolocations from text.

def remove_geoloc(x):
    regex = re.compile(r'\b({}r)\b'.format('|'.join(geolocations)), flags = re.IGNORECASE)
    return regex.sub(' ', x)

df_descriptions['Description_cleaned'] = df_descriptions['Description_cleaned'].apply(remove_geoloc)

# Remove leading/trailing/double white spaces.

df_descriptions['Description_cleaned'] = df_descriptions['Description_cleaned'].apply(remove_empty)

# %%
# Inspect output.

df_descriptions['Description_cleaned'][:10]
# Out:
# 0    job title senior support network analyst locat...
# 1    client global organisation providing support p...
# 2    job title administrator customer support netwo...
# 3    senior account manager oil gas sector sales ma...
# 4    altran currently recruiting telecoms network d...
# 5    network administrator leeds permanent position...
# 6    account director major managed networks servic...
# 7    senior account manager oil gas sector sales ma...
# 8    network security mssql presales consultant pac...
# 9    bdm network solutions basic ote uncapped curre...
# Name: Description_cleaned, dtype: object

# %% [markdown]
# ## 6. Lemmatization

# %%
# Construct empty, new column.

df_descriptions['Description_lemma'] = ''

# %%
# Lemmatize the entire set of job descriptions. Please note, this takes some time. 

df_descriptions['Description_lemma'] = df_descriptions['Description_cleaned'].\
        apply(lambda x: " ".join([token.lemma_ if token.text not in ordinal else token.text for token in nlp(x)]))

# %%
# Inspect output.

df_descriptions['Description_lemma'][:10]
# Out:
# 0    job title senior support network analyst locat...
# 1    client global organisation provide support pro...
# 2    job title administrator customer support netwo...
# 3    senior account manager oil gas sector sale maj...
# 4    altran currently recruit telecom network desig...
# 5    network administrator leeds permanent position...
# 6    account director major manage network service ...
# 7    senior account manager oil gas sector sale maj...
# 8    network security mssql presales consultant pac...
# 9    bdm network solution basic ote uncap currently...
# Name: Description_lemma, dtype: object

# %% [markdown]
# ## 7. Join collocations

# %%
# Create a long list of all words in all documents, in the original order. 

documents = df_descriptions['Description_lemma'].tolist()
words = words_list(documents)

# %%
# Find the most common collocations.

common_collocations = BigramCollocationFinder.from_words(words)
bgm = BigramAssocMeasures()
scores = bgm.mi_like 

# Print the collocations, joined by an underscore '_'.

collocations = {'_'.join(bigram): mi_like 
                for bigram, mi_like in common_collocations.score_ngrams(scores)} 

collocations
# Out:
# {'originally_post': 1329.691793233841,
#  'project_manager': 904.3371463025238,
#  'sql_server': 828.2679186152027,
#  'job_originally': 670.6174515861518,
#  'software_developer': 427.38292461270754,
#  'act_employment': 393.4472864755076,
#  'active_directory': 351.6626745092481,
#  'employment_agency': 344.1567312123717,
#  'allegis_group': 321.0591922005571,
#  'relation_vacancy': 275.1221547269934,
#  'track_record': 228.23606260554675,
#  'cut_edge': 223.16832622461493,
#  'visual_studio': 217.1311421911422,
#  'life_cycle': 197.50127349091974,
#  'blue_chip': 146.9166993720565,
#  'computer_science': 129.83560140890495,
#  'problem_solve': 127.71495375532493,
#  'sexual_orientation': 126.75,
#  'html_css': 118.73800537037565,
#  'fast_pace': 108.9760337728328,
#  'system_administrator': 98.596391690062,
#  'please_send': 95.90067458377082,
#  'discriminate_ground': 94.94178571428571,
#  'successful_candidate': 93.62341441852001,
#  'communication_skill': 90.00688624204743,
#  'teksystems_aerotek': 89.0,
#  'aston_carter': 85.0,
#  'disaster_recovery': 76.20016658337498,
#  'immediate_consideration': 74.72713880401571,
#  'terminology_advert': 74.27305886298844,
#  'milton_keynes': 72.0,
#  'per_annum': 70.90486386840612,
#  'third_party': 70.21671972644735,
#  'intend_discriminate': 70.02232854864434,
#  'oil_gas': 70.01626794258374,
#  'collectively_refer': 67.56771545827634,
#  'lan_wan': 66.85743740795287,
#  'advert_intend': 60.3707372363493,
#  'explicit_consent': 59.71042188805347,
#  'internal_external': 59.343421160971594,
#  'car_allowance': 57.57046332046332,
#  'project_management': 57.128133957420275,
#  'url_remove': 56.01851851851852,
#  'facebook_twitter': 54.112554112554115,
#  'software_engineer': 52.39279362665697,
#  'employment_business': 48.77693265289279,
#  'award_win': 48.03368561420269,
#  'object_orient': 44.46765694313752,
#  'linkedin_jam': 42.02615581953042,
#  'twitter_linkedin': 41.72596899224806,
#  'career_progression': 41.45408256445097,
#  'database_administrator': 37.833837338557174,
#  'large_scale': 37.32188620231228,
#  'castle_windsor': 36.99125064333505,
#  'well_practice': 36.07560561923592,
#  'object_orientate': 35.84565878076396,
#  'childcare_voucher': 35.36418511066398,
#  'fantastic_opportunity': 35.09498588671052,
#  'red_hat': 35.03030303030303,
#  'financial_service': 34.861479294848365,
#  'performance_tune': 34.114976363794554,
#  'store_procedure': 33.77306510574357,
#  'gladly_accept': 33.603949785670544,
#  'harrington_starr': 33.108108108108105,
#  'confirm_gladly': 32.71092677345538,
#  'pci_dss': 32.17539504752679,
#  'public_sector': 31.152647975077883,
#  'agency_relation': 31.062255720388645,
#  'id_ips': 30.661622276029057,
#  'temporary_worker': 29.293333333333333,
#  'attention_detail': 28.492017404295368,
#  'information_security': 27.947193179897013,
#  'software_development': 27.687678044440503,
#  'european_economic': 26.9960830395613,
#  'aerotek_division': 26.9421768707483,
#  'get_touch': 26.741388051108878,
#  'connection_fulfilment': 26.42929728693318,
#  'ideal_candidate': 26.297236592033986,
#  'canary_wharf': 26.0,
#  'long_term': 25.384596577017113,
#  'privacy_notice': 25.226114649681527,
#  'please_apply': 24.54561540867015,
#  'nigel_frank': 24.2,
#  'nationality_ethnic': 23.982517482517483,
#  'nhibernate_rhinomocks': 23.88382792730619,
#  'css_javascript': 23.477755153073982,
#  'competitive_salary': 22.87478466216165,
#  'prove_track': 22.777613800374382,
#  'benefit_package': 22.49613752621706,
#  'root_cause': 21.620173364854217,
#  'gender_race': 21.51480255701138,
#  'shell_script': 21.170802097631366,
#  'eligible_live': 21.098091171022844,
#  'first_instance': 20.978831433786873,
#  'work_closely': 20.8724129979407,
#  'regardless_gender': 20.454714732608373,
#  'load_balance': 20.144058295964125,
#  'hemel_hempstead': 20.0,
#  'windsor_orm': 19.866628396479143,
#  'minimum_year': 19.824766701229446,
#  'badenoch_clark': 19.692307692307693,
#  'agile_scrum': 19.593444086288123,
#  'write_verbal': 19.517198609997326,
#  'excellent_communication': 19.48358389399313,
#  'subject_matt': 19.46783419250053,
#  'monday_friday': 19.28985507246377,
#  'avoid_disappointment': 19.266666666666666,
#  'castle_monorail': 19.04310344827586,
#  'monorail_castle': 19.04310344827586,
#  'strict_confidence': 18.468163430420713,
#  'ground_age': 17.707422274695002,
#  'equal_opportunity': 17.671707808624486,
#  'hit_grind': 17.5024805102764,
#  'disability_age': 17.33179123248293,
#  'ruby_rail': 17.20612128146453,
#  'haywards_heath': 17.19047619047619,
#  'open_source': 17.153339672545087,
#  'rhinomocks_nunit': 16.156707127295363,
#  'jason_fashanu': 16.0,
#  'datum_centre': 15.72880570264444,
#  'treat_accordance': 15.70786541889483,
#  'ltd_act': 15.486999875976684,
#  'caput_resource': 15.439306289197772,
#  'voluntary_request': 15.172482113373693,
#  'loophole_infringement': 15.0,
#  'little_year': 14.93717098458321,
#  'please_note': 14.842224554232216,
#  'extra_mile': 14.491384432560903,
#  'austin_fraser': 14.45,
#  'trouble_shoot': 14.235294117647058,
#  'bury_edmunds': 14.08695652173913,
#  'would_like': 14.032686913404993,
#  'dns_dhcp': 14.017263399889309,
#  'rapidly_expand': 13.749951425795759,
#  'intrusion_detection': 13.717563837129054,
#  'state_art': 13.605442176870747,
#  'outside_european': 13.571801309506228,
#  'henry_morgan': 13.5,
#  'richard_gibson': 13.395348837209303,
#  'day_holiday': 13.38899003997738,
#  'linq_nhibernate': 13.084183994959043,
#  'cradle_grave': 13.066666666666666,
#  'wide_range': 12.987643988816403,
#  'internally_externally': 12.74150641025641,
#  'note_terminology': 12.7375139229227,
#  'gold_partner': 12.194337555448666,
#  'cover_letter': 12.104673971861471,
#  'suitably_qualify': 12.081791790440183,
#  'tight_deadline': 12.076878276062901,
#  'injection_ninject': 12.047058823529412,
#  'backup_recovery': 11.81885570784545,
#  'giacgcia_giac': 11.764705882352942,
#  'take_ownership': 11.645392987180083,
#  'orm_linq': 11.574470457079153,
#  'supply_chain': 11.546088099934254,
#  'datum_warehouse': 11.475956922120242,
#  'jam_recruitment': 11.358480066775309,
#  'high_availability': 11.341410646402418,
#  'supply_temporary': 11.266666666666667,
#  'subversion_svn': 11.184466019417476,
#  'soon_possible': 11.157677902621723,
#  'scrum_master': 11.096875215561841,
#  'balfour_beatty': 11.076923076923077,
#  'carter_limit': 11.015779202676331,
#  'limit_aston': 11.015779202676331,
#  'software_house': 10.973992751214212,
#  'matchtech_act': 10.927740221131723,
#  'stake_holder': 10.829754988633493,
#  'install_configure': 10.501818181818182,
#  'window_server': 10.472032539320114,
#  'development_team': 10.3493129476224,
#  'trunking_interconnection': 10.343157894736843,
#  'must_eligible': 10.298167754807807,
#  'etrm_ctrm': 10.285714285714286,
#  'accept_privacy': 10.260510629318984,
#  'age_confirm': 10.221386109902856,
#  'debian_ubuntu': 10.113022113022113,
#  'dawson_walsh': 10.0,
#  'disclaimer_find': 9.99812382739212,
#  'world_collectively': 9.988270980788675,
#  'oracle_dba': 9.96010201952568,
#  'law_firm': 9.902887139107612,
#  'tcpdump_iptrace': 9.818181818181818,
#  'end_user': 9.771993899456131,
#  'experience_work': 9.502741248663144,
#  'candidate_must': 9.346974655297677,
#  'religion_belief': 9.342560553633218,
#  'opportunity_arise': 9.34041555165002,
#  'self_motivate': 9.062230049362402,
#  'anti_virus': 9.0,
#  'holly_hughes': 9.0,
#  'juliette_allen': 8.861538461538462,
#  'race_disability': 8.849041317850391,
#  'key_skill': 8.770026515630873,
#  'feel_free': 8.751056763285025,
#  'hedge_fund': 8.700642523364486,
#  'web_application': 8.686232542027637,
#  'make_sure': 8.647699110059705,
#  'able_demonstrate': 8.636855499422905,
#  'would_advantageous': 8.611962056914628,
#  'mcsd_mcad': 8.602150537634408,
#  'refer_allegis': 8.557913887204366,
#  'gsm_umts': 8.532051282051283,
#  'notice_submit': 8.518298963654328,
#  'harvey_nash': 8.470588235294118,
#  'backup_restore': 8.468664686044644,
#  'opportunity_join': 8.43933760601254,
#  'timely_manner': 8.410790925812385,
#  'stl_boost': 8.391514500537056,
#  'private_medical': 8.382004349844824,
#  'day_day': 8.269655584945928,
#  'prince_practitioner': 8.21140440249886,
#  'request_fulfilment': 8.162972832926197,
#  'verbal_write': 8.14922480620155,
#  'javascript_jquery': 8.1052901069879,
#  'cooper_lomaz': 8.1,
#  'threaten_derail': 8.1,
#  'minimal_supervision': 8.044000933706815,
#  'pension_scheme': 8.004266948778982,
#  'debenham_framlingham': 8.0,
#  'edgar_cowen': 8.0,
#  'laceymarie_davis': 8.0,
#  'mvc_razor': 7.9227522670268185,
#  'high_level': 7.810966121863675,
#  'excite_opportunity': 7.765921452164822,
#  'wcf_wpf': 7.749722053998355,
#  'gym_membership': 7.737426210153483,
#  'policy_disclaimer': 7.734397677793904,
#  'ssis_ssrs': 7.730962504831852,
#  'math_physic': 7.68660567675346,
#  'high_quality': 7.593764413577376,
#  'udp_icmp': 7.410256410256411,
#  'excellent_opportunity': 7.311926712720459,
#  'work_within': 7.307885876491661,
#  'line_support': 7.255266943057788,
#  'high_profile': 7.188826532765096,
#  'anywhere_authorise': 7.17037037037037,
#  'ethnic_origin': 7.155149934810952,
#  'fast_grow': 7.152753479310103,
#  'ruth_maskrey': 7.142857142857143,
#  'fix_term': 7.106606138943827,
#  'restriction_visa': 7.1022727272727275,
#  'please_contact': 7.003206138243885,
#  'altova_xmlspy': 7.0,
#  'evasion_insertion': 7.0,
#  'insertion_checksums': 7.0,
#  'leighton_buzzard': 7.0,
#  'nids_evasion': 7.0,
#  'burn_sheehan': 6.993006993006993,
#  'profile_confirm': 6.975809716599191,
#  'race_colour': 6.955507668906072,
#  'ebusiness_suite': 6.942919217855026,
#  'asa_pix': 6.921912178239238,
#  'mission_critical': 6.862239637038565,
#  'leamington_spa': 6.76,
#  'pancras_euston': 6.75,
#  'xxx_xxx': 6.75,
#  'business_intelligence': 6.744477951012501,
#  'mock_moq': 6.7368421052631575,
#  'investment_bank': 6.65008105361949,
#  'qualys_nessus': 6.627272727272727,
#  '-PRON-_will': 6.613594611145132,
#  'first_class': 6.423020669967753,
#  'george_barnes': 6.4,
#  'solr_elasticsearch': 6.368421052631579,
#  'christian_gray': 6.320987654320987,
#  'examine_unusual': 6.2987179487179485,
#  'matt_expert': 6.276782257618494,
#  'word_format': 6.267722803805278,
#  'tyne_wear': 6.25,
#  'sniffer_tcpdump': 6.203282828282828,
#  'market_lead': 6.18561524751755,
#  'cissp_cisa': 6.15406162464986,
#  'privately_own': 6.153846153846154,
#  'agency_regard': 6.135176617968167,
#  'jessica_davey': 6.125,
#  'vice_versa': 6.125,
#  'self_starter': 6.123428433268859,
#  'currently_recruit': 6.114589926624001,
#  'marital_status': 6.112161746617466,
#  'cmap_jeppesen': 6.0,
#  'eam_spatial': 6.0,
#  'jprofile_jmeter': 6.0,
#  'ohyper_osharepoint': 6.0,
#  'year_experience': 5.963268076131833,
#  'sys_admin': 5.963239308462239,
#  'pdh_sdh': 5.9171597633136095,
#  'nav_navision': 5.901501501501501,
#  'penetration_tester': 5.872859960552268,
#  'remedial_action': 5.862393162393162,
#  'skill_experience': 5.861411699826945,
#  'stowmarket_debenham': 5.818181818181818,
#  'economically_strategically': 5.7792642140468224,
#  'lucene_solr': 5.776842105263158,
#  'please_forward': 5.732311800701173,
#  'highly_desirable': 5.731444767035934,
#  'router_switch': 5.715178710959302,
#  'employer_welcome': 5.699631180223285,
#  'group_limit': 5.6961335023124615,
#  'health_safety': 5.639489407930473,
#  'confidential_discussion': 5.633421878773243,
#  'leakage_prevention': 5.629838142153413,
#  'applicant_voluntary': 5.585396490943717,
#  'view_late': 5.580552688911822,
#  'msc_phd': 5.570970695970696,
#  'spring_hibernate': 5.56049822064057,
#  'atm_frame': 5.555555555555555,
#  'irrespective_sex': 5.554285714285714,
#  'group_teksystems': 5.516016713091922,
#  'agency_employment': 5.5126299387705835,
#  'ccsa_ccse': 5.5125,
#  'name_caput': 5.508945494891591,
#  'server_dba': 5.502935285187345,
#  'kindle_ereader': 5.444444444444445,
#  'distinct_advantage': 5.422769465022986,
#  'ioc_unity': 5.389473684210526,
#  'maclean_moore': 5.333333333333333,
#  'multi_thread': 5.317753975981824,
#  '-PRON-_be': 5.301956521739131,
#  'frame_relay': 5.281746031746032,
#  'treat_strict': 5.243585858585859,
#  'prompt_turnaround': 5.2378516624040925,
#  'forward_think': 5.211472868217054,
#  'team_player': 5.206213052753345,
#  'would_beneficial': 5.2007519970044935,
#  'network_security': 5.1929212472659945,
#  'ssrs_ssas': 5.184049079754601,
#  'route_switch': 5.146285021827048,
#  'dml_ddl': 5.142857142857143,
#  'jmeter_altova': 5.142857142857143,
#  'lrqa_bsi': 5.142857142857143,
#  'job_description': 5.1165690791985945,
#  'cisa_cism': 5.106663223140496,
#  'economic_area': 5.100536540240518,
#  'next_step': 5.07549032895119,
#  'senitor_associate': 5.073641818032383,
#  'operate_system': 5.060026041344959,
#  'orientation_caput': 5.044843049327354,
#  'job_title': 5.037587631903111,
#  'net_framework': 5.034409876244839,
#  'due_nature': 5.00570141990776,
#  'abigail_hailey': 5.0,
#  'cmake_rake': 5.0,
#  'good_understand': 4.974825056543547,
#  'lispan_stylefontsize': 4.923076923076923,
#  'penetration_test': 4.922427284807323,
#  'opportunity_employer': 4.920492082911794,
#  'interconnection_ipsec': 4.878848063555115,
#  'submit_personal': 4.878542545943603,
#  'gibson_noir': 4.876190476190477,
#  'sql_dba': 4.864418861497914,
#  'interview_slot': 4.798578199052133,
#  'previous_experience': 4.794981827735692,
#  'person_age': 4.7755592761470504,
#  'hardcore_coder': 4.764705882352941,
#  'bloomberg_reuters': 4.763888888888889,
#  'sed_awk': 4.763888888888889,
#  'geographically_disperse': 4.761904761904762,
#  'customer_face': 4.736675381641554,
#  'business_relation': 4.72819387222712,
#  'month_contract': 4.7114113549084315,
#  'market_leader': 4.682545698128551,
#  'unix_linux': 4.667714795614855,
#  'fourth_large': 4.662995248135444,
#  'front_end': 4.654170403587444,
#  'client_face': 4.641747859462651,
#  'age_sexual': 4.6292293565020834,
#  'hnc_hnd': 4.619528619528619,
#  'installation_configuration': 4.609373427764233,
#  'normalization_denormalization': 4.5,
#  'sanction_restorative': 4.5,
#  'end_end': 4.471373985431842,
#  'great_opportunity': 4.427049894476445,
#  'party_supplier': 4.4225146198830405,
#  'intuition_elegantly': 4.408163265306122,
#  'ethical_hacker': 4.39453125,
#  'recruitment_limit': 4.378752909872807,
#  'web_service': 4.371282998824021,
#  'tom_kemp': 4.3478260869565215,
#  'key_responsibility': 4.324875466998755,
#  'city_guild': 4.313432835820896,
#  'mcp_mcsd': 4.301075268817204,
#  'colour_nationality': 4.295454545454546,
#  'mark_keers': 4.247058823529412,
#  'degree_educate': 4.232680301399355,
#  'sudbury_stowmarket': 4.231404958677686,
#  'highly_skilled': 4.194988370631129,
#  'short_notice': 4.180831058538065,
#  'antimoney_launder': 4.166666666666667,
#  'boot_camp': 4.166666666666667,
#  'bubb_madison': 4.166666666666667,
#  'clapham_junction': 4.166666666666667,
#  'morgan_dawson': 4.166666666666667,
#  'preferential_jsoftware': 4.166666666666667,
#  'timeware_videoconferencing': 4.166666666666667,
#  'reference_ash': 4.159658119658119,
#  'ticket_loan': 4.138359891177614,
#  'imanage_worksite': 4.083333333333333,
#  'section_community': 4.06368899917287,
#  'orion_npm': 4.05,
#  'apache_tomcat': 4.0491758241758244,
#  'developer_join': 4.047669328478919,
#  'quote_reference': 4.041497975708502,
#  'easily_commutable': 4.039989837398374,
#  'privacy_policy': 4.020148073253861,
#  'acpo_acpos': 4.0,
#  'alice_patterson': 4.0,
#  'amy_johnson': 4.0,
#  'ape_bng': 4.0,
#  'basel_cva': 4.0,
#  'bng_dpe': 4.0,
#  'braga_porto': 4.0,
#  'brighouse_hebden': 4.0,
#  'burim_hykaj': 4.0,
#  'cdct_cdcmp': 4.0,
#  'clare_sinanan': 4.0,
#  'dpe_ipe': 4.0,
#  'earlsfield_haydon': 4.0,
#  'friendliness_supportiveness': 4.0,
#  'gwapt_gpen': 4.0,
#  'impartial_unbiased': 4.0,
#  'ipe_mtu': 4.0,
#  'isam_ape': 4.0,
#  'isle_wight': 4.0,
#  'lisbon_braga': 4.0,
#  'lombardi_appian': 4.0,
#  'osce_gwapt': 4.0,
#  'oscp_osce': 4.0,
#  'otley_wetherby': 4.0,
#  'portlets_jsps': 4.0,
#  'qmail_ecelerity': 4.0,
#  'qnx_vpx': 4.0,
#  'styleman_mfg': 4.0,
#  'surbiton_esher': 4.0,
#  'syscomerp_systex': 4.0,
#  'systex_prima': 4.0,
#  'thirsk_easingwold': 4.0,
#  'vdcs_vpcs': 4.0,
#  'vpx_vme': 4.0,
#  'wayne_hawthorne': 4.0,
#  'people_regardless': 3.9870666607254255,
#  'specialist_recruitment': 3.9792159957905815,
#  'casual_dress': 3.9768115942028985,
#  'ninject_ioc': 3.914705882352941,
#  'contributory_pension': 3.894372724263489,
#  'civica_universal': 3.878787878787879,
#  'unit_test': 3.8766387976186603,
#  'oracle_database': 3.862429405641838,
#  'please_visit': 3.8584393128969183,
#  'cast_iron': 3.857142857142857,
#  'goole_ride': 3.857142857142857,
#  'establishment_flourish': 3.854385964912281,
#  'area_connection': 3.846306243460063,
#  'accordance_allegis': 3.817080698258685,
#  'client_look': 3.814456601974381,
#  'belief_reason': 3.8117647058823527,
#  'simon_thomson': 3.7925925925925927,
#  'mvvm_prism': 3.750915750915751,
#  'multimillion_pound': 3.721969696969697,
#  'dynamic_axapta': 3.6833684210526316,
#  'annual_leave': 3.673788591290125,
#  'write_oral': 3.6676809389263205,
#  'follow_facebook': 3.6225684057530128,
#  'linux_system': 3.5753116227180217,
#  'hipaa_glba': 3.5714285714285716,
#  'midlothian_lothian': 3.5714285714285716,
#  'noir_consult': 3.540462427745665,
#  'division_allegis': 3.531448809273341,
#  'recruitment_act': 3.5205801374162684,
#  'bachelor_degree': 3.5142810799652007,
#  'life_assurance': 3.488346979842487,
#  'jeppesen_ecdis': 3.4722222222222223,
#  'nps_csat': 3.4722222222222223,
#  'currently_look': 3.4694590262362084,
#  'ocs_blackberry': 3.4615384615384617,
#  'moq_rhinomocks': 3.4218880534670006,
#  'svn_ajax': 3.405372605615324,
#  'tdd_bdd': 3.404779411764706,
#  'san_nas': 3.396049896049896,
#  'cism_cisa': 3.383608815426997,
#  'tcp_udp': 3.3822783119658117,
#  'impose_sanction': 3.375,
#  'team_member': 3.3540713593340636,
#  'excellent_benefit': 3.3261860683070803,
#  'regard_position': 3.3256113576749367,
#  'entity_framework': 3.3113936272932087,
#  'pre_sale': 3.310292871268481,
#  'household_name': 3.308328811720022,
#  'smtp_http': 3.302771618625277,
#  'tdd_castle': 3.2905362576064907,
#  'excel_powerpoint': 3.286330358038311,
#  'boroughbridge_ripon': 3.282051282051282,
#  'cep_liquidity': 3.272727272727273,
#  'daily_basis': 3.2615763333116448,
#  'mis_activeh': 3.24,
#  'free_park': 3.2367285458394397,
#  'currently_seek': 3.2267467778954804,
#  'assembler_ada': 3.2,
#  'castleford_holmfirth': 3.2,
#  'ilkley_sowerby': 3.2,
#  'lake_district': 3.2,
#  'nasty_chemical': 3.2,
#  'pro_rata': 3.2,
#  'srm_ebp': 3.2,
#  'must_able': 3.1772835297989968,
#  'ahead_prompt': 3.170278637770898,
#  'ncluding_enclosure': 3.125,
#  'ping_federate': 3.125,
#  'rob_baker': 3.125,
#  'precise_nature': 3.120398009950249,
#  'database_administration': 3.1036985637621934,
#  'oms_ems': 3.085714285714286,
#  'scheduler_tws': 3.085714285714286,
#  'dovecot_jenkins': 3.0625,
#  'sean_devlin': 3.0625,
#  'upon_precise': 3.044660194174757,
#  'interpersonal_skill': 3.031273670225834,
#  'parker_white': 3.0303030303030303,
#  'sound_like': 3.0251290877796904,
#  'chris_reilly': 3.025,
#  'solarwinds_orion': 3.025,
#  'limit_act': 3.0207838978941313,
#  'energetic_goaloriented': 3.017857142857143,
#  'fulfilment_applicant': 3.005008638402468,
#  'arbor_peakflow': 3.0,
#  'carillion_willmot': 3.0,
#  'checker_optimisers': 3.0,
#  'chesham_amersham': 3.0,
#  'clearpass_tufin': 3.0,
#  'collaberating_ukleading': 3.0,
#  'collinson_rockfield': 3.0,
#  'cristian_novotny': 3.0,
#  'czech_republic': 3.0,
#  'dixon_sir': 3.0,
#  'dll_smalltalk': 3.0,
#  'dunn_bradstreet': 3.0,
#  'endur_allegro': 3.0,
#  'henley_chesham': 3.0,
#  'jncip_jncis': 3.0,
#  'kamailio_openser': 3.0,
#  'kier_eon': 3.0,
#  'launchpad_sourceforge': 3.0,
#  'linda_davison': 3.0,
#  'lottie_robertson': 3.0,
#  'mcalpine_vinci': 3.0,
#  'mike_leeson': 3.0,
#  'millennium_copthorne': 3.0,
#  'monica_dhaliwal': 3.0,
#  'mscs_nlb': 3.0,
#  'naomi_madeley': 3.0,
#  'packeteer_packetshaper': 3.0,
#  'paypoint_sagepay': 3.0,
#  'rack_mount': 3.0,
#  'requiremnets_corperate': 3.0,
#  'rfis_rfps': 3.0,
#  'sarbanes_oxley': 3.0,
#  'symmetric_asymmetric': 3.0,
#  'temple_meads': 3.0,
#  'transportable_tablespaces': 3.0,
#  'tufin_securetrack': 3.0,
#  'willmot_dixon': 3.0,
#  'yas_mahtab': 3.0,
#  'https_smtp': 2.995731707317073,
#  'look_recruit': 2.986811083526508,
#  'canteen_petrol': 2.9761904761904763,
#  'resharper_ncrunch': 2.9761904761904763,
#  'snmp_mono': 2.9761904761904763,
#  'click_apply': 2.976044452424377,
#  'love_hear': 2.9674966383827144,
#  'modernise_streamline': 2.9411764705882355,
#  'reperio_human': 2.9411764705882355,
#  'atern_rad': 2.9316239316239314,
#  'time_budget': 2.9306491192422515,
#  'trade_name': 2.9249877270495825,
#  'tacacs_radius': 2.916,
#  'can_not': 2.9058520954549287,
#  'point_contact': 2.8860707673372583,
#  'commercial_experience': 2.867244412695173,
#  'kemp_harrington': 2.857142857142857,
#  'ssis_ssas': 2.8546567191787156,
#  'edmunds_braintree': 2.8444444444444446,
#  'walsh_henry': 2.8444444444444446,
#  'nunit_mstest': 2.8333333333333335,
#  'agree_timescale': 2.811815190157436,
#  'apply_online': 2.8027224084273996,
#  'keep_date': 2.8,
#  'group_inc': 2.7951872485298668,
#  'dsdm_atern': 2.793103448275862,
#  'high_volume': 2.7918069403661994,
#  'framlingham_bury': 2.782608695652174,
#  'thames_ditton': 2.782608695652174,
#  'problem_solver': 2.782442748091603,
#  'custody_magnetic': 2.7777777777777777,
#  'qlx_kypera': 2.7777777777777777,
#  'group_privacy': 2.758008356545961,
#  'dynamic_nav': 2.7436,
#  'manage_multiple': 2.7227032306364034,
#  'inc_group': 2.6976896608225465,
#  'join_team': 2.6877835411224513,
#  'group_transfer': 2.6850419775210863,
#  'dhcp_pxe': 2.6726907630522088,
#  'ambridge_harris': 2.6666666666666665,
#  'bishop_stortford': 2.6666666666666665,
#  'craig_eggett': 2.6666666666666665,
#  'esher_epsom': 2.6666666666666665,
#  'firefox_safari': 2.6666666666666665,
#  'freight_silly': 2.6666666666666665,
#  'gibson_noirconsulting': 2.6666666666666665,
#  'hawthorne_vadis': 2.6666666666666665,
#  'heathrow_airport': 2.6666666666666665,
#  'highlysecure_highlyavailable': 2.6666666666666665,
#  'hong_kong': 2.6666666666666665,
#  'jon_spragg': 2.6666666666666665,
#  'martyn_hurricks': 2.6666666666666665,
#  'morgan_dawsonandwalsh': 2.6666666666666665,
#  'vme_linus': 2.6666666666666665,
#  'http_https': 2.650909090909091,
#  'radius_syslog': 2.650909090909091,
#  'net_developer': 2.64500656482961,
#  'user_interface': 2.644307008407298,
#  'edge_technology': 2.6384233668271806,
#  'sccm_scom': 2.637720488466757,
#  'icmp_http': 2.6272727272727274,
#  'close_date': 2.62720999301188,
#  'submarine_surface': 2.6041666666666665,
#  'load_balancer': 2.5829596412556053,
#  'guis_sensor': 2.5789473684210527,
#  'thus_mitigate': 2.5746996996997,
#  'green_field': 2.5742836676217764,
#  'bgp_ospf': 2.5714285714285716,
#  'ospf_bgp': 2.5714285714285716,
#  'pegasus_exchequer': 2.5714285714285716,
#  'jboss_tomcat': 2.5682117028270874,
#  'skill_ability': 2.5651414593252544,
#  'activex_ole': 2.56,
#  'kensington_chelsea': 2.56,
#  'confirm_contact': 2.552275146970328,
#  'match_applicant': 2.531312695403064,
#  'policy_procedure': 2.5080121324839437,
#  'recruitment_agency': 2.5029903266634133,
#  'aareon_qlx': 2.5,
#  'haskell_apl': 2.5,
#  'datum_allegis': 2.4851704822677934,
#  'mcts_mcp': 2.4691358024691357,
#  'national_origin': 2.463083918974783,
#  'risk_assessment': 2.458542014468559,
#  'postfix_dovecot': 2.45,
#  'mstest_mock': 2.4466911764705883,
#  'experience_manage': 2.4397004416788146,
#  'security_consultant': 2.43527734185231,
#  'event_reconstruct': 2.4285714285714284,
#  'citrix_netscaler': 2.4167561761546725,
#  'switch_router': 2.4110910186859553,
#  'carbon_emission': 2.4,
#  'graham_wallace': 2.4,
#  'otv_ucs': 2.4,
#  'universal_orchard': 2.3986013986013988,
#  'career_path': 2.395247828308636,
#  'keep_abreast': 2.3872691933916426,
#  'coffee_shop': 2.380952380952381,
#  'essential_skill': 2.339382053199622,
#  'sense_urgency': 2.3372340425531917,
#  'express_consent': 2.331983805668016,
#  'share_option': 2.308653846153846,
#  'answer_yes': 2.3077731092436973,
#  'term_contract': 2.2951272793569455,
#  'season_ticket': 2.2908777969018934,
#  'iptrace_utility': 2.2865853658536586,
#  'cia_aaa': 2.2857142857142856,
#  'investigatory_confirmatory': 2.2857142857142856,
#  'ld_adam': 2.2857142857142856,
#  'nics_hds': 2.2857142857142856,
#  'rachel_lipman': 2.2857142857142856,
#  'wetherby_yeadon': 2.2857142857142856,
#  'ospf_eigrp': 2.278125,
#  'system_administration': 2.2777621985417835,
#  'cando_attitude': 2.276369463869464,
#  'apl_lisp': 2.272727272727273,
#  'imposingly_dominant': 2.272727272727273,
#  'look_someone': 2.266346665303405,
#  'provide_explicit': 2.260297783025056,
#  'adm_webspeed': 2.25,
#  'ann_harrison': 2.25,
#  'cdcmp_cdcdp': 2.25,
#  'cloudfront_vpc': 2.25,
#  'eqaullogic_isci': 2.25,
#  'gantt_chant': 2.25,
#  'guv_jassal': 2.25,
#  'ishan_shah': 2.25,
#  'jamie_macmillan': 2.25,
#  'spragg_reqiva': 2.25,
#  'upstream_downstream': 2.25,
#  'warfare_cybercrime': 2.25,
#  'william_cranston': 2.25,
#  'xml_xslt': 2.2414775793950645,
#  'warehouse_builder': 2.2405236198064884,
#  'log_ship': 2.231023102310231,
#  'relational_database': 2.2293618835567766,
#  'would_advantage': 2.228143232137241,
#  'steer_committee': 2.2222222222222223,
#  'continuous_integration': 2.2204541007891327,
#  'drive_licence': 2.209080911233307,
#  'ability_work': 2.1990642302862953,
#  'role_involve': 2.1943618630538135,
#  'educate_degree': 2.1841071642148067,
#  'disability_symbol': 2.1739130434782608,
#  'leader_field': 2.170075572515724,
#  'wpf_mvvm': 2.1657482918227906,
#  'ccsa_ssca': 2.1645021645021645,
#  'sourcefire_rsa': 2.1634615384615383,
#  'cpanel_lamp': 2.1620269002189554,
#  'lamp_stack': 2.1584930528859356,
#  'guild_certificate': 2.156716417910448,
#  'society_economy': 2.150537634408602,
#  'hmg_approve': 2.1496278887583236,
#  'service_desk': 2.1369646045530173,
#  'continuous_improvement': 2.1345878234232263,
#  'cayman_island': 2.1333333333333333,
#  'pega_metastorm': 2.1333333333333333,
#  'justine_lloyd': 2.1176470588235294,
#  'siem_toolset': 2.1163502755664423,
#  'high_calibre': 2.1107611222014238,
#  'catalyst_nexus': 2.109704641350211,
#  'network_infrastructure': 2.0897392935435954,
#  'welcome_application': 2.0837120306146857,
#  'dan_rodrigues': 2.0833333333333335,
#  'gcia_gcih': 2.0833333333333335,
#  'sftp_ftps': 2.0833333333333335,
#  'zeus_zxtm': 2.0833333333333335,
#  'automatically_reject': 2.0787878787878786,
#  'wide_variety': 2.0665967016491753,
#  'bash_perl': 2.0631578947368423,
#  'medical_insurance': 2.0592402227274227,
#  'alex_froude': 2.0416666666666665,
#  'groovy_grail': 2.0416666666666665,
#  'html_javascript': 2.0346679715041542,
#  'term_condition': 2.0302530415058766,
#  'change_control': 2.0230473354426453,
#  'origin_disability': 2.02210759027266,
#  'security_analyst': 2.021082054967079,
#  'unusual_trend': 2.0135245901639345,
#  'unsuccessful_occasion': 2.0102291325695583,
#  'aimee_o’hanlon': 2.0,
#  'aleph_voyager': 2.0,
#  'amoria_bond': 2.0,
#  'apc_memcache': 2.0,
#  'ascii_unicode': 2.0,
#  'avi_flv': 2.0,
#  'azmer_bains': 2.0,
#  'backtrack_metasploit': 2.0,
#  'bccpa_bccpp': 2.0,
#  'beach_doorstep': 2.0,
#  'beneficials_exsoftware': 2.0,
#  'billy_hayes': 2.0,
#  'bio_embeded': 2.0,
#  'biological_biomedical': 2.0,
#  'biomedical_pharmacological': 2.0,
#  'bottle_neck': 2.0,
#  'burp_idapro': 2.0,
#  'byte_ascii': 2.0,
#  'callaghan_futureheads': 2.0,
#  'caroleanne_manser': 2.0,
#  'cassandre_butcher': 2.0,
#  'celery_nose': 2.0,
#  'chaplin_vantage': 2.0,
#  'charlene_jacques': 2.0,
#  'cim_gvp': 2.0,
#  'cinderella_divine': 2.0,
#  'collier_wood': 2.0,
#  'cornwallis_elt': 2.0,
#  'cowbridge_treorchy': 2.0,
#  'cribbs_causeway': 2.0,
#  'elsewhere_responsibitilites': 2.0,
#  'emvbased_issuer': 2.0,
#  'encoder_receiver': 2.0,
#  'endeca_fatwire': 2.0,
#  'enterasys_safenet': 2.0,
#  'faye_charlesworth': 2.0,
#  'gfi_languard': 2.0,
#  'gsk_kingfisher': 2.0,
#  'heap_recursion': 2.0,
#  'hessen_hesse': 2.0,
#  'hewlett_packard': 2.0,
#  'hivemanager_•other': 2.0,
#  'holton_mary': 2.0,
#  'hostile_reluctant': 2.0,
#  'howgate_sable': 2.0,
#  'idapro_ollydbg': 2.0,
#  'illustrator_indesign': 2.0,
#  'ingres_postgress': 2.0,
#  'intereact_wwith': 2.0,
#  'jbpm_knime': 2.0,
#  'jca_jbi': 2.0,
#  'jonathan_williams': 2.0,
#  'katherine_oxlade': 2.0,
#  'kbasicsqlserver_dbmstsql': 2.0,
#  'kepler_jbpm': 2.0,
#  'lance_boraman': 2.0,
#  'lara_dsats': 2.0,
#  'larkfield_aylesford': 2.0,
#  'limscds_cerity': 2.0,
#  'lis_lara': 2.0,
#  'liveaction_photographic': 2.0,
#  'lucy_anning': 2.0,
#  'malaysia_brazil': 2.0,
#  'martinshakouri_computerpeople': 2.0,
#  'mastermaster_masterslave': 2.0,
#  'mca_mbg': 2.0,
#  'mcd_uca': 2.0,
#  'metasploit_burp': 2.0,
#  'miller_hyman': 2.0,
#  'mime_disp': 2.0,
#  'mpg_avi': 2.0,
#  'mywest_midlandsbased': 2.0,
#  'nose_sphinx': 2.0,
#  'npv_payback': 2.0,
#  'paisley_rutherglen': 2.0,
#  'palo_alto': 2.0,
#  'pas_xlims': 2.0,
#  'pdr_cdr': 2.0,
#  'peggy_aherne': 2.0,
#  'pharmacology_biosciences': 2.0,
#  'plymouth_torquay': 2.0,
#  'pmx_pas': 2.0,
#  'porth_pontypridd': 2.0,
#  'reasult_restructre': 2.0,
#  'recursion_polymorphism': 2.0,
#  'roof_drainage': 2.0,
#  'rtca_eurocae': 2.0,
#  'rti_utmc': 2.0,
#  'rutherford_appleton': 2.0,
#  'sab_choudhury': 2.0,
#  'sapmes_pmx': 2.0,
#  'sirsidynix_talis': 2.0,
#  'smell_antipatterns': 2.0,
#  'sophie_creswell': 2.0,
#  'sparx_artisan': 2.0,
#  'specialty_apparel': 2.0,
#  'spell_punctuation': 2.0,
#  'susie_venator': 2.0,
#  'sybaseiqlocation_albanscontract': 2.0,
#  'symmetrx_clariion': 2.0,
#  'sysprep_ghost': 2.0,
#  'tas_miller': 2.0,
#  'taverna_kepler': 2.0,
#  'teamcenter_windchill': 2.0,
#  'technicalskillswithinthefollowingvendors_enterasys': 2.0,
#  'technol_ogy': 2.0,
#  'therapy_physiotherapy': 2.0,
#  'tina_lacey': 2.0,
#  'treorchy_porth': 2.0,
#  'uca_mca': 2.0,
#  'utmc_utc': 2.0,
#  'vienna_austria': 2.0,
#  'waltham_porchester': 2.0,
#  'wep_eap': 2.0,
#  'wigton_cumbria': 2.0,
#  'woodrow_mercer': 2.0,
#  '•linq_•insurance': 2.0,
#  '•mvvm_•oop': 2.0,
#  '•xslt_•mq': 2.0,
#  'private_healthcare': 1.9955719557195573,
#  'senior_software': 1.9925218339560504,
#  'push_boundary': 1.9806576402321083,
#  'minute_walk': 1.9806547619047619,
#  'submission_asv': 1.9692307692307693,
#  'analytic_problemsolving': 1.9653814602132895,
#  'dependency_injection': 1.9652,
#  'permit_expose': 1.9636363636363636,
#  'jncia_jncie': 1.9488636363636365,
#  'assure_treat': 1.944896331738437,
#  'thame_uxbridge': 1.9285714285714286,
#  'proof_concept': 1.92798418972332,
#  'divspan_stylefontsize': 1.9230769230769231,
#  'sam_gillett': 1.9230769230769231,
#  'verb_header': 1.9230769230769231,
#  'equality_diversity': 1.917540181691125,
#  'grind_run': 1.9155075236568593,
#  'notify_respond': 1.9100470957613815,
#  'dot_net': 1.8847292968256324,
#  'world_class': 1.8830518624985029,
#  'ccnp_ccdp': 1.8792613636363635,
#  'consent_use': 1.863497453310696,
#  'visit_website': 1.858307992202729,
#  'signoff_sow': 1.8555743243243243,
#  'business_analyst': 1.852337402139564,
#  'positive_attitude': 1.8518668831168832,
#  'logrhythm_arcsight': 1.8461538461538463,
#  'low_latency': 1.8366800535475234,
#  'salary_plus': 1.8344441308642512,
#  'bill_crm': 1.8337075211756302,
#  'full_lifecycle': 1.8315818379923405,
#  'carolyn_ambis': 1.8285714285714285,
#  'gala_bingo': 1.8285714285714285,
#  'securid_hsbc': 1.8285714285714285,
#  'specialise_solely': 1.820814061054579,
#  'worker_apply': 1.8176665732174564,
#  'dhcp_dns': 1.813274298607859,
#  'project_plan': 1.8081537841812474,
#  'mes_scada': 1.805263157894737,
#  'spf_jsp': 1.805263157894737,
#  'frank_international': 1.8010922075194287,
#  'arcserve_veeam': 1.8,
#  'danny_woodhall': 1.8,
#  'dodd_frank': 1.8,
#  'halesowen_stourbridge': 1.8,
#  'lectra_plm': 1.8,
#  'loyal_longstanding': 1.8,
#  'megan_bradley': 1.8,
#  'michael_jensen': 1.8,
#  'morning_lunchtime': 1.8,
#  'mouth_powerful': 1.8,
#  'nonvirtualised_serverbased': 1.8,
#  'perfmon_dmvs': 1.8,
#  'redundant_pseudo': 1.8,
#  'ryan_quinn': 1.8,
#  'sscm_perfmon': 1.8,
#  'worldpay_paypoint': 1.8,
#  'apply_position': 1.7999847901285233,
#  'invest_heavily': 1.796252352507978,
#  'degree_computer': 1.7894778296261802,
#  'arinc_arinc': 1.7777777777777777,
#  'blogs_tweet': 1.7777777777777777,
#  'onquality_onbudget': 1.7777777777777777,
#  'reactive_panic': 1.7777777777777777,
#  'sutton_coldfield': 1.7777777777777777,
#  'client_base': 1.7707568217701606,
#  'hardware_firmware': 1.7683465959328029,
#  'development_lifecycle': 1.767179914028157,
#  'huxley_associate': 1.7598653119092627,
#  'plus_benefit': 1.7593607682568715,
#  'manager_join': 1.7586428695263079,
#  'highly_motivate': 1.7244233528308133,
#  'cisco_ccnp': 1.7175550906019657,
#  'checkpoint_firewall': 1.7162197194458046,
#  'quantum_super': 1.7142857142857142,
#  'watchguard_firebox': 1.7142857142857142,
#  'reed_specialist': 1.7045454545454546,
#  'transfer_datum': 1.7015853312716358,
#  'hot_cold': 1.7006802721088434,
#  'protectively_mark': 1.6941176470588235,
#  'abel_cole': 1.6875,
#  'acia_acsa': 1.6875,
#  'fruit_veg': 1.6875,
#  'lifesize_polycom': 1.6875,
#  'prove_experience': 1.6863803969510525,
#  'ipsec_vpns': 1.6800656275635768,
#  'welcome_applicant': 1.6752520545623995,
#  'graham_feegan': 1.6666666666666667,
#  'jake_king': 1.6666666666666667,
#  'permanent_basis': 1.6626596762421524,
#  'applicant_must': 1.6510383272742508,
#  'ipswich_suffolk': 1.644736842105263,
#  'keers_executive': 1.644736842105263,
#  'beatty_workplace': 1.641025641025641,
#  'lesson_learn': 1.6390556222488997,
#  'datum_treat': 1.6344833182629663,
#  'clear_concise': 1.6207469431153643,
#  'spring_technology': 1.6201128358470058,
#  'responsibility_include': 1.6201092169626796,
#  'role_please': 1.6150197208379584,
#  'bridgwater_plymouth': 1.6,
#  'coal_metal': 1.6,
#  'conferencing_telepresence': 1.6,
#  'exmouth_taunton': 1.6,
#  'fwsm_asas': 1.6,
#  'gigabytes_terabytes': 1.6,
#  'gpen_gcih': 1.6,
#  'ipkvms_serial': 1.6,
#  'multibyte_character': 1.6,
#  'otv_vdcs': 1.6,
#  'toot_collier': 1.6,
#  'sql_database': 1.5887774911566626,
#  'pop_ldap': 1.5845238095238094,
#  'pxe_apache': 1.5845238095238094,
#  'udp_snmp': 1.5824175824175823,
#  'fortinet_sourcefire': 1.5783045977011494,
#  'solve_skill': 1.5746907102644094,
#  'argent_bus': 1.565217391304348,
#  'body_lrqa': 1.565217391304348,
#  'openhousing_aareon': 1.5625,
#  'technical_support': 1.5584347335618822,
#  'science_math': 1.5534794179265048,
#  'braintree_colchester': 1.5515151515151515,
#  'hibernate_strut': 1.5515151515151515,
#  'span_tree': 1.5515151515151515,
#  'design_pattern': 1.550529391996801,
#  'risk_issue': 1.5463022360101482,
#  'skill_set': 1.5453017988882327,
#  'oldham_rochdale': 1.542857142857143,
#  'saml_oauth': 1.542857142857143,
#  'centos_redhat': 1.5396335132890366,
#  'make_recommendation': 1.5385433427657254,
#  'even_hairdresser': 1.5384615384615385,
#  'work_alongside': 1.5334786651336696,
#  'good_establish': 1.5320488460260986,
#  'certes_compute': 1.5300529430084087,
#  'tsql_store': 1.5277681532445677,
#  'full_life': 1.526751466394151,
#  'local_authority': 1.524627720504009,
#  ...}

# %%
# Many different collocations.

len(collocations)
# Out:
# 188544

# %%
# Join the X most common collocations in all documents by an underscore.

l_begin = []
l_end = []

for coll in collocations:
    if collocations[coll] > 50:
        begin, end = coll.split('_')   
        l_begin.append(begin)
        l_end.append(end)

df_descriptions['Description_lemma'] = df_descriptions['Description_lemma'].apply(join_collocations)

# %%
# Remove leading/trailing/double white spaces.

df_descriptions['Description_lemma'] = df_descriptions['Description_lemma'].apply(remove_empty)

# Inspect the output.

df_descriptions['Description_lemma'][2]
# Out:
# 'job title administrator customer support network disaster_recovery administrationreference location central londonsalary kexcellent opportunity experience administrator hand capable confident join exist service team directly regional manager successful administrator responsible provide support customer across region support various ongoing base project across role require broad mix technical customer orient skill main focus ensure excellent customer satisfaction organisation communication escalation management successful administrator join small team must selfmotivated keen problem solver able work good pressure must also comfortable deal round mix range engineer admin staff shareholder company travel require time time therefore desire applicant full drive license able work away home occasion work follow technology essential window vista window server microsoft office toshiba laptop compaq desktops tcp procurve switch good understand apple mac ios mitel telephony experience work follow technology desirable dell poweredge server sharepoint symantec backup exec active_directory please forward lynne hamilton wilde associate work capacity employment business vacancy'

# %% [markdown]
# ## 8. Store output

# %%
# Output final dataframe.

df_descriptions.to_csv('Descriptions_cleaned.csv', index = False)
